# %% [markdown]
# # Imports
# <a id='imports_id'> </a>

# %%
import os
import json

import pandas as pd
from dataclasses import dataclass, field
from typing import TextIO, List
from abc import ABC
import pyarrow as pa
from functools import cached_property

# %%
PREFIX = 'sent'
DATA_FOLDER = 'data'
RAW_DATA = 'SentenceDatabase.txt'

# %% [markdown]
# # POS Data Extraction

# %%
@dataclass
class DatabaseParser(ABC):
    dest: str
    seq_per_csv: int = field(default=100000)


    @cached_property
    def table_schema(self) -> pa.Schema:
        list_str_type = pa.list_(pa.string())
        table_schema = pa.schema([
            pa.field('init_words', list_str_type),
            pa.field('mod_words', list_str_type),
            pa.field('pos_tags', list_str_type)])
        return table_schema

    def __parse_word(self, line: str) -> List[str]:
        return line.split()[1:]  # discard word index

    def __read_sentence(self, database: TextIO) -> pa.Table:
        init_words = []
        mod_words = []
        pos_tags = []

        for i, line in enumerate(database):
            if line == "":
                raise EOFError
            if not line[0].isnumeric():
                break
            init_word, mod_word, pos_tag = self.__parse_word(line)
            init_words.append(init_word)
            mod_words.append(mod_word)
            pos_tags.append(pos_tag)

        return pa.Table.from_arrays([[init_words], [mod_words], [pos_tags]], schema=self.table_schema)

    def parse(self, database: TextIO) -> None:
        sentences = []
        curr: int = 0
        part: int = 1
        while True:
            try:
                curr_sent = self.__read_sentence(database)
            except EOFError:
                break
            curr += 1
            if curr == self.seq_per_csv:
                pa.concat_tables(sentences).to_pandas(types_mapper=pd.ArrowDtype).to_orc(os.path.join(self.dest, f'{PREFIX}_{part}.orc'))
                sentences = [curr_sent]
                curr = 0
                part += 1
            else:
                sentences.append(curr_sent)


        sentences.to_pandas(types_mapper=pd.ArrowDtype).to_orc(os.path.join(self.dest, f'{PREFIX}_{part}.orc'))

# %%
with open(os.path.join(DATA_FOLDER, RAW_DATA), 'r') as f:
   DatabaseParser(DATA_FOLDER, 1000000).parse(f)

# %%
NUM_PARTS = 0

for root, dirs, files in  os.walk(DATA_FOLDER):
    NUM_PARTS += len([file for file in files if file.startswith(PREFIX)])

NUM_PARTS
# Out:
# 9

# %%
def get_dataset(idx: int, prefix: str) -> pd.DataFrame:
    return pd.read_orc(os.path.join(DATA_FOLDER, f'{prefix}_{idx}.orc'))

# %% [markdown]
# # Frequency Data

# %%
from collections import Counter
def get_freq(prefix: str):
    freq = Counter()
    for idx in range(1, NUM_PARTS + 1):
        df = get_dataset(idx, prefix)
        for word in df['mod_words'].explode():
            freq[word] += 1
    return freq

# %%
freq = get_freq(PREFIX)

# %%
with open(os.path.join(DATA_FOLDER, 'vocab', 'freq.json'), 'w') as f:
    json.dump(freq, f, ensure_ascii = False)

# %%
# Freq. Score

# %%
freq_scores = []
for idx in range(1, NUM_PARTS + 1):
    df = get_dataset(idx, PREFIX)
    min_score = df.mod_words.apply(lambda l: min([freq[word] for word in l]) if len(l) > 0 else 0).quantile(0.02)
    max_score = df.mod_words.apply(lambda l: max([freq[word] for word in l]) if len(l) > 0 else 0).quantile(0.98)
    avg_score = df.mod_words.apply(lambda l: sum([freq[word] for word in l]) / len(l) if len(l) > 0 else 0).quantile(0.02)
    freq_scores.append((min_score, avg_score, max_score))

# %%
max_freq_score = min([score[2] for score in freq_scores])
max_freq_score
# Out:
# 11924561.0

# %%
min_avg_freq_score = sum([score[1] for score in freq_scores]) / len(freq_scores)
min_avg_freq_score
# Out:
# 382749.2299380481

# %%
min_freq_score = max([score[0] for score in freq_scores])
min_freq_score
# Out:
# 1.0

# %% [markdown]
# ## Clear Data

# %%
CLEARED_PREFIX = f'cleared_{PREFIX}'

# %%
rest = []
for idx in range(1, NUM_PARTS + 1):
    df = get_dataset(idx, PREFIX)
    df_mod = df[df.mod_words.apply(lambda l: min([freq[word] for word in l]) if len(l) > 0 else 0) > min_freq_score]
    df_mod = df_mod[~df_mod.pos_tags.apply(lambda l: 'Other' in set(l))]
    df_mod.to_orc(os.path.join(DATA_FOLDER, f'{CLEARED_PREFIX}_{idx}.orc'))
    rest_df = df[df.mod_words.apply(lambda l: min([freq[word] for word in l]) if len(l) > 0 else 0) <= min_freq_score]
    rest.append(rest_df)

# %%
for idx, sent in enumerate(pd.concat(rest).mod_words):
    if len(sent) < 10:
        print(" ".join(sent))
    if idx >= 200:
        break
# Out:
# მისი ზურგი ათეულობით ადამიანის მწყობრისკენაა მიქცეული .
# ფეხები ლურსმნებივით დამჭედებოდა .
# მას უნდა ეზღო ხაიმკესათვის .
# სტაშეკმაც დაიჭირა მილკას გახარებული მზერა და გაეღიმა .
# ფელდმანი ჩენსტუხოვიდან , სტაშეკ !
# ფრენისა და თავბრუხვევისაგან დაქანცულიყო .
# როხელეს საქმრო თავის ხელისმომკიდესთან ერთად გაღიმებული შემოდის .
# ჩვენი თვალები ელვარებისგან თითქოს ნაპერწკლებს ყრიან .
# სარკიდანვე , ჩემი შეძრწუნებული სახე მომჩერებია .
# როგორ ფიქრობთ ამდენი ხალხი ზღვებს ცუდი ექიმისათვის გადმოცურავდა ?
# შარვლის ტოტები დაეკარწახებინა , წელზემოთ შიშველი იყო .
# ფანდურზედაც დაამღერა და უფრო ძაან მოეწონა .
# … ეულალიას ქმარი !
# მე შენე არა ვარ .
# შლაპაზე ბუზი დამჯდარიყო , ხელი ავუქნიე .
# თქვენ საითკენღა წახვედით , შალვა ?
# შრიალ-შრიალში , ოღროჩოღროზე მივაბიჯებდი , გული მიცემდა .
# … ვხვანჩალობდით , ჰეჰ !
# რაღაც მაპეტიჟებოდი აქეთ … მე შენ გიჩვენებ !
# და ისევ ის არ მომიგო , მრავალპირიანი ?
# წარმოიდგინეთ , მიკრო-უდაბნოც კი მოიძევება .
# თვალის ერთი გადავლებით შემეძლო გამერჩია ჩინეთი არიზონისაგან .
# მაგალითად , „ ასტეროიდი 3251 ” .
# ნუ გავუბრაზდებით მათ .
# მარტო მათი ქცერით და სურნელებით უნდა დატკბე .
# იგი მე სურნელებას მაკმევდა და ცხოვრებას მინათებდა .
# აბა , დაამთქნარე .
# მერე კი ყოველთვის შეიწყნარებ .
# საყიალოდ არა მცალია .
# მათ შორის ჩამქრალ ვულკანსაც .
# ჩემი მფლობელობა სასარგებლოა ვულკანებისთვისაც და ყვავილისთვისაც .
# და მან ხელხლა აანთო ფარანი .
# ამ არმიის მოძრაობა საბალეტო დასივით იყო აწყობილი .
# მათ თავიანთი თავი ბაობაბებივით ბუმბერაზი ჰგონიათ .
# მაგრამ მათ ქათმებიცა ჰყავთ .
# რა კარგი იქნება , რომ მომიშინაურებდე !
# და ადამიანებსაც მეღარ უპოვიათ მეგობარი .
# თუ მეგობარი გსურს , მე მომიშინაურე .
# ამ დღეს ზვრებამდეც კი შემიძლია გავისეირნო .
# პატარა უფლისწული ვარდებისკენ გაემართა .
# თქვენ ჯერ არავის მოუშინაურებიხართ .
# და არც თქვენ მოგიშინაურებიათ ვინმე .
# იგი არაფრით გამოირჩეოდა ასი ათასი სხვა მელიისაგან .
# შენ ვალდებული ხარ იზრუნო იმაზე , ვინც მოიშინაურე .
# მე კი ისე ვამაყობდი ჩემი ბაობაბებით !
# შემდეგ საფეთქლები დავუნამე და წყალი შევასვი .
# ერთი ნაბიჯი გადამადგმევინე მარტოს .
# უთასმოდ კი პატარა უფლისწული პირს ვეღარ აუკრავს ბატკანს .

# %%
get_freq(CLEARED_PREFIX)
# Out:
# Counter({',': 10245863,
#          '.': 7313044,
#          'და': 3254784,
#          'რომ': 1516287,
#          '„': 1395447,
#          'არ': 1159666,
#          '“': 841077,
#          'ეს': 692591,
#          'ამ': 691970,
#          'კი': 491561,
#          'უნდა': 472451,
#          '”': 456784,
#          'თუ': 440344,
#          'მაგრამ': 414166,
#          'იყო': 407043,
#          'საქართველოს': 401173,
#          'არის': 371985,
#          ':': 344858,
#          'ის': 330532,
#          'როგორც': 315742,
#          'რომელიც': 292213,
#          'მისი': 275717,
#          'შემდეგ': 262382,
#          'რაც': 261827,
#          ')': 244192,
#          '?': 241701,
#          'წლის': 236443,
#          '(': 234999,
#          'რა': 233066,
#          'ვერ': 221531,
#          'არა': 221036,
#          'იმ': 215448,
#          'თუმცა': 209196,
#          'მათ': 206744,
#          '!': 205224,
#          'ერთი': 203486,
#          'მას': 193764,
#          'მხოლოდ': 192024,
#          'არც': 178359,
#          '…': 176778,
#          'მე': 176676,
#          'უფრო': 176238,
#          'უკვე': 174662,
#          'ჩვენ': 174502,
#          'დიდი': 170176,
#          'სხვა': 164254,
#          'ძალიან': 162327,
#          'ყველა': 158420,
#          'დღეს': 158202,
#          'შორის': 155589,
#          'კიდევ': 154902,
#          'აქვს': 151520,
#          'იქნება': 150534,
#          'შესახებ': 147631,
#          'მიერ': 146681,
#          'ჩვენი': 146131,
#          'შეიძლება': 141327,
#          'საქართველოში': 136705,
#          'რუსეთის': 136543,
#          'იგი': 131021,
#          'ახალი': 128108,
#          'ამის': 127315,
#          'როცა': 124231,
#          'დროს': 123672,
#          'მის': 119639,
#          'ასე': 118687,
#          'ან': 114930,
#          'თავის': 113214,
#          'ასეთი': 112605,
#          'გამო': 112270,
#          'ასევე': 111272,
#          'სახელმწიფო': 110884,
#          'მათი': 109561,
#          'ახლა': 109441,
#          'სწორედ': 108516,
#          'ჩემი': 107766,
#          'რამდენიმე': 106982,
#          'მაინც': 106886,
#          'ქართული': 106760,
#          'ისინი': 105187,
#          'წელს': 103882,
#          'ისე': 103023,
#          'თქმით': 102342,
#          'რადგან': 102219,
#          'მან': 102212,
#          'მეორე': 100449,
#          'ორი': 99305,
#          'მაშინ': 98704,
#          'სადაც': 96753,
#          'შემთხვევაში': 95386,
#          'ერთად': 95301,
#          'ქვეყნის': 94185,
#          'თავისი': 92981,
#          'წინ': 92823,
#          'პირველი': 90348,
#          'არიან': 90117,
#          'როგორ': 89784,
#          'განაცხადა': 89572,
#          'ჯერ': 89006,
#          'ამას': 88782,
#          'ყველაზე': 87686,
#          'იყოს': 87256,
#          'რომელსაც': 87043,
#          'რომლებიც': 86261,
#          'საერთაშორისო': 85227,
#          'პოლიტიკური': 81820,
#          'როდესაც': 80184,
#          'ხელისუფლების': 77716,
#          'ბოლო': 76807,
#          'დაკავშირებით': 75554,
#          'იქ': 73683,
#          'ყველაფერი': 73364,
#          'სულ': 72818,
#          'აღარ': 71622,
#          'იმის': 71502,
#          'ბევრი': 71090,
#          'ამიტომ': 71005,
#          ';': 70723,
#          'რომლის': 70606,
#          'თბილისის': 70433,
#          'მთელი': 70163,
#          'ხომ': 69979,
#          'აქ': 69543,
#          'სამხედრო': 68432,
#          'განმავლობაში': 67811,
#          'ხოლო': 67087,
#          'ჩვენს': 66920,
#          'კარგად': 65586,
#          'მიუხედავად': 65247,
#          'პარლამენტის': 64938,
#          'გარდა': 64477,
#          'ერთ': 64171,
#          'საქმე': 64019,
#          'მეტი': 63357,
#          'ერთ-ერთი': 62873,
#          'პრეზიდენტის': 62828,
#          'საკუთარი': 62696,
#          'გიორგი': 62643,
#          'არსებობს': 62533,
#          'მერე': 62163,
#          'ალბათ': 62036,
#          'თავად': 61101,
#          'საქმეთა': 60435,
#          'წინააღმდეგ': 60161,
#          'ვარ': 60005,
#          'ქართველი': 58321,
#          'ხელისუფლება': 58257,
#          'მთავარი': 57615,
#          'ეროვნული': 57281,
#          'თავი': 56539,
#          'ქვეყანაში': 56447,
#          'არამედ': 56356,
#          'თავს': 56233,
#          'რატომ': 55658,
#          'ჰქონდა': 55539,
#          'ისევ': 55536,
#          'ისეთი': 55324,
#          'მიმართ': 55046,
#          '"': 54670,
#          'ხდება': 54423,
#          'შეეხება': 54224,
#          'პირველ': 53975,
#          'სამინისტროს': 53802,
#          'საგარეო': 53657,
#          'სხვადასხვა': 53631,
#          'მოხდა': 53130,
#          'დაიწყო': 53014,
#          'საკმაოდ': 53006,
#          'ადამიანი': 51901,
#          'განცხადებით': 51570,
#          'საქართველო': 51083,
#          'გუშინ': 50720,
#          'თბილისში': 50628,
#          'გახდა': 49427,
#          'აფხაზეთის': 49188,
#          'დავით': 49057,
#          'ანუ': 48937,
#          'პრეზიდენტი': 48098,
#          'არაფერი': 47965,
#          'ვინც': 47561,
#          'კარგი': 47137,
#          'სამი': 47052,
#          'რომელმაც': 46854,
#          'თქმა': 46817,
#          'რათა': 45853,
#          'მსოფლიო': 45677,
#          'რას': 45393,
#          'ადამიანის': 45220,
#          'ბოლოს': 45200,
#          'აქვთ': 45032,
#          'იმას': 44416,
#          'საარჩევნო': 44405,
#          'აზრით': 44332,
#          'ვიდრე': 44118,
#          'ვინ': 43497,
#          'ცოტა': 43327,
#          'ხელი': 43198,
#          'არჩევნების': 43166,
#          'მიხეილ': 43042,
#          'საპარლამენტო': 42884,
#          'ერთხელ': 42827,
#          'საერთოდ': 42699,
#          'რასაც': 42612,
#          'ჩემს': 42477,
#          'იმიტომ': 42141,
#          'ისიც': 41987,
#          'გარეშე': 41706,
#          'ახალ': 41527,
#          '7': 41502,
#          'მიიღო': 41471,
#          'მთავრობის': 41431,
#          'ყოველთვის': 41219,
#          'ასეთ': 41171,
#          'საკითხი': 41090,
#          'არსებული': 41062,
#          'ცნობილი': 41058,
#          'თითქმის': 40784,
#          'რაღაც': 40718,
#          'შესაძლოა': 40476,
#          'მხრივ': 40470,
#          'ქართულ': 40441,
#          'ხშირად': 40086,
#          'შედეგად': 40012,
#          'აცხადებს': 39843,
#          'მარტო': 39817,
#          'ევროპის': 39606,
#          'დღის': 39536,
#          'დიდ': 39382,
#          'მხრიდან': 38846,
#          'სამხრეთ': 38674,
#          'ადრე': 38576,
#          'პრეზიდენტმა': 38325,
#          'ხალხი': 38209,
#          'ჩანს': 38160,
#          'კვლავ': 37767,
#          'საბჭოს': 37732,
#          'თითქოს': 37644,
#          'იყვნენ': 37412,
#          'გვაქვს': 37274,
#          'მინისტრის': 37225,
#          'ხელისუფლებას': 37027,
#          'ყოფილი': 36944,
#          'ამბობს': 36489,
#          'მსოფლიოს': 36363,
#          'საკუთარ': 36281,
#          'მიხედვით': 36240,
#          'ინფორმაციით': 36005,
#          'მინდა': 35992,
#          'დაცვის': 35943,
#          'ირაკლი': 35927,
#          'თქვენ': 35834,
#          'ხელს': 35686,
#          'ნაწილი': 35624,
#          'მართლაც': 35481,
#          'მეტად': 35468,
#          'ნამდვილად': 35449,
#          'ეკონომიკური': 35184,
#          'უფლება': 35123,
#          'მნიშვნელოვანი': 34956,
#          'ინფორმაცია': 34936,
#          'ნიშნავს': 34864,
#          'საჭირო': 34628,
#          'პარტიის': 34616,
#          'რუსეთი': 34417,
#          'შესაბამისად': 34336,
#          'ვიცი': 34217,
#          'ჯერჯერობით': 34193,
#          'მიმდინარე': 33948,
#          'პოლიტიკურ': 33656,
#          'განსაკუთრებით': 33511,
#          'გადაწყვეტილება': 33334,
#          'სახელმწიფოს': 33190,
#          'თაობაზე': 33132,
#          'თავდაცვის': 33098,
#          'გარკვეული': 33015,
#          'რამ': 32867,
#          'მაქვს': 32850,
#          'ათასი': 32800,
#          'დრო': 32786,
#          'ადგილი': 32785,
#          'ამასთან': 32673,
#          'ზურაბ': 32664,
#          'მაგალითად': 32557,
#          'აი': 32381,
#          'კაცი': 32349,
#          'საზოგადოების': 32337,
#          'იმისა': 31986,
#          'აღმოჩნდა': 31969,
#          'იცის': 31920,
#          'ამჟამად': 31376,
#          'ვართ': 31189,
#          'ორ': 31117,
#          'მინისტრი': 31004,
#          'საუბარი': 30947,
#          'სასამართლოს': 30900,
#          'ხალხის': 30751,
#          'არავინ': 30655,
#          'მართალია': 30653,
#          'მალე': 30641,
#          '10': 30425,
#          'პრობლემა': 30335,
#          'სერიოზული': 30325,
#          'ამერიკის': 30294,
#          'პერიოდში': 30123,
#          'აღნიშნული': 30083,
#          'ყველას': 29946,
#          'დაახლოებით': 29841,
#          'იმედი': 29799,
#          'სააკაშვილის': 29702,
#          'ოპოზიციის': 29694,
#          'ახალგაზრდა': 29490,
#          'ამისა': 29317,
#          'აღნიშნა': 29248,
#          'ტერიტორიაზე': 29159,
#          'ვერც': 29016,
#          'შეხვედრა': 29010,
#          'ქვეყანა': 29003,
#          'მოსახლეობის': 28972,
#          'გამომდინარე': 28928,
#          'შეუძლია': 28786,
#          'განცხადება': 28757,
#          'რის': 28650,
#          'პარლამენტში': 28532,
#          'აუცილებლად': 28509,
#          'რუსული': 28481,
#          'მესამე': 28478,
#          'საუკეთესო': 28353,
#          'ორივე': 28339,
#          'საბჭოთა': 28278,
#          'თანახმად': 28242,
#          'მაღალი': 28060,
#          'პროცესი': 27852,
#          'ამაზე': 27834,
#          'ვფიქრობ': 27801,
#          'მძიმე': 27678,
#          'ადგილობრივი': 27654,
#          'კონფლიქტის': 27630,
#          'კომისიის': 27610,
#          '2': 27601,
#          'თვითონ': 27558,
#          'უშიშროების': 27511,
#          'სასამართლო': 27407,
#          'ომის': 27394,
#          'ამით': 27328,
#          '5': 27274,
#          'სამწუხაროდ': 27211,
#          'თქვა': 27193,
#          'ერთმანეთს': 27143,
#          'წინაშე': 27122,
#          'წინა': 27040,
#          'უკან': 27034,
#          'პატარა': 26999,
#          'გუნდი': 26982,
#          'აპირებს': 26968,
#          'თავმჯდომარე': 26938,
#          'გუნდის': 26864,
#          'ლევან': 26857,
#          'განვითარების': 26702,
#          'ერთ-ერთ': 26684,
#          'უბრალოდ': 26676,
#          'ყოფილა': 26587,
#          'სრულიად': 26545,
#          'მიზეზი': 26542,
#          'წარმომადგენლები': 26413,
#          'თვის': 26267,
#          'წელი': 26261,
#          'საერთო': 26115,
#          'მით': 26098,
#          'სჭირდება': 26081,
#          'პოლიციის': 26074,
#          'შენ': 26017,
#          'რაიმე': 25999,
#          'იქნებოდა': 25966,
#          'წევრი': 25947,
#          'არადა': 25847,
#          'ნინო': 25790,
#          'სახალხო': 25788,
#          'გაეროს': 25774,
#          'მიზნით': 25722,
#          'თუნდაც': 25698,
#          'მცირე': 25678,
#          'საშუალება': 25622,
#          'ნაკრების': 25588,
#          'ადამიანები': 25550,
#          'თქვენი': 25468,
#          'რაიონის': 25396,
#          'თუკი': 25374,
#          'ერთადერთი': 25178,
#          'არავის': 25174,
#          'წლების': 25172,
#          'სააკაშვილი': 25099,
#          '20': 25076,
#          'ამავე': 25030,
#          'ყოველ': 25009,
#          'დღემდე': 24991,
#          'იმაზე': 24958,
#          'იგივე': 24839,
#          'დღე': 24786,
#          'მიმდინარეობს': 24719,
#          'რომელშიც': 24699,
#          'მილიონი': 24659,
#          'ხოლმე': 24652,
#          'აქედან': 24648,
#          'ხელისუფლებამ': 24634,
#          'საინტერესო': 24611,
#          'თამაში': 24589,
#          'კიდეც': 24469,
#          'ჩემთვის': 24455,
#          'ოფიციალური': 24411,
#          '15': 24234,
#          'ამიტომაც': 24110,
#          'პირველად': 24088,
#          'მომავალი': 24046,
#          'წლებში': 24038,
#          'ხალხს': 24000,
#          'ყველაფერს': 23937,
#          'მისთვის': 23897,
#          'მიღებული': 23849,
#          'ხნის': 23760,
#          'ადგილზე': 23657,
#          'ძირითადად': 23644,
#          'კომიტეტის': 23593,
#          'ეტაპზე': 23558,
#          'გააკეთა': 23555,
#          'კავშირის': 23518,
#          'ბოლომდე': 23506,
#          '1': 23415,
#          'ქვეყანას': 23345,
#          'რამდენად': 23318,
#          'კანონის': 23264,
#          'ქართველ': 23243,
#          'ამბობენ': 23228,
#          'საქმის': 23126,
#          'თანაც': 23116,
#          'ქალაქის': 23079,
#          'სისხლის': 23006,
#          'თან': 22999,
#          'სამართლის': 22910,
#          'არჩევნები': 22871,
#          'სახით': 22816,
#          'მზად': 22781,
#          'მთლიანად': 22664,
#          'სოციალური': 22656,
#          'გზა': 22508,
#          'ცხადია': 22490,
#          'იქნა': 22456,
#          'კერძოდ': 22420,
#          'მინისტრმა': 22419,
#          'უარი': 22306,
#          'მსგავსი': 22278,
#          'განათლების': 22247,
#          'თავიდან': 22141,
#          'სანამ': 22134,
#          'სად': 22092,
#          'ევროკავშირის': 22085,
#          'სახლში': 22040,
#          'აგვისტოს': 21987,
#          'სხვათა': 21961,
#          'რუსეთს': 21867,
#          '3': 21851,
#          'შეხვედრის': 21843,
#          'შინაგან': 21738,
#          '4': 21672,
#          'წინათ': 21633,
#          'ვისაც': 21568,
#          'მიიჩნევს': 21552,
#          'ძველი': 21522,
#          'სხდომაზე': 21522,
#          'რომელთა': 21454,
#          'მანძილზე': 21344,
#          'გასულ': 21301,
#          'სამოქალაქო': 21284,
#          'სამსახურის': 21158,
#          'მანამდე': 21157,
#          'მომავალში': 21125,
#          'არჩევნებში': 21125,
#          'გაცილებით': 21118,
#          '12': 21110,
#          'აფხაზეთში': 21057,
#          'მთავარია': 20985,
#          'მისივე': 20860,
#          'ძალების': 20839,
#          'ცხოვრების': 20814,
#          'გზით': 20787,
#          'პირდაპირ': 20735,
#          'პრეზიდენტს': 20710,
#          'აშშ-ის': 20658,
#          'პასუხი': 20615,
#          'ოპოზიცია': 20613,
#          '6': 20595,
#          'რუსეთში': 20578,
#          'მთელ': 20560,
#          'დარჩა': 20498,
#          'ლარი': 20476,
#          'თავისუფლების': 20360,
#          'რეგიონში': 20306,
#          'უკრაინის': 20284,
#          'გამართულ': 20281,
#          'მუშაობა': 20248,
#          '30': 20166,
#          'დეპარტამენტის': 20115,
#          'პრობლემები': 20110,
#          'ფაქტი': 20083,
#          'ოთხი': 20078,
#          'შესაბამისი': 20063,
#          'რუსი': 20062,
#          'ვთქვათ': 20059,
#          'საბოლოოდ': 20052,
#          'მთავრობა': 20012,
#          'ფარგლებში': 20009,
#          'გაიმართა': 19935,
#          'მოძრაობის': 19935,
#          'უსაფრთხოების': 19899,
#          'მხარე': 19842,
#          'გენერალური': 19821,
#          'წარმოადგენს': 19804,
#          'სოფლის': 19774,
#          'ხმა': 19749,
#          'აგრეთვე': 19730,
#          'სამშვიდობო': 19656,
#          'აზრი': 19601,
#          'რესპუბლიკის': 19587,
#          'ოსეთის': 19558,
#          'პარტია': 19545,
#          'საპრეზიდენტო': 19532,
#          'კულტურის': 19522,
#          'თავისუფალი': 19498,
#          'მდგომარეობა': 19494,
#          'თვალსაზრისით': 19489,
#          'ფული': 19479,
#          'სააკაშვილმა': 19457,
#          'სურვილი': 19448,
#          'მოსკოვში': 19419,
#          'ლიდერი': 19413,
#          'დემოკრატიული': 19405,
#          'ხელში': 19380,
#          'გია': 19366,
#          'პროექტის': 19356,
#          'სრული': 19355,
#          'ცდილობს': 19322,
#          'მონაწილეობა': 19317,
#          'ჩვენთან': 19265,
#          '9': 19261,
#          'უახლოეს': 19247,
#          'შედარებით': 19234,
#          'საზოგადოება': 19203,
#          'ფინანსური': 19189,
#          'ცხოვრება': 19173,
#          'შეერთებული': 19158,
#          'ცნობილია': 19146,
#          'მოხდება': 19132,
#          'ძლიერი': 19094,
#          'ნატოს': 19089,
#          'მიიღებს': 19047,
#          'ძირითადი': 19035,
#          'პრეზიდენტ': 18999,
#          'ვიყავი': 18991,
#          'შენი': 18977,
#          'რჩება': 18971,
#          'წევრები': 18958,
#          'სამუშაო': 18957,
#          'არასამთავრობო': 18944,
#          'ყურადღება': 18854,
#          'აცხადებენ': 18730,
#          'ურთიერთობა': 18713,
#          'სავარაუდოდ': 18706,
#          'მნიშვნელობა': 18662,
#          'ნებისმიერი': 18657,
#          'ქვეყნების': 18635,
#          'ეროვნულ': 18629,
#          'ფეხბურთის': 18591,
#          'ადამიანს': 18579,
#          'უმაღლესი': 18565,
#          'ოჯახის': 18548,
#          'რომლებსაც': 18467,
#          'შექმნა': 18455,
#          'ნაციონალური': 18421,
#          'ისევე': 18412,
#          'თვით': 18388,
#          'კახა': 18311,
#          'თანამედროვე': 18297,
#          'მასთან': 18286,
#          'სურს': 18269,
#          'იმავე': 18265,
#          'ითქვას': 18244,
#          'ფაქტობრივად': 18239,
#          'რომელიმე': 18192,
#          'დღევანდელი': 18179,
#          'თავმჯდომარის': 18100,
#          'პროექტი': 18048,
#          'შედეგი': 18037,
#          'საქმეს': 17940,
#          'ჰყავს': 17870,
#          'მნიშვნელოვანია': 17869,
#          'გასული': 17862,
#          'კონკრეტული': 17856,
#          'უნივერსიტეტის': 17853,
#          'საბოლოო': 17840,
#          'პოლიტიკის': 17825,
#          'ამჯერად': 17818,
#          'შექმნილი': 17818,
#          'მიმართულებით': 17804,
#          'თანხა': 17779,
#          'ბატონი': 17772,
#          'ამგვარი': 17753,
#          'ვეღარ': 17719,
#          'კვირის': 17717,
#          'განსაკუთრებული': 17705,
#          'პირობებში': 17651,
#          'ეკონომიკის': 17626,
#          'ჩვენთვის': 17540,
#          'ინფორმაციის': 17515,
#          'მაისს': 17513,
#          'წლიდან': 17510,
#          'სოფელ': 17488,
#          'ზუსტად': 17460,
#          'გახლდათ': 17459,
#          'ჩემპიონატის': 17459,
#          'ვინაიდან': 17421,
#          'ჯგუფი': 17397,
#          'უმეტეს': 17360,
#          'იუსტიციის': 17358,
#          'საზოგადოებრივი': 17341,
#          'დე': 17333,
#          'ფედერაციის': 17318,
#          'საქმეში': 17296,
#          'კომპანია': 17278,
#          'კანონი': 17267,
#          'ორგანიზაციის': 17261,
#          'მსოფლიოში': 17224,
#          'სპეციალური': 17195,
#          'არანაირი': 17140,
#          'დაკავშირებული': 17137,
#          'მხარეს': 17119,
#          '11': 17099,
#          'საპროტესტო': 17087,
#          'არასოდეს': 17081,
#          'სფეროში': 17080,
#          'გახდება': 17072,
#          'მხარს': 17068,
#          'ნუ': 17066,
#          'მეც': 17065,
#          'იმდენად': 17058,
#          'მოჰყვა': 17047,
#          'უამრავი': 16982,
#          'მოხდეს': 16968,
#          'ბუნებრივია': 16912,
#          'ჯგუფის': 16910,
#          '25': 16898,
#          'მათთვის': 16888,
#          'გაიმართება': 16880,
#          'მედიანიუსი': 16879,
#          'ქალი': 16859,
#          '24': 16803,
#          'მონაწილეობას': 16782,
#          'საჭიროა': 16756,
#          'დღეებში': 16746,
#          '8': 16717,
#          'შანსი': 16702,
#          'თურმე': 16616,
#          'ისეთ': 16599,
#          'სამინისტრო': 16596,
#          'მომავალ': 16595,
#          'იქნებ': 16591,
#          'პოზიცია': 16573,
#          'მოსახლეობა': 16540,
#          'ძალა': 16500,
#          'ცენტრალური': 16435,
#          'ცნობით': 16423,
#          'ბრძოლა': 16404,
#          'საფუძველზე': 16393,
#          'არსებულ': 16312,
#          'საზოგადოებას': 16308,
#          'მატჩი': 16289,
#          'მოსახლეობას': 16286,
#          'რაიონში': 16282,
#          'რადგანაც': 16252,
#          'საკანონმდებლო': 16213,
#          'ოღონდ': 16210,
#          'სისტემის': 16198,
#          'ვის': 16187,
#          'რუსეთთან': 16185,
#          'უფლებების': 16143,
#          'გოლი': 16089,
#          'ქვეშ': 16046,
#          'გუნდს': 15976,
#          'თავიანთი': 15955,
#          'რეალურად': 15936,
#          'კერძო': 15908,
#          'ხანია': 15897,
#          'ეხება': 15886,
#          'რიგში': 15865,
#          'გამოიწვია': 15815,
#          'მრავალი': 15754,
#          'მოგვიანებით': 15753,
#          'ზოგიერთი': 15724,
#          'გამოვიდა': 15694,
#          'ჰქონდათ': 15668,
#          'შეიარაღებული': 15640,
#          'მასში': 15637,
#          'ითვალისწინებს': 15593,
#          'აქამდე': 15573,
#          'ყოფილიყო': 15563,
#          'ნებისმიერ': 15559,
#          'ბანკის': 15559,
#          'მთავარ': 15533,
#          'მატჩის': 15520,
#          'ბევრ': 15501,
#          'სულაც': 15477,
#          'საკრებულოს': 15469,
#          'პირადად': 15459,
#          'ამბავი': 15455,
#          'შეხვედრაზე': 15447,
#          'დარწმუნებული': 15400,
#          'ხუთი': 15382,
#          'მუშაობს': 15379,
#          'თავზე': 15349,
#          '14': 15339,
#          'ნაცვლად': 15335,
#          'საკითხის': 15314,
#          'გული': 15302,
#          'მიდის': 15223,
#          'სიტყვა': 15210,
#          'დგას': 15208,
#          'საჯარო': 15190,
#          'ბიუჯეტის': 15189,
#          'საღამოს': 15181,
#          'რეალური': 15181,
#          'დონეზე': 15159,
#          'აუცილებელია': 15141,
#          'საკითხზე': 15093,
#          'სკოლის': 15086,
#          'ექნება': 15078,
#          'გავიდა': 15059,
#          'საინფორმაციო': 15057,
#          'საგადასახადო': 15056,
#          'ორგანიზაცია': 15055,
#          'ერთიანი': 14993,
#          'საგანგებო': 14990,
#          'როგორი': 14961,
#          'ურთიერთობის': 14951,
#          'მოითხოვს': 14903,
#          'თამაშის': 14861,
#          'სამედიცინო': 14850,
#          'პროცესში': 14819,
#          'ალექსანდრე': 14798,
#          'წარმომადგენელი': 14780,
#          'მარტს': 14778,
#          'აღსანიშნავია': 14775,
#          'აჭარის': 14770,
#          'შარშან': 14740,
#          'პირი': 14721,
#          '13': 14700,
#          'ოპოზიციური': 14662,
#          'გაზის': 14656,
#          '18': 14643,
#          'მოკლედ': 14591,
#          'ხელმძღვანელი': 14572,
#          'მოძრაობა': 14564,
#          'ნაკლებად': 14507,
#          'სახელობის': 14467,
#          'სასამართლოში': 14461,
#          'ცენტრის': 14446,
#          'პირიქით': 14427,
#          'ადამიანებს': 14413,
#          'დღესაც': 14382,
#          'აშკარად': 14373,
#          'კლუბის': 14363,
#          'დღეში': 14345,
#          'არაა': 14344,
#          'გახლავთ': 14344,
#          'მოედანზე': 14321,
#          'შიდა': 14319,
#          'მხარის': 14311,
#          'ცხინვალის': 14308,
#          'რომელთაც': 14296,
#          'სიტყვით': 14294,
#          'უფროსი': 14279,
#          'კვირაში': 14275,
#          'შესაძლებელია': 14261,
#          'დროზე': 14253,
#          'პროგრამის': 14247,
#          'უდიდესი': 14242,
#          'მქონე': 14209,
#          'ქალაქ': 14205,
#          'საკითხს': 14195,
#          '2008': 14170,
#          'მიღება': 14164,
#          'მოსკოვის': 14133,
#          'მისცა': 14130,
#          'საშუალებას': 14062,
#          'შეხვდა': 14021,
#          'ინფორმაციას': 14008,
#          'შევარდნაძის': 13996,
#          'აქტიურად': 13976,
#          'მუშაობის': 13959,
#          'უმრავლესობა': 13919,
#          'მართლა': 13903,
#          'ძალზე': 13844,
#          'შტატების': 13807,
#          'ხელისუფლებაში': 13803,
#          'ფონზე': 13800,
#          'ინტერპრესნიუსი': 13794,
#          'სპორტის': 13778,
#          '17': 13770,
#          'ხარ': 13759,
#          'დატოვა': 13716,
#          'დახმარების': 13711,
#          'მიზანი': 13696,
#          'თვეში': 13678,
#          'ვითარება': 13675,
#          'სააკაშვილს': 13671,
#          'გადაწყვეტილებას': 13665,
#          'იმისთვის': 13638,
#          'ადამიანების': 13632,
#          'უმრავლესობის': 13630,
#          'მოადგილე': 13630,
#          'გვერდით': 13628,
#          'საკითხებში': 13627,
#          'რაოდენობა': 13613,
#          'შეუძლებელია': 13607,
#          'რთული': 13592,
#          '16': 13579,
#          'პროგრამა': 13565,
#          'განუცხადა': 13553,
#          'კონტროლის': 13504,
#          'მასზე': 13501,
#          'უკანასკნელი': 13437,
#          'კვირას': 13435,
#          'აპრილს': 13425,
#          'ყოველი': 13410,
#          'სახის': 13409,
#          'შეგახსენებთ': 13407,
#          'მწვრთნელი': 13400,
#          'ფინანსთა': 13397,
#          'აქციის': 13377,
#          'სამინისტროში': 13366,
#          'დახმარება': 13354,
#          'ფეხბურთელი': 13345,
#          'მყოფი': 13344,
#          'არაფერს': 13279,
#          'ტიპის': 13257,
#          'გადაწყვეტილების': 13253,
#          'ნოემბერს': 13235,
#          'პოლიტიკა': 13214,
#          'წინასწარ': 13208,
#          'მილიონ': 13206,
#          'მისმა': 13198,
#          'ცვლილებები': 13193,
#          'დასრულდა': 13182,
#          'ყველამ': 13175,
#          'წლამდე': 13171,
#          'კავშირი': 13142,
#          '2006': 13135,
#          '26': 13116,
#          'მგონია': 13115,
#          'გამოდის': 13111,
#          'ცუდი': 13106,
#          'ბიძინა': 13105,
#          'აშშ': 13092,
#          'გააჩნია': 13053,
#          'სისტემა': 13053,
#          'სერგეი': 13051,
#          'ჰქონდეს': 13043,
#          'შეიქმნა': 13036,
#          'გარეთ': 13027,
#          'წინასწარი': 12966,
#          'დამოუკიდებელი': 12964,
#          'ვინმე': 12951,
#          'იანვარს': 12922,
#          'აქცია': 12913,
#          'გავრცელებული': 12899,
#          'ბევრს': 12889,
#          'რამე': 12888,
#          'რომლებმაც': 12882,
#          'წესით': 12872,
#          'აღნიშნულ': 12854,
#          'ივნისს': 12825,
#          'დააკავეს': 12816,
#          'აკეთებს': 12811,
#          'ირანის': 12807,
#          'პარლამენტი': 12805,
#          'შავი': 12804,
#          'ყოველივე': 12791,
#          'რადიო': 12775,
#          'უკანონო': 12774,
#          'ბრძოლის': 12771,
#          'მოდის': 12740,
#          'ომი': 12726,
#          'მოქმედი': 12704,
#          'სასამართლომ': 12699,
#          'გუნდში': 12682,
#          'ღია': 12662,
#          'გვინდა': 12659,
#          'მქონდა': 12644,
#          'ცენტრში': 12641,
#          'უფლებათა': 12641,
#          'წელია': 12631,
#          'ბუნებრივი': 12626,
#          'სამ': 12609,
#          'თორემ': 12569,
#          'საინტერესოა': 12566,
#          'შედეგები': 12563,
#          'თებერვალს': 12559,
#          'მამა': 12547,
#          'რუსეთმა': 12545,
#          'საფრანგეთის': 12540,
#          'არასდროს': 12520,
#          'პრობლემის': 12518,
#          'როგორიც': 12486,
#          'დოლარი': 12457,
#          'სიტუაცია': 12449,
#          'მთავრობას': 12431,
#          'სახელი': 12394,
#          'თბილისი': 12327,
#          'ფიქრობს': 12308,
#          'ეჭვი': 12270,
#          '2005': 12262,
#          'ცვლილებების': 12252,
#          'გერმანიის': 12242,
#          'დროის': 12204,
#          'პრაქტიკულად': 12198,
#          'აბსოლუტურად': 12195,
#          'მატჩში': 12182,
#          'საქართველოსთვის': 12175,
#          'პირადი': 12174,
#          'ამაში': 12166,
#          'სექტემბერს': 12160,
#          'დაკავებული': 12154,
#          'თურქეთის': 12137,
#          'ივლისს': 12131,
#          'გამოც': 12103,
#          'დამოკიდებული': 12102,
#          'წავიდა': 12091,
#          'აქვე': 12082,
#          'პრობლემების': 12068,
#          'შესაძლებელი': 12058,
#          'პროცესის': 12049,
#          'შესაძლებლობა': 12042,
#          'ოქროს': 12013,
#          'შემადგენლობაში': 12000,
#          'შემდგომ': 11999,
#          'დაგეგმილი': 11996,
#          'ქალაქში': 11984,
#          'თანამშრომლობის': 11973,
#          'თავმჯდომარემ': 11972,
#          'ოქტომბერს': 11966,
#          'საკონსტიტუციო': 11963,
#          'შემიძლია': 11959,
#          'წმინდა': 11941,
#          '100': 11931,
#          'რამდენი': 11920,
#          '50': 11920,
#          'ფაქტია': 11886,
#          'ნაბიჯი': 11881,
#          '22': 11880,
#          'ოფიციალურად': 11880,
#          'იმისათვის': 11878,
#          'ინსტიტუტის': 11875,
#          'იმით': 11872,
#          'მდგომარეობაში': 11870,
#          '21': 11811,
#          'შეძლო': 11809,
#          'მიიღეს': 11797,
#          'გადაწყვიტა': 11778,
#          'ნამდვილი': 11772,
#          'გამოძიება': 11752,
#          'მიმართა': 11741,
#          'ილია': 11724,
#          'როდის': 11722,
#          'იცოდა': 11710,
#          'ათას': 11709,
#          'უთხრა': 11683,
#          'იქვე': 11677,
#          'ნაკრები': 11663,
#          'სამინისტრომ': 11650,
#          'ძნელი': 11645,
#          'წუთზე': 11638,
#          'აბა': 11631,
#          '19': 11623,
#          'იდგა': 11621,
#          'იღებს': 11618,
#          'განსხვავებით': 11594,
#          'შექმნის': 11557,
#          'წესი': 11541,
#          'იწვევს': 11534,
#          'შვილი': 11509,
#          'არაერთი': 11506,
#          'გახდეს': 11505,
#          'დეკემბერს': 11504,
#          'მდგომარეობის': 11469,
#          'სახლის': 11464,
#          'დამოკიდებულება': 11461,
#          '2004': 11460,
#          'ფონდის': 11460,
#          'საქართველომ': 11459,
#          'დღევანდელ': 11431,
#          'ზონაში': 11423,
#          'ათი': 11422,
#          'ვიცით': 11399,
#          ...})

# %% [markdown]
# # Vocabulary Exctraction

# %%
def get_vocab(prefix: str):
    unique_words = set()
    for idx in range(1, NUM_PARTS + 1):
        df = get_dataset(idx, prefix)
        unique_words |= set(df['mod_words'].explode())
    return unique_words

# %%
unique_words = get_vocab(PREFIX)
len(unique_words)
# Out:
# 1836994

# %%
with open(os.path.join(DATA_FOLDER, 'vocab', 'words.json'), 'w') as f:
    json.dump(list(unique_words), f, ensure_ascii = False)

# %%
unique_words = get_vocab(CLEARED_PREFIX)
len(unique_words)
# Out:
# 904401
