# %%
import os
import pandas as pd

# %%
pron = ['ეს', 'ეგ', 'ის', 'ასეთი', 'ეგეთი', 
            'ისეთი', 'ამნაირი', 'მაგნაირი', 'იმნაირი',
            'ამისთანა', 'მაგისთანა', 'იმისთანა',
            'ამდენი', 'მაგდენი', 'იმდენი', 'თვით', 'თითოეული', 'ყოველი', 
            'ვიღაც', 'რაღაც', 'რომელიღაც', 'როგორიღაც', 'ვინმე', 'რამე', 'რომელიმე', 'როგორიმე', 
            'ზოგი', 'ზოგიერთი', 'არავინ', 'ვერავინ', 'ნურავინ', 'არაფერი', 'ვერაფერი', 'ნურაფერი', 
            'ვერა', 'ნურავინ', 'სხვები', 'სხვებიც', 'ყველამ', 'ყველას', 'სხვასაც', 'ერთის', 'ზოგს']


pron_adj = ['ყველა', 'არცერთი', 'ზოგი', 'ზოგმა', 'სხვა']
mixed_pron = ['მეორეს', 'ერთმა', 'მეორემ' ,'ორნი']

# %%
TRAIN_PATH = os.path.join('data', 'train')
TEST_PATH = os.path.join('data', 'test')

# %%
df = pd.read_orc(os.path.join(TRAIN_PATH, 'train_1.orc'), dtype_backend='pyarrow')

# %%
def get_pre_verb_adj_index(row):
    # print(row)
    words = row.mod_words
    pos_tags = row.pos_tags
    indicies = []
    for idx, (pos, word) in enumerate(zip(pos_tags, words)):
        if pos == 'V' and idx != 0 and pos_tags[idx - 1] == 'A':
            if word.endswith('-მეთქი'):
                word = word[:-6]
            if word.endswith('-თქო'):
                word = word[:-4]
            if word not in {'ვარ', 'ხარ', 'არის', 'ვართ', 'ხართ', 'არიან', 
                            'ვიყავით', 'იყავით', 'იყვნენ', 'ვიყავი', 'იყავი', 'იყო',
                            'ვიქნებოდი', 'იქნებოდი', 'იქნებოდა', 'ვიქნებოდით', 'იქნებოდით', 'იქნებოდნენ',
                            'ვიქნებოდე', 'იქნებოდე', 'იქნებოდა', 'ვიქნებოდეთ', 'იქნებოდეთ',
                            'ვიქნები', 'იქნები', 'იქნება', 'ვიქნებით', 'იქნებით',
                            'იქნება', 'ითვლება', 'იქცაო', 'იქცა', 'გადავიქეცი', 'გადაიქეცი', 'დავრჩი', 
                            'დარჩა', 'დარჩი', 'დავრჩით', 'დარჩით', 
                            'დარჩნენ'} and words[idx-1][-1] != 'ი' and words[idx-1][-1] != 'ს' and words[idx-1][:-2] != 'ია':
                indicies.append(idx - 1)
    

    return indicies

# %%
def get_pronouns(row):
    words = row.mod_words
    pos_tags = row.pos_tags
    indicies = []
    for idx, (pos, word) in enumerate(zip(pos_tags, words)):
        if word.endswith('-მეთქი'):
            word = word[:-6]
        if word.endswith('-თქო'):
            word = word[:-4]
        if word in pron:
            indicies.append(idx)
        if ((len(pos_tags) != idx + 1) and pos_tags[idx+1] not in ('N', 'A')) and word in pron_adj:
            indicies.append(idx)
        if (len(pos_tags) != idx + 1) and words[idx+1] != 'მხრივ' and (pos_tags[idx+1] not in ('N', 'A') or words[idx+1][-1] == 'ი') and word in mixed_pron:
            indicies.append(idx)
    return indicies

# %%
adj = df.apply(get_pre_verb_adj_index, axis=1)
pron = df.apply(get_pronouns, axis=1)

adj, pron
# Out:
# (0         []
#  1         []
#  2         []
#  3         []
#  4         []
#            ..
#  669512    []
#  669513    []
#  669514    []
#  669515    []
#  669516    []
#  Length: 669517, dtype: object,
#  0         [2]
#  1          []
#  2          []
#  3          []
#  4          []
#           ...
#  669512     []
#  669513     []
#  669514     []
#  669515    [7]
#  669516     []
#  Length: 669517, dtype: object)

# %%
df['inc_adj'] = adj
df['inc_pron'] = pron

# %%
df[df['inc_pron'].apply(lambda l: len(l) != 0)][['mod_words', 'pos_tags', 'inc_pron']].head(60)
# Out:
#                                              mod_words  \
# 0    ['არის' 'ამაში' 'რაღაც' 'ძლევამოსილი' 'და' 'ამ...
# 5    ['სწორედ' 'ეს' 'იქნებოდა' 'დაუნდობლობა' 'საკუთ...
# 12   ['ეკონომიკიდან' 'რამე' 'სერიოზული' ',' 'რაც' '...
# 16   ['ის' 'უარზეა' ',' 'ამბობს' 'არ' 'დამიფიცნია' ...
# 20   ['ხო' ',' 'მე' 'ალბათ' 'ჩემი' 'მისია' 'ამოვწურ...
# 21   ['ეს' 'ხომ' 'დიდი' 'განსხვავებაა' ',' 'კოპერფი...
# 37   ['სხვა' 'საფეხური' 'იყო' 'მწარმოებლისთვის' 'პო...
# 38   ['ეს' 'ერთადერთია' ',' 'რასაც' 'ყოველთვისა' 'ა...
# 39   ['მხოლოდ' 'განგებ' 'და' 'ისე' 'თითქოს' 'დაუდევ...
# 40   ['(' '7' ')' ',' '259' 'ანუ' ':' 'ვინ' 'ყოფილა...
# 57   ['ეს' 'ერთხელ' 'კიდევ' 'მიუთითებს' 'იმაზე' ','...
# 65   ['შესაძლოა' ',' 'ეს' 'იყოს' 'პირველშობილთა' '(...
# 72   ['მაშ' 'მზად' 'იყავი' 'გადმოხვიდე' 'ჩემთან' 'ე...
# 80   ['ეს' 'ნიშნავს' ',' 'რომ' '„' 'ცდა' 'ჩვენი' 'ც...
# 82   ['630' 'ის' 'კი' ',' 'ვით' 'ლომი' ',' 'თავს' '...
# 85   ['სიყვარულიც' 'ხომ' 'სიკვდილია' ',' 'ოღონდ' 'ს...
# 87   ['798' 'ქვრივი' 'რა' 'დაჯდეს' ',' 'მოთქმასა' '...
# 88   ['მაგრამ' 'ახლა' ',' 'ბატონო' 'ნათლიმამა' ',' ...
# 96   ['სარისკოა' 'დავუშვათ' 'ის' 'აზრი' ',' 'რომ' '...
# 99   ['ეს' 'უნდოდა' 'ეპასუხნა' 'უტას' ',' 'მაბრამ' ...
# 100  ['რაკი' 'საჭირო' 'იყო' ',' 'თვითონვე' 'თქვა' '...
# 103  ['დედამ' 'კარგად' 'იცოდა' 'ეს' ',' 'გაგზავნა' ...
# 104  ['ხევის' 'ქალაქო' ',' 'ასე' 'ეშხით' 'ვინ' 'დაგ...
# 115  ['„' 'რამდენიმე' 'ბიზნესმენი' 'იძულებული' 'გახ...
# 117  ['ისინიც' 'გაბრუნდნენ' 'შერცხვენილნი' 'და' 'თა...
# 123  ['მზის' 'მხარეს' ',' 'თოვლშემდნარ' 'სახურავებზ...
# 124  ['თავად' 'ეს' 'პროფესიები' 'პატივსაცემია' ',' ...
# 139  ['ხოლო' 'რაც' 'შეეხება' 'პიკასოს' 'და' 'მაზალო...
# 148  ['ეს' 'თავიდანვე' 'აქცენტირებულია' 'ავტორის' '...
# 163  ['ამ' 'თვალსაზრისით' ',' 'ნიშანდობლივია' ',' '...
# 164  ['გასათვალისწინებელია' 'ისიც' ',' 'რომ' 'ეს' '...
# 177  ['ეს' 'სავარაუდოდ' 'თვის' 'ბოლომდე' 'მოხდება' ...
# 178  ['ეს' 'დათა' 'აუცილებელი' 'არ' 'არის' ',' 'თუთ...
# 179              ['…' 'ასე' 'ჩამოეთხოვე' 'ყველას' '?']
# 187  ['მე' 'თვითონ' 'ვფიქრობდი' 'შესვლას' 'აქ' 'ერთ...
# 188  ['იმიტომ' ',' 'რომ' 'ბავშვობიდანვე' 'გემზე' 'ვ...
# 203  ['ცხადია' ',' 'რომ' 'პოეტიკა' 'არც' 'ისე' 'სწრ...
# 205               ['მართა' ':' 'არაფერი' 'მესმის' '.']
# 209  ['აკრედიტაციის' 'სისტემის' 'სიძლიერე' 'ისაა' '...
# 217  ['ის' 'ორი' 'კვირა' 'საშინლად' 'ვიყავი' ',' 'ს...
# 222  ['ისეთი' 'რამე' ',' 'რასაც' 'უარყოფ' 'და' 'აზრ...
# 228  ['თუმცა' ',' 'ალასანიამ' 'განაცხადა' ',' 'რომ'...
# 230  ['ყურაშვილის' 'განცხადებას' ',' 'ეს' 'იყო' 'სრ...
# 237  ['„' 'მუშაობა' 'დაიწყე' '”' ',' 'ჩამჩიჩინებდა'...
# 249  ['თქვენვე' 'შიგ' 'ჩართვით' 'წაიკითხეთ' 'და' 'მ...
# 254  ['ასეთი' 'გულკეთილნი' 'ხართ' 'თქვენ' 'და' 'გვა...
# 265  ['ოფიციალურმა' 'პირებმა' 'რამოდენიმე' 'ისეთი' ...
# 271  ['მაკეტი' ':' 'წა' ',' 'აილანძე' 'ეგ' 'პირისახ...
# 290           ['ამაში' 'ვერავინ' 'გადამარწმუნებს' '.']
# 295  ['ამით' 'ყველაფერი' 'დამთავრდა' '(' 'ეს' 'ამბა...
# 297  ['16' 'სრას' 'უხდებოდა' 'ხელმწიფე' 'თაჯითურთ' ...
# 303  ['ერთ' 'დღეს' 'თუ' 'გაფანტე' 'ფიქრები' ',' 'ზო...
# 305  ['არ' 'იციან' 'რა' 'ქნან' 'ზოგი' 'იარაღს' 'ესვ...
# 307  ['მეფის' 'ასულიც' '…' 'მშვენიერი' ',' 'თვით' '...
# 314  ['მე' 'არაფერს' 'არ' 'გადავიხდიდი' ',' 'რადგან...
# 316  ['მრევლს' 'რომ' 'ერთს' 'უქადაგებთ' ',' 'თვითონ...
# 323  ['არსებობს' 'წესდება' 'და' 'ფორმალური' 'ლოგიკა...
# 334  ['ის' 'მეორე' 'ოპოზიციონერი' 'პოლიტიკოსია' 'ზუ...
# 337  ['ედპ' 'ჯერ' 'კიდევ' 'გასულ' 'წელს' 'აქტიურ' '...
# 343  ['ამისთანა' 'ხალხს' 'უგულოდ' 'გაუწვდიდა' 'ხელს...
#
#                                               pos_tags     inc_pron
# 0             ['V' 'Pron' 'Pron' 'A' 'Cj' 'A' 'Punct']          [2]
# 5               ['Adv' 'Pron' 'V' 'N' 'A' 'N' 'Punct']          [1]
# 12   ['N' 'A' 'A' 'Punct' 'Cj' 'N' 'V' 'V' 'Punct' ...      [1, 11]
# 16   ['Pron' 'N' 'Punct' 'V' 'Adv' 'V' 'A' 'Cj' 'Ad...          [0]
# 20   ['Adv' 'Punct' 'Pron' 'Adv' 'Pron' 'N' 'V' 'Ad...         [15]
# 21          ['Pron' 'Adv' 'A' 'N' 'Punct' 'N' 'Punct']          [0]
# 37   ['A' 'N' 'V' 'A' 'A' 'N' 'Cj' 'A' 'A' 'N' 'Pun...          [0]
# 38   ['Pron' 'A' 'Punct' 'Pron' 'Adv' 'V' 'N' 'Punc...          [0]
# 39   ['Adv' 'Adv' 'Cj' 'Adv' 'Adv' 'A' 'Punct' 'V' ...         [18]
# 40   ['Punct' 'Num' 'Punct' 'Punct' 'Num' 'Cj' 'Pun...         [10]
# 57   ['Pron' 'Adv' 'Adv' 'V' 'Pron' 'Punct' 'Cj' 'N...          [0]
# 65   ['A' 'Punct' 'Pron' 'V' 'N' 'Punct' 'A' 'Punct...          [2]
# 72   ['Adv' 'A' 'V' 'V' 'Pron' 'N' 'N' 'Cj' 'Adv' '...         [13]
# 80   ['Pron' 'V' 'Punct' 'Cj' 'Punct' 'N' 'Pron' 'N...          [0]
# 82   ['Num' 'Pron' 'Adv' 'Punct' 'Cj' 'N' 'Punct' '...          [1]
# 85   ['N' 'Adv' 'N' 'Punct' 'Cj' 'A' 'Punct' 'Adv' ...          [8]
# 87   ['Num' 'N' 'Pron' 'V' 'Punct' 'N' 'V' 'N' 'Pun...          [9]
# 88   ['Cj' 'Adv' 'Punct' 'N' 'N' 'Punct' 'A' 'N' 'N...          [6]
# 96   ['A' 'V' 'Pron' 'N' 'Punct' 'Cj' 'A' 'Punct' '...          [2]
# 99   ['Pron' 'V' 'V' 'N' 'Punct' 'N' 'Pp' 'Pron' 'V...          [0]
# 100  ['Cj' 'A' 'V' 'Punct' 'Adv' 'V' 'N' 'N' 'A' 'P...     [19, 24]
# 103  ['N' 'A' 'V' 'Pron' 'Punct' 'N' 'N' 'N' 'V' 'N...          [3]
# 104  ['N' 'N' 'Punct' 'Adv' 'N' 'Pron' 'V' 'Punct' ...         [10]
# 115  ['Punct' 'A' 'N' 'A' 'N' 'Pron' 'A' 'N' 'Punct...         [17]
# 117  ['Pron' 'V' 'A' 'Cj' 'A' 'Punct' 'V' 'Cj' 'V' ...         [11]
# 123  ['N' 'N' 'Punct' 'N' 'N' 'Punct' 'A' 'V' 'Adv'...         [21]
# 124  ['Adv' 'Pron' 'N' 'A' 'Punct' 'Cj' 'Pron' 'N' ...          [1]
# 139  ['Cj' 'Pron' 'V' 'N' 'Cj' 'A' 'Punct' 'Pron' '...          [7]
# 148  ['Pron' 'Adv' 'A' 'N' 'Pp' 'Punct' 'N' 'Num' '...       [0, 8]
# 163  ['Pron' 'N' 'Punct' 'A' 'Punct' 'Cj' 'Punct' '...         [15]
# 164  ['A' 'Pron' 'Punct' 'Cj' 'Pron' 'N' 'A' 'Punct...          [4]
# 177                   ['Pron' 'A' 'A' 'A' 'V' 'Punct']          [0]
# 178  ['Pron' 'N' 'A' 'Adv' 'V' 'Punct' 'N' 'V' 'Pun...          [0]
# 179                    ['Punct' 'Adv' 'V' 'A' 'Punct']          [3]
# 187  ['Pron' 'Adv' 'V' 'N' 'Adv' 'Num' 'N' 'Punct' ...          [1]
# 188  ['Adv' 'Punct' 'Cj' 'N' 'N' 'V' 'Punct' 'N' 'C...         [10]
# 203  ['A' 'Punct' 'Cj' 'N' 'Adv' 'Adv' 'A' 'V' 'Pun...         [14]
# 205                   ['V' 'Punct' 'Pron' 'V' 'Punct']          [2]
# 209  ['N' 'N' 'N' 'Pron' 'Punct' 'Cj' 'Pron' 'Adv' ...          [6]
# 217  ['Pron' 'Num' 'N' 'A' 'V' 'Punct' 'Adv' 'V' 'C...          [0]
# 222  ['Pron' 'Pron' 'Punct' 'Pron' 'V' 'Cj' 'N' 'Ad...       [0, 1]
# 228  ['Adv' 'Punct' 'N' 'V' 'Punct' 'Cj' 'N' 'Pron'...          [7]
# 230       ['N' 'N' 'Punct' 'Pron' 'V' 'A' 'N' 'Punct']          [3]
# 237  ['Punct' 'N' 'V' 'Punct' 'Punct' 'V' 'A' 'Punct']          [6]
# 249  ['Pron' 'Adv' 'N' 'V' 'Cj' 'Adv' 'Adv' 'A' 'V'...          [9]
# 254  ['Pron' 'A' 'V' 'Pron' 'Cj' 'V' 'Punct' 'Cj' '...          [0]
# 265  ['A' 'N' 'A' 'Pron' 'N' 'V' 'Punct' 'Pron' 'A'...          [3]
# 271  ['N' 'Punct' 'V' 'Punct' 'V' 'Pron' 'N' 'Punct...          [5]
# 290                        ['Pron' 'Pron' 'V' 'Punct']          [1]
# 295  ['Adv' 'A' 'V' 'Punct' 'Pron' 'N' 'Pron' 'Pron...          [4]
# 297  ['Num' 'N' 'V' 'N' 'N' 'N' 'Punct' 'Adv' 'N' '...          [7]
# 303  ['Num' 'N' 'Cj' 'V' 'N' 'Punct' 'A' 'N' 'Punct...       [6, 9]
# 305  ['Adv' 'V' 'Pron' 'V' 'N' 'N' 'V' 'N' 'N' 'Adv...    [4, 8, 8]
# 307  ['N' 'N' 'Punct' 'N' 'Punct' 'Adv' 'N' 'Punct'...          [5]
# 314  ['Pron' 'A' 'Adv' 'V' 'Punct' 'Cj' 'A' 'Pron' ...          [7]
# 316  ['N' 'Cj' 'Num' 'V' 'Punct' 'Adv' 'A' 'N' 'V' ...       [5, 6]
# 323  ['V' 'N' 'Cj' 'A' 'N' 'V' 'Punct' 'Cj' 'Adv' '...         [14]
# 334  ['Pron' 'Num' 'N' 'N' 'N' 'N' 'Pp' 'Punct' 'Pr...          [0]
# 337  ['N' 'Adv' 'Adv' 'A' 'N' 'A' 'N' 'V' 'Punct' '...         [18]
# 343  ['Pron' 'N' 'A' 'V' 'N' 'Punct' 'Num' 'A' 'V' ...  [0, 11, 12]

# %%
def get_adv_v(row):
    words = row.mod_words
    indicies = row.inc_adj
    pairs = []
    for idx in indicies:
        pairs.append((words[idx], words[idx + 1]))
    return pairs

# %%
df['pairs'] = df.apply(get_adv_v, axis=1)

# %%
# df[df['pairs'].apply(lambda l: len(l) != 0)]['pairs'].tolist()
