# %%
from dataclasses import dataclass, field
from typing import List, Any, Dict, Set
from collections import Counter
from abc import ABC
import pprint
import re
import os
pp = pprint.PrettyPrinter(indent=4)

# %%
@dataclass
class Word:
    word_init: str
    word_mod: str
    lemma_basic: Counter = field(default_factory=Counter)
    lemma_adv: Counter = field(default_factory=Counter)
    pos_tags: Counter = field(default_factory=Counter)
    freq: int = field(default=1)
    


def join_words(word1: Word, word2: Word) -> Word:
    return Word(word1.word_init, word1.word_mod,
                word1.lemma_basic + word2.lemma_basic, 
                word1.lemma_adv + word2.lemma_adv,
                word1.pos_tags + word2.pos_tags,
                word1.freq + word2.freq
                )
    
@dataclass
class WordDict(ABC):
    dictionary: Dict[str, Word] = field(default_factory=dict)
    
    def add(self, word: Word):
        if word.word_mod in self.dictionary:
            self.dictionary[word.word_mod] = join_words(word, self.dictionary[word.word_mod])
        else:
            self.dictionary[word.word_mod] = word
    
    def save(self, path: str) -> None:
        pass
    
class CSVWordDict(WordDict):
    header = ["word" ,'lemma', 'pos_tag', 'freq']
    def save(self, path: str) -> None:
        with open(path,'w', encoding='UTF8') as f:
            writer = csv.writer(f)
            writer.writerow(self.header)
            for _, word in self.dictionary.items():
                writer.writerow([word.word_mod, word.lemma_basic.most_common(1)[0][0], word.pos_tags.most_common(1)[0][0], word.freq])

# %%
DOC_TAG = 'document'
TEXT_TAG = 'text'
DIV_TAG = 'div'
PARAGRAPH_TAG = 'p'


WORD_PATTERN = re.compile(r'(?P<word_forms>.+?)¦(?P<lemma1>.*?)¦?'
                               r'.*?¦(?P<lemma2>.*?)¦.*?¦(?P<pos_tags>.+?)¦\s*(?P<title>.+)', re.DOTALL)
START_TAG_PATTERN = re.compile(r'<(?P<tag>\w+)(?P<attributes>(\s*?\w+?=.+?)*)>\s+(?P<title>.+)', 	re.DOTALL)
END_TAG_PATTERN = re.compile(r'<(/?(?P<tag>\w+)/?)>\s+(?P<title>.+)', 	re.DOTALL)

@dataclass
class CorpusParser:
    dict_: WordDict = field(default_factory=CSVWordDict)
    tag_stack: List[str] = field(default_factory=list)
    
    def handle_starttag(self, match: re.Match) -> None:
        tag = match.groupdict()['tag']
        self.tag_stack.append(tag)  # add tag on top of the stack, marking start of the tag
                
    def handle_endtag(self, match: re.Match) -> None:
        tag = match.groupdict()['tag']
        try:
            self.tag_stack.pop()  ## remove tag from the top of the stack, marking end of the tag
        except Exception:
            print(tag, match.group())
            
    def handle_parts(self, parts: List[str]):
        # title = "".join(parts[-1].strip().split())
        word_forms = parts[0]
        word_forms = word_forms.split()
        init_form = " ".join(word_forms[:len(word_forms) // 2 ])
        ext_form = " ".join(word_forms[len(word_forms) // 2: ])
        pos_tags = Counter(parts[-2].split())
        lemma_basic = Counter([parts[1]])
        lemma_adv = Counter(parts[3].split())
        word = Word(init_form, ext_form, lemma_basic, lemma_adv, pos_tags)
        self.dict_.add(word)

    def handle_word(self, line: str):
        curr_tag = self.tag_stack[-1]
        if curr_tag == PARAGRAPH_TAG or curr_tag == DIV_TAG:
            parts = line.split('¦')
            self.handle_parts(parts)
        # parts = line.split('¦')
        # self.handle_parts(parts)
            
    def finish_dict(self) -> WordDict:
        return self.dict_
            
    def feed(self, line: str) -> None:
        open_tag_match = START_TAG_PATTERN.match(line)
        closed_tag_match = END_TAG_PATTERN.match(line)
        if open_tag_match is not None:
            self.handle_starttag(open_tag_match)
        elif closed_tag_match is not None:
            self.handle_endtag(closed_tag_match)
        else:
            self.handle_word(line)

# %%
CSV_FILES_PATh = r'csv/'
PART_FILE_ROOT = r'parts/'

parser = CorpusParser()


source = "grc-cwb"
# source = 'parts/part9.txt'
dest = os.path.join(CSV_FILES_PATh, f"adv_dict2.csv")
print(source)
with open(source, "r") as f:
    for number, line in enumerate(f):
        parser.feed(line)
    parser.finish_dict().save(dest)
# Out:
# grc-cwb
# document </document>					lib.ge	იოსიფ ბროდსკი	განვავრცობ პლატონს
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# text </text>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# document </document>					lib.ge	ბესო ხვედელიძე	მინდვრის ყვავილები
#
# div </div>					lib.ge	ბესო ხვედელიძე	ჯადო
#
# div </div>					lib.ge	ბესო ხვედელიძე	ჯადო
#
# div </div>					lib.ge	ბესო ხვედელიძე	ჯადო
#
# text </text>					lib.ge	ბესო ხვედელიძე	ჯადო
#
# document </document>					lib.ge	ბესო ხვედელიძე	ჯადო
#
# document </document>					lib.ge	ლაშა ბუღაძე	NIL
#
# div </div>					lib.ge	ბესო ხვედელიძე	წყევლა
#
# text </text>					lib.ge	ბესო ხვედელიძე	წყევლა
#
# document </document>					lib.ge	ბესო ხვედელიძე	წყევლა
#
# document </document>					civil.ge			2001-12-05
#
# document </document>					civil.ge			2001-12-05
#
# document </document>					civil.ge			2001-12-06
#
# document </document>					civil.ge			2001-12-06
#
# document </document>					civil.ge			2001-12-06
#
# document </document>					civil.ge			2001-12-06
#
# document </document>					civil.ge			2001-12-07
#
# document </document>					civil.ge			2001-12-07
#
# document </document>					civil.ge			2001-12-07
#
# document </document>					civil.ge			2001-12-07
#
# document </document>					civil.ge			2001-12-08
#
# document </document>					civil.ge			2001-12-08
#
# document </document>					civil.ge			2001-12-10
#
# document </document>					civil.ge			2003-12-29
#
# document </document>					tavisupleba.org	ნინო გელაშვილი		2003-06-26
#
# document </document>					tavisupleba.org	ზაზა გაჩეჩილაძე, თბილისი		2004-12-23
#
# document </document>					tavisupleba.org	ზაზა გაჩეჩილაძე, თბილისი		2004-12-25
#
# document </document>					tavisupleba.org			2006-11-24
#
# document </document>					tavisupleba.org			2006-12-28
#
# document </document>					tavisupleba.org	ნიკო ნერგაძე		2008-04-12
#
# document </document>					tavisupleba.org			2008-06-15
#
# document </document>					tavisupleba.org			2009-01-20
#
# document </document>					tavisupleba.org		დედა ცეცილია (მსხილაძე), მონაზონი	2011-05-01
#
# document </document>					tavisupleba.org	ოქროპირ რუხაძე	რადიო თავისუფალი ევროპა / რადიო თავისუფლება ახალსახლობას აღნიშნავს	2009-05-12
#
# document </document>					tavisupleba.org	ეკა ქევანიშვილი	სიზმარი დედაზე, ანუ ერთი დღე წყნეთის ბავშვთა სახლში	2009-05-31
#
# document </document>					tavisupleba.org	ნონა მჭედლიშვილი	ავიაკატასტროფას საქართველოს ორი მოქალაქე შეეწირა	2009-07-15
#
# document </document>					tavisupleba.org	კახა მჭედლიძე	როგორ მიმდინარეობს რთველი საქართველოში	2009-09-16
#
# document </document>					tavisupleba.org	კახა მჭედლიძე	თბილისი „თბილისობას” 30–ედ აღნიშნავს	2009-10-24
#
# document </document>					tavisupleba.org		ფოტოკონკურსის შედეგები	2009-10-25
#
# document </document>					tavisupleba.org	მალხაზ ხარბედია	ალტერნატიული ტფილისის ტექსტი	2009-12-15
#
# document </document>					tavisupleba.org	გოგა აფციაური	კარალეთელი დევნილები ახალ წელს ახალ კოტეჯებში ვალით ხვდებიან	2009-12-31
#
# document </document>					tavisupleba.org	მაია იველაშვილი	საქართველო დაღუპულ სპორტსმენს გლოვობს	2010-02-17
#
# document </document>					tavisupleba.org	ნინო თარხნიშვილი	იქნებ აღარ იწვიმოს…	2010-03-16
#
# document </document>					tavisupleba.org	მარიამ ჭიაურელი	მედვედევის სრულფასოვანი პარტნიორი	2010-05-18
#
# document </document>					tavisupleba.org	ნინო თარხნიშვილი	რას მოგვიტანს 30 მაისის არჩევნები?	2010-05-30
#
# document </document>					tavisupleba.org	გიორგი გვახარია	„არ წამიკითხავს, მაგრამ ვგმობ”	2010-07-16
#
# document </document>					tavisupleba.org	ეკა ქევანიშვილი	დევნილებს ისნის სამხედრო ჰოსპიტალიც დაატოვებინეს	2010-08-13
#
# document </document>					tavisupleba.org	ნინო თარხნიშვილი	თბილისში განახლდა დევნილების გამოსახლების პროცესი	2011-01-20
#
# document </document>					tavisupleba.org	სალომე ასათიანი	ვაშაძე: „არ მესმის, რა კავშირი აქვს იდეალიზმს საგარეო პოლიტიკასთან”	2011-02-24
#
# document </document>					tavisupleba.org		თემურ პეშკოვი – ექიმი	2011-02-27
#
# document </document>					tavisupleba.org		მაია ქურციკიძე – UNICEF-ის პროგრამის ხელმძღვანელი	2011-03-06
#
# document </document>					tavisupleba.org	ლაშა ბუღაძე	მუსიკა, რომელსაც დიქტატორები განურისხებია	2011-03-09
#
# document </document>					tavisupleba.org		საბინა ალიევა – უფლებადამცველი	2011-03-13
#
# document </document>					tavisupleba.org	თეა აბსარიძე	„საბავშვო ბაღიდან ვიცოდი, რომ მეზღვაური გავხდებოდი”	2011-03-24
#
# document </document>					tavisupleba.org		ანა გაბრიაძე – მხატვარი	2011-05-08
#
# document </document>					tavisupleba.org	დავით კაკაბაძე	დისკუსია „ამერიკის პროგრესის ცენტრის” ანგარიშზე	2011-05-13
#
# document </document>					tavisupleba.org		ზურაბ ჭუმბურიძე – ფილოლოგი	2011-05-15
#
# document </document>					tavisupleba.org	სალომე ასათიანი	ქუჩის პოეტი კარის პოეტების ნადიმზე	2011-05-20
#
# document </document>					tavisupleba.org		ლევან ვეფხვაძე – პარლამენტის დეპუტატი	2011-03-27
#
# document </document>					tavisupleba.org		ნინო ჟვანია – ლიტერატურული კაფეების ქსელის დამფუძნებელი	2011-04-03
#
# document </document>					tavisupleba.org	დავით ჩაგანავა	ბორის კაგარლიცკი: „კაპიტალიზმმა საკუთარი თავი ამოწურა”	2011-04-07
#
# document </document>					tavisupleba.org		თამარ ჩუგოშვილი – იურისტი	2011-04-10
#
# document </document>					tavisupleba.org		12 წუთი თორმეტზე	2015-12-15
#
# document </document>					ახალი თაობა			2000
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი თაობა			2008
#
# document </document>					ახალი 7 დღე			2003
#
# document </document>					ახალი 7 დღე			2003
#
# document </document>					ახალი 7 დღე			2003
#
# document </document>					ახალი ივერია			2002
#
# document </document>					საქართველო			2003
#
# document </document>					საქართველოს რესპუბლიკა			2007
#
# document </document>					სარბიელი			2006
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# ...
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					სარბიელი			2008
#
# document </document>					მწერალი			2002
#
# document </document>					საქართველოს რესპუბლიკა		მოგვმართავენ, გვეკითხებიან	2009-02-18
#
# document </document>					საქართველოს რესპუბლიკა		ხოჭო-ნათურა	2010-04-27
#
# document </document>					საქართველოს რესპუბლიკა		მოგებით დაიწყეს	2010-04-09
#
# document </document>					საქართველოს რესპუბლიკა		ორთაბრძოლა პიტონთან	2010-05-07
#
# text </text>					ლელო		მენთეშაშვილის პირველი ებრაული	2010-05-13
#
# document </document>					ლელო		მენთეშაშვილის პირველი ებრაული	2010-05-13
#
# document </document>					საქართველოს რესპუბლიკა	ლევან ჭითანავა		2010-05-19
#
# document </document>					საქართველოს რესპუბლიკა			2010-05-22
#
# text </text>					საქართველოს რესპუბლიკა		გაზეთის შემდეგი ნომერი გამოვა შაბათს, 14 აგვისტოს	2010-08-12
#
# document </document>					საქართველოს რესპუბლიკა		გაზეთის შემდეგი ნომერი გამოვა შაბათს, 14 აგვისტოს	2010-08-12
#
# document </document>					საქართველოს რესპუბლიკა			2010-09-30
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					შირაქი			2010-10-20
#
# document </document>					საქართველოს რესპუბლიკა		სამძიმარი: ანდრო ზოდელავა	2010-12-18
#
# document </document>					საქართველოს რესპუბლიკა		სამძიმარი: ანდრო ზოდელავა	2010-12-18
#
# document </document>					საქართველოს რესპუბლიკა			2012-12-19
#
# document </document>					საქართველოს რესპუბლიკა			2013-04-17
#
# document </document>					საქართველოს რესპუბლიკა			2013-08-08
#
# document </document>					საქართველოს რესპუბლიკა			2014-03-20
#
# document </document>					საქართველოს რესპუბლიკა			2014-06-25
