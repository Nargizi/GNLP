# %%
import pandas as pd
import numpy as np
import torch
# import torch.nn as nn
# import torchtext
# from torchtext.vocab import build_vocab_from_iterator
# import itertools

# %%
data = pd.read_csv('csv/train.csv')
data

# %%
from collections import defaultdict
import re
def get_pairs(vocab):
    pairs = defaultdict(int)
    for word, freq in vocab.items():
        symbols = word.split()
        for i in range(len(symbols) - 1):
            pairs[symbols[i], symbols[i + 1]] += freq
    return pairs

def merge_pairs(pair, v_in):
    v_out = {}
    bigram = re.escape(' '.join(pair))
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

def get_vocab(data):
    vocab = defaultdict(int)
    for word, freq in data:
        vocab[' '.join(list(word)) + ' </w>'] += freq
    return vocab

def byte_pair_encoding(data, n):
    vocab = get_vocab(data)
    for i in range(n):
        pairs = get_pairs(vocab)
        best = max(pairs, key=pairs.get)
        print(best)
        vocab = merge_pairs(best, vocab)
        # print(list(vocab.items())[:5])
    return set([ngram for word in vocab.keys() for ngram in word.split()])

# %%
# Byte-Pair Encoding
freqs = data[['word','freq']]
vocab = byte_pair_encoding([(pair[0], pair[1]) for pair in freqs.values.tolist()], 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Byte-Pair Encoding
#       2 freqs = data[['word','freq']]
# ----> 3 vocab = byte_pair_encoding([(pair[0], pair[1]) for pair in freqs.values.tolist()], 100)
#
# Cell In[18], line 27, in byte_pair_encoding(data, n)
#      26 def byte_pair_encoding(data, n):
# ---> 27     vocab = get_vocab(data)
#      28     for i in range(n):
#      29         pairs = get_pairs(vocab)
#
# Cell In[18], line 23, in get_vocab(data)
#      21 vocab = defaultdict(int)
#      22 for word, freq in data:
# ---> 23     vocab[' '.join(list(word)) + ' </w>'] += freq
#      24 return vocab
#
# KeyboardInterrupt:

# %%
freqs.values.tolist()
# Out:
# [['მონოზონისა', 1],
#  ['სამხრეთიდგან', 1],
#  ['მოფიქრებაშია', 1],
#  ['სიდიადეს', 209],
#  ['განგსტერებისათვის', 2],
#  ['დრამაა-მეთქი', 1],
#  ['ფურცელზეა', 22],
#  ['გამინისტრებისას', 3],
#  ['ნანობა', 1],
#  ['მახუნჯია', 1],
#  ['მხცოვანია', 6],
#  ['უქადიდნენ', 1],
#  ['ლაშქარაშვილები', 2],
#  ['სდეს', 1],
#  ['განივში', 3],
#  ['ლასკალას', 12],
#  ['დარაშვილთან', 1],
#  ['მიდრეკილებასა', 5],
#  ['აღაღანდა', 5],
#  ['გირბოდა', 1],
#  ['ხილაბანდები', 3],
#  ['შეიტანთ', 74],
#  ['არა-იმიგრაციის', 1],
#  ['დავეთანხმე', 286],
#  ['საზოგადოებრივად', 267],
#  ['ქურუმების', 44],
#  ['ვულკანზე', 12],
#  ['გამოგეწვია', 1],
#  ['შფოთი', 273],
#  ['დაითხოვა', 882],
#  ['გასასყიდი', 9],
#  ['დასანახადაც', 18],
#  ['ლამაზო-მეთქი', 1],
#  ['დავესხმებიო', 2],
#  ['გამოკრულიო', 1],
#  ['იეღოველების', 194],
#  ['ინტერიერთა', 1],
#  ['ნინელიმ', 40],
#  ['ენცეფალიტით', 3],
#  ['დოსტებმა', 3],
#  ['გაგვახსნევინეო', 1],
#  ['აგიზგიზების', 3],
#  ['მომჩივანად', 4],
#  ['თანაზიარებად', 1],
#  ['გადამიპატიჟა', 1],
#  ['მარეგულირებლ', 1],
#  ['ჭელაშვილთან', 4],
#  ['მოგრეხილიყვნენ', 1],
#  ['ცნებითმა', 1],
#  ['გაექცევოდი', 1],
#  ['სტეფნაძეზე', 2],
#  ['ჩანავლდება', 4],
#  ['მიშველის', 122],
#  ['ფრანცისკისა', 2],
#  ['-პერიოდს', 1],
#  ['აღთქმისაკენ', 1],
#  ['მოუგვარებლობისას', 2],
#  ['ინექციასავით', 1],
#  ['გაურთულდათ', 22],
#  ['მაძღრობაა', 1],
#  ['დაგიყოლიეს', 2],
#  ['ვაკურთხევთ', 7],
#  ['პირობაზე', 333],
#  ['ბახუსიც', 1],
#  ['ბჭის', 13],
#  ['სასმელისაც', 1],
#  ['ფაინთან', 1],
#  ['იბერებთან', 3],
#  ['გადამიტანია', 33],
#  ['მოგვარებულიაო', 14],
#  ['იჩივლეო', 3],
#  ['ოაზისსა', 3],
#  ['-ანუ', 19],
#  ['სწურავდა', 9],
#  ['ნათქვამი-მეთქი', 3],
#  ['წარყვნენ', 1],
#  ['ამაოებათა', 57],
#  ['გაბნევთ', 7],
#  ['სევდიას', 18],
#  ['გამოსკდები', 3],
#  ['დამადებდი', 1],
#  ['მიგზავნიდაო', 1],
#  ['უსაქმობაში', 3],
#  ['მატეოზე', 2],
#  ['გამაბითურებელ', 3],
#  ['ჩვენებაო', 13],
#  ['მოერგე', 15],
#  ['განიშნებ', 3],
#  ['ადეიშვილამდე', 1],
#  ['თვალხატულავ', 2],
#  ['მაცდით', 1],
#  ['ჩავიძირით', 1],
#  ['გადასავლელების', 3],
#  ['შენობათაგანის', 1],
#  ['გათეთრებისათვის', 4],
#  ['იცხადებ', 1],
#  ['შუქ-დიოდი', 1],
#  ['მომაცვლევინებს', 1],
#  ['აქებსო', 5],
#  ['გვეპყრობიან', 28],
#  ['რითმას', 69],
#  ['მახურებს', 2],
#  ['ჩატარებულმა', 1310],
#  ['წყვეტ-მეთქი', 1],
#  ['გენაა', 3],
#  ['მეცხვარიაშვილთან', 1],
#  ['ნადაბი', 8],
#  ['განსაკუთრებულობამ', 4],
#  ['დამადაბლა', 1],
#  ['ამოვძირკვეთო', 3],
#  ['რამდენნაირადაც', 1],
#  ['კემპინგებში', 3],
#  ['ბენდერზე', 2],
#  ['გულახდილებს', 1],
#  ['ჰიპერბოლაა', 6],
#  ['იზეიმებ', 2],
#  ['ინგლისელებიცა', 1],
#  ['ლოკალიზებაც', 5],
#  ['ვაიოა', 2],
#  ['უნდობლობამდეც', 1],
#  ['მოხაზეს', 17],
#  ['გვცემს', 88],
#  ['დაჰრბის', 1],
#  ['მოთხოვნილებასაო', 2],
#  ['სინედრიონმა', 1],
#  ['დაუღალავ', 118],
#  ['გააგრილეთ', 3],
#  ['მომწიფებით', 4],
#  ['სამწყსოთაო', 1],
#  ['ჯორ-ცხენასავით', 1],
#  ['მონასმებით', 30],
#  ['მიკროფონივით', 2],
#  ['შემომიტანეთ', 5],
#  ['ფეხმოდგმული', 4],
#  ['ზარიაა', 3],
#  ['იდეალურობაზე', 3],
#  ['ოპერაციაშია', 2],
#  ['გაიღვიძო', 24],
#  ['არისტოც', 2],
#  ['მოანგარიშედ', 4],
#  ['გაკვეთდა', 6],
#  ['დამოყვრებისა', 1],
#  ['ლონდონშიაც', 3],
#  ['მაგდანამ', 64],
#  ['გათავისუფლებულებიო', 1],
#  ['მობრძავი', 2],
#  ['გადმიწყვეტია', 2],
#  ['ხარბედიას', 109],
#  ['მონახევრეაო', 55],
#  ['ენტომოლოგის', 3],
#  ['დადინჯდებაო', 1],
#  ['აღსაგზნებ', 1],
#  ['ცისკრამდე', 5],
#  ['ცარცისმაგვარი', 1],
#  ['ციმენტიამ', 1],
#  ['ჩამოეთვალა', 25],
#  ['ტარაკანივით', 5],
#  ['რობაქიძესაც', 3],
#  ['უწყინარ', 442],
#  ['რეგლამენტაციები', 1],
#  ['კახელიო', 3],
#  ['გიმრავლებ', 2],
#  ['უმაქნისობაც', 1],
#  ['წამოუწყებ', 1],
#  ['კვიპროსელები', 55],
#  ['შევაგდებდიო', 1],
#  ['გახედვისთვისაც', 1],
#  ['გადურჩები', 2],
#  ['რექტორატს', 83],
#  ['შესრულთა', 3],
#  ['დამნაშავეობით', 5],
#  ['მიწათმოსარგებლე', 2],
#  ['თიხა-მიწიანია', 1],
#  ['საპატარძლომაც', 1],
#  ['ტანწვრილნი', 1],
#  ['არაფრისგანაა', 6],
#  ['დამიცინიხარ', 1],
#  ['ასულებიც', 2],
#  ['მსყიდველთა', 2],
#  ['ჩაგებარებინოთ', 1],
#  ['ისტორიკოსში', 1],
#  ['მშრომელის', 28],
#  ['ფარქვეშვე', 1],
#  ['უბლატოდ', 1],
#  ['არსებასა', 19],
#  ['ჩერქეზეთის', 63],
#  ['ოინბაზობ', 2],
#  ['გასამართლეს', 212],
#  ['ნაბოლარებს', 5],
#  ['ვარდნილით', 1],
#  ['ვშოლტავთ', 1],
#  ['დაქვეითებულად', 2],
#  ['უკვნესის', 2],
#  ['ბერტყვის', 4],
#  ['დამასახლოს', 1],
#  ['გაყალბებასაც', 41],
#  ['გაევრცელებინოს', 1],
#  ['რწმენებზე', 2],
#  ['ზიგზაგი', 19],
#  ['ჟურბასთან', 2],
#  ['დამიჯერია', 1],
#  ['შესუსტებამა', 1],
#  ['ანკლავებისგან', 1],
#  ['აკივლდებიან', 4],
#  ['ჩაეტოვებინათ', 4],
#  ['შემინდე', 134],
#  ['პირველკაცობაში', 3],
#  ['ღიმს', 4],
#  ['დაჭმუჭნოს', 2],
#  ['პირმცინარო', 1],
#  ['მბერველ', 1],
#  ['ხელმძღვანელობამო', 3],
#  ['ინსტიტუტელების', 4],
#  ['შევუმსუბუქე', 4],
#  ['მიტყიპე', 5],
#  ['სოპრანოებიდან', 1],
#  ['ხელფასებამდე', 3],
#  ['გვაძინებდეს', 1],
#  ['დავეკითხებით', 21],
#  ['ზოგადადვე', 1],
#  ['მიაყოლებენო', 1],
#  ['პასკუალეა', 1],
#  ['დიმიტრისაგან', 4],
#  ['სიზმრულით', 1],
#  ['თუალისა', 11],
#  ['ფერისცვალების', 264],
#  ['კანფეტით', 9],
#  ['გაფერმკრთალებასაც', 1],
#  ['ავტორიტეტიანია', 2],
#  ['ტვინამღვრეული', 2],
#  ['სისრულითაა', 7],
#  ['წებოვანი', 97],
#  ['ფაკტებით', 1],
#  ['სკანდალებისათვის', 1],
#  ['დავცლილიყავი', 4],
#  ['ვუდგავარ', 54],
#  ['მჩქროლავი', 1],
#  ['გაიბუტებოდა', 3],
#  ['რეზულტატია', 22],
#  ['აზვირთებულიყო', 7],
#  ['ქსეროასლები', 66],
#  ['დოროთესა', 2],
#  ['ბაგრატიონისანი', 1],
#  ['უშვილძიროდ', 32],
#  ['დვორნიკს', 2],
#  ['ვისრულებთ', 2],
#  ['მისაკითხი', 2],
#  ['გამკვეთრებულ', 1],
#  ['ჟირაფისთვის', 1],
#  ['ქართველითაა', 1],
#  ['მიუახლოვო', 1],
#  ['ოცდაექვსისა', 5],
#  ['ჩავიტიოთ', 1],
#  ['ექიშპებოდნენ', 21],
#  ['თვითნებური', 521],
#  ['კასრაძესა', 1],
#  ['ჩინელებისგან', 15],
#  ['დაწვრილმანდეთ', 1],
#  ['დაჭრან', 4],
#  ['დალაშქვრისთვის', 1],
#  ['ისრებად', 14],
#  ['მრეწველობაც', 24],
#  ['ნიშნებმა', 33],
#  ['მკლა-ვის', 2],
#  ['შემეჩხირება', 1],
#  ['გამოუძღვნენ', 3],
#  ['გვაპატიებენო', 4],
#  ['ლექსიკოლოგიური', 11],
#  ['გვიბიძგებსო', 1],
#  ['სქემატურობაა', 1],
#  ['უთვლიდნენ', 68],
#  ['ცნობისმოყვარეს', 18],
#  ['იდუმლად', 15],
#  ['ფურკამეჩი', 1],
#  ['ბორცვაძესთან', 1],
#  ['კინოფესტივალიდან', 19],
#  ['კუმეტი', 3],
#  ['ტრადიციებისათვის', 14],
#  ['მულტფილმია', 5],
#  ['აკაკუნებდეს', 1],
#  ['ნოყიერად', 10],
#  ['მამწესებენ', 1],
#  ['გრადუსითაც', 3],
#  ['მიმინოსათვის', 2],
#  ['პავლოვა', 25],
#  ['რესპუბლიკებო', 1],
#  ['გადმოაბიჯოს', 1],
#  ['გრიალზე', 9],
#  ['სტანჯონ', 3],
#  ['შესარჩევებსაც', 1],
#  ['შეაცოდონ', 6],
#  ['თეშუბა', 7],
#  ['შეუნდო', 100],
#  ['პატიოსნებაშიო', 1],
#  ['ვკადრებთ', 5],
#  ['ანტირეკლამად', 6],
#  ['ჰაიდუკიდან', 3],
#  ['რაკეტიან', 1],
#  ['გადატანებს', 1],
#  ['გულშემოყრილს', 4],
#  ['თანაგუნდელობამდე', 1],
#  ['კატასტროფასა', 5],
#  ['ვთბებოდითო', 1],
#  ['უსახელომ', 8],
#  ['ჰპირდებათ', 6],
#  ['საბაღნაროსო', 1],
#  ['ამოძვრაო', 6],
#  ['უვაროს', 4],
#  ['ნაქალაქარებს', 2],
#  ['ქარელმაც', 7],
#  ['ბათილო', 2],
#  ['მესიმინდის', 2],
#  ['რეალიზებაღაა', 1],
#  ['კომუტატორს', 1],
#  ['ჩეროებზე', 1],
#  ['მუნიციპალიტეტები', 114],
#  ['ზენაარმა', 5],
#  ['თამარიანო', 7],
#  ['გჩუქნით', 31],
#  ['ხაზარაძეზე', 13],
#  ['შედევნის', 1],
#  ['აგენტად', 306],
#  ['კბილად', 4],
#  ['მდივან-მწიგნობრებად', 1],
#  ['საუცხოვომ', 1],
#  ['ჯავახმან', 1],
#  ['ბირკიანიდან', 8],
#  ['უჩენდეს', 3],
#  ['შეუხამოთ', 5],
#  ['ეტაკნენ', 8],
#  ['ნამატისგან', 1],
#  ['ცან', 27],
#  ['ლუწში', 3],
#  ['სააპელაციოდ', 13],
#  ['ჭრილობასა', 4],
#  ['ატმოსფეროშიც', 4],
#  ['მიამწყვდევენ', 2],
#  ['დავანთოო', 1],
#  ['ორგანიზაციაშიც', 46],
#  ['გამოყრისათვის', 1],
#  ['მაზრაა', 1],
#  ['რედაქტორობს', 38],
#  ['გადმოვარდნილიო', 1],
#  ['იზიდავს', 1043],
#  ['ესმერალდასის', 1],
#  ['გადაგივლიდნენ', 1],
#  ['ჩამოსხეპის', 1],
#  ['გაგაწნავთ', 3],
#  ['ბალანთა', 1],
#  ['ბა-ღიდგან', 1],
#  ['დაბუდრებული', 2],
#  ['მოფარიკავეებსაც', 2],
#  ['დახატონ', 32],
#  ['ფილარმონიად', 1],
#  ['საბელაშვილის', 8],
#  ['ვერცხლისმოყვარეობაზეა', 1],
#  ['მახასიათებლებიდან', 4],
#  ['უიმპერიო', 4],
#  ['გაშიშვლებისაკენ', 1],
#  ['კონტრაპუნქტშია', 1],
#  ['აღგვეწერა', 6],
#  ['გაღიზიანდი', 1],
#  ['ნაჩეხ', 2],
#  ['ვკითხავ-მეთქი', 1],
#  ['გავამარჯვებ', 1],
#  ['სტელაჟს', 4],
#  ['ციგაობისთვის', 2],
#  ['ცდებში', 20],
#  ['რესპუბლიკადაა', 2],
#  ['მარგველიძეს', 2],
#  ['მანათებიც', 1],
#  ['გათიშულიაო', 2],
#  ['გადაუსროლია', 2],
#  ['წინააღმდეგობაც', 152],
#  ['ტაგანროგშიო', 1],
#  ['კინომანს', 1],
#  ['გიგისაცა', 3],
#  ['მოხსნისათვის', 22],
#  ['სამორანოზე', 1],
#  ['კოდუებმა-მეთქი', 1],
#  ['წინასწარმა', 100],
#  ['ხვალ-ზევით', 1],
#  ['მიუახლოვეთ', 1],
#  ['ჩამონათვალით', 65],
#  ['გვართმევენ', 212],
#  ['მიიწვევე', 1],
#  ['რენტგენის', 207],
#  ['შტანდარტით', 1],
#  ['ფარ-ხმალ', 4],
#  ['მალთაყვაშია', 1],
#  ['გამიხარო', 1],
#  ['ბიოლოგიას', 70],
#  ['მოითბესო', 2],
#  ['პაპებზე', 5],
#  ['მარუსიაზე', 2],
#  ['მოხსნათ', 14],
#  ['დაძაბულნი', 26],
#  ['ბაირუც', 1],
#  ['მოსულებით', 2],
#  ['სპეცშეკვეთაა', 3],
#  ['სინორჩიდან', 2],
#  ['ქმედებანი', 227],
#  ['ჩინელი-მეთქი', 1],
#  ['გაეყინოთ', 2],
#  ['არაუნივერსიტეტელი', 7],
#  ['მისაყვედურებენო', 1],
#  ['აგაღებინა', 4],
#  ['სამარელები', 36],
#  ['გავწმენდ', 7],
#  ['სამყაროსთან', 1531],
#  ['ფიცრულებს', 3],
#  ['გაჯიუტებულები', 1],
#  ['ზარმაცად', 41],
#  ['დამხმარებიან', 2],
#  ['აქტივობაშია', 5],
#  ['ჩაუწყობელ', 1],
#  ['დავნებდე', 9],
#  ['ჭაობშიაც', 1],
#  ['რეპერტუარები', 3],
#  ['შეგვახრევინა', 1],
#  ['პროფესიონალიზმი', 1589],
#  ['ნება-სურვილისამებრ', 3],
#  ['გამომაყრუა', 1],
#  ['გულაგისთვის', 2],
#  ['განმარიდო', 1],
#  ['შევაკლავთო', 1],
#  ['წარმოება-დაწესებულებებთან', 1],
#  ['სავაის', 2],
#  ['გადალახულ', 19],
#  ['დაკბილული', 63],
#  ['სანელებლებმა', 4],
#  ['ილოები', 1],
#  ['შეეტოპა', 4],
#  ['ნიკარაგუელებისადმი', 1],
#  ['ხახამშრალები', 12],
#  ['ნახპეტნი', 1],
#  ['ჩამომართვეს', 95],
#  ['უღმერთოა', 7],
#  ['ცრურწმენისკენ', 1],
#  ['ძალადურმა', 1],
#  ['დევკაცის', 17],
#  ['სიმწვავითა', 20],
#  ['უნივერსიტეტთანაც', 4],
#  ['ორიენტაციისაც', 3],
#  ['მოძახილში', 1],
#  ['ჯანყისგან', 1],
#  ['გამოსავალიაო', 1],
#  ['შემწყნარებლობიდან', 1],
#  ['ბლოკადა', 810],
#  ['შევეთვისოთ', 3],
#  ['შემდეგმა', 172],
#  ['შემოგვიბრუნებენ', 2],
#  ['ხუთკუბია', 1],
#  ['საახალწლოდო', 1],
#  ['კეხივით', 1],
#  ['გარე-მებნეს', 1],
#  ['მამულები', 265],
#  ['შემცოდეთა', 5],
#  ['ჩატარდეს', 5325],
#  ['ნარიაშვილებზე', 1],
#  ['დრანდის', 142],
#  ['გასტროლიორად', 2],
#  ['აქაველსაც', 1],
#  ['გასაცემადო', 3],
#  ['გამდგარხარ', 1],
#  ['მიგეყენებინა', 3],
#  ['გაასწრებდი', 1],
#  ['გადაელია', 2],
#  ['კურორტებში', 9],
#  ['მდიდრული', 590],
#  ['გადარდიანოს', 1],
#  ['არგამარჯვება', 2],
#  ['რელიქვიაა', 7],
#  ['შევაღებთ', 9],
#  ['იზამს-მეთქი', 5],
#  ['ნახევარწრე', 13],
#  ['ქართლიო', 3],
#  ['დააქროლებთ', 1],
#  ['ხმობდაო', 1],
#  ['ოერტესა', 1],
#  ['თერხვმა', 1],
#  ['ნუმერით', 2],
#  ['გუნცაძემ', 461],
#  ['ვიგინდარავ', 5],
#  ['წამოეგო', 377],
#  ['მოთიაშვილმა', 3],
#  ['მოკალმენი', 3],
#  ['გამხელისაგან', 26],
#  ['ჩამოვაფარებთ', 1],
#  ['სამხრეულებით', 1],
#  ['ფატუმის', 18],
#  ['მოთოკავ-მეთქი', 1],
#  ['უიმისოდაო', 1],
#  ['საგარეოპოლიტიკური', 337],
#  ['ნახევარკუნძულისას', 1],
#  ['გამგეობებს', 200],
#  ['დამაახლოვეთ', 1],
#  ['ქვეყანათ', 1],
#  ['ლილეს', 63],
#  ['თარხნიშვილში', 2],
#  ['ტრიუკები', 55],
#  ['მოფარიკავეთა', 159],
#  ['პენსიითა', 13],
#  ['განხუმევასა', 1],
#  ['დასასრულით', 90],
#  ['გვერდალში', 6],
#  ['შერევისა', 4],
#  ['ხოხბისაგან', 1],
#  ['მოგვმართეს', 173],
#  ['დამამშვიდეს', 28],
#  ['შარიაშვილი', 1],
#  ['წყალობასო', 1],
#  ['ამერიკულიო', 2],
#  ['ცნების', 663],
#  ['ამომაც', 1],
#  ['საათებშიო', 1],
#  ['მსხვილღეროიანი', 1],
#  ['გაჰმთელებია', 1],
#  ['შელანძულია', 1],
#  ['მონაღა', 1],
#  ['ფსიქიატრიით', 1],
#  ['რთხმელა', 1],
#  ['მოგვაგეს', 2],
#  ['მაჭარაშვილზე', 1],
#  ['ქაედასი', 1],
#  ['წიაღი', 115],
#  ['შეუშლიო', 1],
#  ['გაბედო-მეთქი', 3],
#  ['გასახსენები', 1],
#  ['ებნისსა', 4],
#  ['აღმსრულებელს', 22],
#  ['ნაპობში', 2],
#  ['თარაშვილის', 19],
#  ['დამახვევს', 5],
#  ['დაგდევნებოდაო', 1],
#  ['კიტეიშვილმა', 1],
#  ['გახელმწიფებამ', 1],
#  ['გავერთეო', 1],
#  ['ასაკშია', 175],
#  ['-შობა', 1],
#  ['შევუტევო', 7],
#  ['სეზონამდეც', 2],
#  ['დამიჭყლეტია', 1],
#  ['ყურეც', 6],
#  ['უსუფთაოსიც', 1],
#  ['გავუხეთქავ', 2],
#  ['გამახარებდით', 1],
#  ['მაჰარაჯმა', 7],
#  ['გადაგვყლაპეს', 1],
#  ['გიჭამით', 1],
#  ['ჩაკეტვები', 1],
#  ['პიკთა', 1],
#  ['საჩეჩნოდ', 1],
#  ['სახელიღაა', 3],
#  ['გალივლივება', 1],
#  ['ნინოწმინდისთვის', 1],
#  ['ეუთოსა', 469],
#  ['ყარაულნი', 5],
#  ['დასახარჯის', 1],
#  ['აამუშაო', 5],
#  ['დამადასტურებელად', 3],
#  ['უპატიურსა', 2],
#  ['შემოცურდა', 9],
#  ['კაცაძემ', 15],
#  ['კუნძულამდე', 20],
#  ['შესთავაზოთ', 37],
#  ['შეთავაზებებისა', 9],
#  ['გაკვირვებითა', 16],
#  ['ვიქცევდით', 11],
#  ['წყალსადენიც', 3],
#  ['აიჭრენ', 1],
#  ['გწყვეტ', 1],
#  ['შევაწერე', 3],
#  ['შერცხვენილმა', 47],
#  ['თელ-ავივსა', 11],
#  ['მიმორხევით', 1],
#  ['ჩახლართავ', 1],
#  ['ჭუპრებზე', 1],
#  ['გამოგითხარონ', 1],
#  ['იძახოდისო', 1],
#  ['გამონაკლისებიცო', 1],
#  ['კინოკრიტიკაშიც', 1],
#  ['კბენაზეც', 1],
#  ['წამლობებს', 2],
#  ['ლეზგარის', 1],
#  ['თმობდნენ', 72],
#  ['არაკაცია', 17],
#  ['სასმენელმან', 1],
#  ['ქავთარაძესო', 1],
#  ['ნიავებით', 3],
#  ['შემსუბუქებულიყვნენ', 1],
#  ['კომპრომისია', 51],
#  ['შარავანდებს', 2],
#  ['ჩამონათვალიც', 98],
#  ['გამწარებითა', 1],
#  ['შიმშილობანი', 1],
#  ['პრივატიზებაზეა', 6],
#  ['თევდორაძისათვის', 5],
#  ['ქრომატიზმების', 1],
#  ['გამოჯანმრთელებულთა', 3],
#  ['პრინციპებისაკენ', 3],
#  ['შეურქმევიაო', 1],
#  ['ვაჭრობაო', 4],
#  ['იხოცდა', 1],
#  ['ძველმოდურობის', 3],
#  ['ბეჩავნი', 14],
#  ['წარდგენით', 229],
#  ['ბელასიცაში', 3],
#  ['ვაცადო', 3],
#  ['გაგვირემონტა', 5],
#  ['ოპიუმსა', 3],
#  ['გვადალახარასთან', 4],
#  ['ბარომეტრული', 2],
#  ['გაუზრდიხარო', 1],
#  ['რაკუნში', 1],
#  ['მჭერიაო', 2],
#  ['წავფორხილდით', 3],
#  ['ანტი-დემოკრატიულად', 1],
#  ['დაგიხვეწს', 1],
#  ['ქრონიკაზეა', 1],
#  ['ექსპედიციებია', 1],
#  ['თანხვედრათა', 1],
#  ['შინება', 1],
#  ['დაიფშვნებაო', 1],
#  ['გაწერაზეც', 2],
#  ['გადმოანთხიონ', 3],
#  ['სამოციანელია', 1],
#  ['გეოგრაფთა', 8],
#  ['ჰაერამდე', 5],
#  ['თანამოსაუბრეების', 11],
#  ['ჩაძახილიც', 1],
#  ['გამოგასახლებენ', 3],
#  ['ებრაელებზე', 90],
#  ['მელნისათვის', 3],
#  ['გადაქანდით', 1],
#  ['წელგატეხილი', 3],
#  ['ავიღე', 1665],
#  ['მიჩქმალულიყო', 12],
#  ['კეცვას', 2],
#  ['შეგეგრძნო', 1],
#  ['პრორექტორებისა', 1],
#  ['მებუკედ', 1],
#  ['ინჟექტორული', 1],
#  ['გამოსარიცხად', 57],
#  ['ცხოველე', 1],
#  ['ბუღა', 123],
#  ['გვიღალატონ', 2],
#  ['უტაქტობებზე', 1],
#  ['ყაუხჩიშვილიც', 3],
#  ['გააკეთე', 613],
#  ['ფორთოხალსაც', 1],
#  ['მეზობლებისაა', 1],
#  ['შეუჭედა', 1],
#  ['აყროყინდნენ', 1],
#  ['გამოვდევნოთ', 4],
#  ['ექსტაზი', 136],
#  ['კოშკადაა', 1],
#  ['სთქუთ-ღა', 1],
#  ['შეხმად', 1],
#  ['ქვრივზედ', 3],
#  ['გადმოლახესო', 4],
#  ['ბაბუხადია', 165],
#  ['ცეკვა-სიმღერებს', 1],
#  ['შემაძრწუნებელისა', 2],
#  ['ვასალიო', 1],
#  ['ქოსატყუილასი', 1],
#  ['ფოტოკომპოზიციების', 1],
#  ['ოქრუაშვილისაც', 2],
#  ['დამწიხლეს', 1],
#  ['დრედნოუტებს', 1],
#  ['ნებართვებისთვის', 3],
#  ['გაადგამდი', 1],
#  ['გადაჰკრასო', 1],
#  ['იომებენ', 52],
#  ['გვივარგაო', 3],
#  ['გახსენებითღა', 1],
#  ['დაასურათხატა', 11],
#  ['გადაყვითლებულს', 1],
#  ['ჰალუცინაციას', 7],
#  ['დეკლარირებენ', 7],
#  ['სანაპიროებზედ', 1],
#  ['ძეთა', 261],
#  ['სიბრმესა', 2],
#  ['ნაკეთის', 3],
#  ['კლასელსა', 1],
#  ['ამოგაყოფინებთ', 4],
#  ['არიდებენ', 566],
#  ['დაცვენილები', 2],
#  ['ფიწლებითა', 1],
#  ['დანაპირებები', 5],
#  ['მასშტაბურობისკენ', 1],
#  ['განეგულვა', 1],
#  ['ვგეშავთ', 1],
#  ['ფურცლებზე', 2397],
#  ['გვანანო', 10],
#  ['ვაწვევო', 2],
#  ['აღმართ-დაღმართის', 4],
#  ['მეფისწული', 21],
#  ['ჩაატარებსო', 8],
#  ['შესაბრუნებლად', 4],
#  ['დავიკლაკნე', 1],
#  ['იმპროვიზაციებსაც', 2],
#  ['ფუტურიზმა', 1],
#  ['მოივლის', 140],
#  ['საბაბმა', 4],
#  ['მარგინალურად', 16],
#  ['გამოუყენებელზე', 1],
#  ['ქვითკირს', 2],
#  ['დაუგროვდებათ', 9],
#  ['ალაფობას', 1],
#  ['ხელისდადებით', 2],
#  ['აპოგეაც', 1],
#  ['გავწვალდებოდი', 4],
#  ['გამოგჭამა', 3],
#  ['მოდითო', 48],
#  ['განსწავლილი', 1],
#  ['ხელუხლებელად', 1],
#  ['ინგლისელებისათვის', 10],
#  ['ჰერობს', 1],
#  ['აწესებსო', 2],
#  ['სუპერმანქანით', 1],
#  ['შორისშორ', 1],
#  ['გაუცოცხლებელი', 1],
#  ['გადახურდავებაა', 3],
#  ['ძმურსა', 1],
#  ['გოგიშვილისთვის', 3],
#  ['შემოეჩვიათ', 2],
#  ['დოსტაქრის', 7],
#  ['გვარიშვილისთვის', 2],
#  ['გადამშალა', 1],
#  ['მიზანშეწონილობისათვის', 2],
#  ['დასახელებისაც', 1],
#  ['მანამდის-კი', 1],
#  ['არმიცემით', 6],
#  ['დაქსელე', 1],
#  ['არიად', 1],
#  ['შემხედავი', 7],
#  ['ქარიშხლისთვის', 1],
#  ['გადამიფრენს', 1],
#  ['შემიმსუბუქო', 2],
#  ['ინვესტიციებიდან', 39],
#  ['იგნორირებით', 422],
#  ['აფარფატებულს', 1],
#  ['გედები', 91],
#  ['მეკალმეთაგან', 1],
#  ['გამოვტვინებულვარ', 1],
#  ['ვყნოსავ', 19],
#  ['ჩავისახე', 3],
#  ['მიათრიეთ', 1],
#  ['უნაზღაურდებოდათ', 2],
#  ['ამდაგვარს', 53],
#  ['მერვანია', 1],
#  ['აღანთებ', 2],
#  ['დაინთქმებიან', 1],
#  ['არაერთდროულად', 1],
#  ['მისიაშვილისთვის', 1],
#  ['ბავშვებითა', 15],
#  ['აპენინებისაკენ', 1],
#  ['-დაფარული', 1],
#  ['მეჯოგეთ', 1],
#  ['მალიორკელ', 20],
#  ['რადიოსგან', 7],
#  ['გაირღვნენ', 1],
#  ['სადივიზიო', 3],
#  ['გაქრობისკენ', 3],
#  ['სიმოკლეშია', 1],
#  ['მიჰ-ყიდიან', 1],
#  ['გამოსთქვამდნენ', 14],
#  ['ტირანიად', 7],
#  ['ქეთელაურამდე', 1],
#  ['ავანტიურითა', 3],
#  ['ქაცავა', 1],
#  ['გავუწვები', 1],
#  ['მომთვინიერებლებიც', 2],
#  ['მომიმწყვდიეთ', 2],
#  ['სარკოფაგებში', 12],
#  ['სიაფანდური', 3],
#  ['გამოგაპანღურებენ', 3],
#  ['კეთილსაიმედოობაში', 7],
#  ['განაიარაღება', 1],
#  ['წაიფრუტუნა', 8],
#  ['ამაღლებულა', 42],
#  ['ნაოჭთა', 7],
#  ['გიცხოვრიათო', 2],
#  ['სახისმეტყველებასთან', 1],
#  ['სიალალეში', 3],
#  ['ელემენტარულიდან', 1],
#  ['მორაგბეებისაა', 1],
#  ['მოვლინებაა', 6],
#  ['გევაჭრებათ', 2],
#  ['დაეტევი', 7],
#  ['ლოყაც', 6],
#  ['თვალჟუჟუნა', 29],
#  ['მიაშურო', 6],
#  ['გადაგვზიდე', 1],
#  ['გასარწყავების', 9],
#  ['მოვიცვით', 2],
#  ['თანამოაზრეობაზე', 5],
#  ['არკვია', 1],
#  ['ჩაილეწნენ', 1],
#  ['უნებისყოფობაც', 1],
#  ['გენოციდადაა', 3],
#  ['პროდასავლურობაში', 18],
#  ['კომპაქტდისკები', 36],
#  ['არგუმენტებისა', 49],
#  ['გაბობღდა', 3],
#  ['ნიკარაგუაზე', 1],
#  ['კერასთანო', 1],
#  ['ლეიტენანტობისა', 1],
#  ['რჩეულთაგანმა', 1],
#  ['ჩრდილოეთელების', 1],
#  ['ბაღლინჯოს', 23],
#  ['შერკინებაზე', 23],
#  ['გაჯილდოებენ', 3],
#  ['დაამძიმაო', 1],
#  ['ენდრიუც', 2],
#  ['თოთხმეტ-თექვსმეტწლიანთა', 1],
#  ['სააფხაზოში', 1],
#  ['რეზიდენციასა', 13],
#  ['შემყურის', 2],
#  ['ურეგისტრაციო', 1],
#  ['სუვერენული', 2079],
#  ['პროკურორებთან', 36],
#  ['სადგერსა', 1],
#  ['რეაგირებებმა', 1],
#  ['გააძევეთო', 1],
#  ['დავასო', 2],
#  ['გიყიდიო', 18],
#  ['სწყურია', 429],
#  ['ვერიდებოდეთ', 4],
#  ['მო-ვედი', 1],
#  ['მოქეიფედ', 2],
#  ['მიდუნდება', 3],
#  ['კოტეტიშვილთან', 21],
#  ['ვთელეთ', 1],
#  ['იეჰოველთა', 42],
#  ['შემსვლელებიც', 1],
#  ['კეკოშვილის', 2],
#  ['გაძლიერებულ', 422],
#  ['ფსიქოლოგობა', 11],
#  ['სუხიშვილებსა', 2],
#  ['ზარანდიებს', 5],
#  ['პლაკეს', 2],
#  ['მასრებისა', 3],
#  ['მოუხედავთ', 18],
#  ['მხარეებზეა', 11],
#  ['ექსპროპრიაციიდან', 2],
#  ['მწვანილნი', 1],
#  ['მხარისას', 9],
#  ['ფინიქსის', 229],
#  ['მუცლიანები', 1],
#  ['მოიკვეთდა', 1],
#  ['გაეკილოს', 1],
#  ['კლიმიაშვილსაც', 3],
#  ['დააჯილდოეს', 117],
#  ['შვილება', 24],
#  ['დოკუმენტი', 11601],
#  ['მიწაყრილი', 15],
#  ['სამადაშვილისა', 11],
#  ['დემოკრატიაში', 236],
#  ['კატლეტსაც', 2],
#  ['ეროვნულობამ', 1],
#  ['საპატრიაქოში', 2],
#  ['ჩამწერების', 2],
#  ['ვუფრთხილდებოდეთ', 26],
#  ['გასვარა', 15],
#  ['სასმელშიო', 1],
#  ['მივაჭრი-მეთქი', 1],
#  ['ექვსტერფიანად', 1],
#  ['დათუაშვილთან', 35],
#  ['გამძაფრდები', 1],
#  ['სახლეში', 4],
#  ['ტკაცუნმა', 3],
#  ['თავ-კაცებმა', 1],
#  ['ჩამოგდეთ', 1],
#  ['გაჯაგული', 1],
#  ['იდეოლოგიასაც', 7],
#  ['კუკლებო', 1],
#  ['გამეფდა', 237],
#  ['ფერგანაშიო', 1],
#  ['პარკშიო', 3],
#  ['გაუგებრობაზეც', 2],
#  ['ხარიხებსაო', 1],
#  ['აფრქვია', 17],
#  ['ყაითნის', 4],
#  ['მესისგან', 7],
#  ['კომიკურთან', 1],
#  ['ჩასადენ', 9],
#  ['გამიჯნურდება', 1],
#  ['ხვისტანიც', 3],
#  ['მორისმა', 110],
#  ['ტოტალურობას', 6],
#  ['ჰარალალეო', 1],
#  ['ბგერათა', 132],
#  ['დარდსაო', 1],
#  ['მიდრეკილებაში', 18],
#  ['ქართლ-კახურის', 1],
#  ['სკამებს', 278],
#  ['შერეკილებისგან', 4],
#  ['კნაჭამ', 8],
#  ['ფარავნამდე', 3],
#  ['ტერმინალებისა', 2],
#  ['გაწრთვნის', 6],
#  ['მწიგნობრობასა', 4],
#  ['შვენიერნო', 1],
#  ['გაზავებულ', 19],
#  ['მაგატესთან', 15],
#  ['ფილოსოფოსთაგან', 6],
#  ['აზერბაიჯანელში', 1],
#  ['ენერგიულობით', 61],
#  ['ბერიასგანაა', 1],
#  ['აღმოვიკვნესე', 2],
#  ['გაიღებთო', 1],
#  ['ფსიქოთერაპევტებთან', 1],
#  ['რასინი', 1026],
#  ['ფროდიაშვილიც', 1],
#  ['შაქრიანზე', 1],
#  ['ითმინეს', 42],
#  ['გადააწყვეტინებდნენ', 1],
#  ['ბოყოჩაძის', 1],
#  ['მერგოს-მეთქი', 1],
#  ['სრო-ლაა', 1],
#  ['ინსპექციებად', 1],
#  ['ვაცეცხლო', 1],
#  ['თბილქალაქგანათებასა', 1],
#  ['მოვიკეთე', 3],
#  ['სისხლხორციელ', 1],
#  ['კიდობანის', 32],
#  ['გადმოუვარდება', 5],
#  ['შეკრებისთვისაც', 2],
#  ['ელდარს', 40],
#  ['დგამდაო', 3],
#  ['დამიღერღოს', 1],
#  ['წამოჯდომია', 1],
#  ['ბეზინი', 4],
#  ['რუსულაშვილი', 2],
#  ['რკალისებრ', 1],
#  ['დაადანაშაულო', 64],
#  ['ბერაში', 4],
#  ['დათხარიან', 5],
#  ['ჩაუწერენ', 6],
#  ['მოკვეთდა', 5],
#  ['დაუდნათ', 1],
#  ['ფინანსისტზე', 1],
#  ['ნუგეშისცემაც', 3],
#  ['მშვილდოსნიდან', 1],
#  ['რესტავრატორ', 6],
#  ['გადაგვიჭრა', 13],
#  ['შევუმოწმო', 1],
#  ['წარმომადგენელობისაო', 1],
#  ['ლიტერატურისმცოდნეობის', 17],
#  ['ხავერდგადაკრული', 6],
#  ['ომაინიანი', 1],
#  ['შეამთხვივა', 1],
#  ['კაფეების', 119],
#  ['ითხოვენო', 35],
#  ['ალამისით', 1],
#  ['ჯიბგირობის', 1],
#  ['გადათვლიდი', 2],
#  ['ამბოხებად', 15],
#  ['მეახელ', 1],
#  ['დალესისა', 1],
#  ['უფრთხიან', 192],
#  ['ორთოგრაფიაში', 5],
#  ['დუისშიც', 2],
#  ['გულსაბამი', 1],
#  ['გადაალაჯოს', 1],
#  ['ჩამრგვალებულ', 2],
#  ['აღგვიდგენენ', 5],
#  ['დაირტყამ', 5],
#  ['ბითლზშიც', 1],
#  ['ქვლივიძეებს', 1],
#  ['თელაში', 9],
#  ['უხშირე', 1],
#  ['აღიარებასთან', 191],
#  ['ავუნაზღაუროთ', 21],
#  ['ტაშკენტმა', 38],
#  ['დამბაჩის', 46],
#  ['სათბობ-ენერგეტიკის', 1054],
#  ['კურსდამთავრებულია', 111],
#  ['ნოინებმა', 27],
#  ['მაურინიუსი', 2],
#  ['მიხატავთ', 1],
#  ['გასვლასავითაა', 1],
#  ['წააკითხო', 13],
#  ['ჟინოლაა', 1],
#  ['მოაზრეებთან', 2],
#  ['გჭირთ', 116],
#  ['ენადღეობასა', 1],
#  ['ორღანოდ', 1],
#  ['უცხოელში', 6],
#  ['მომდევდეს', 5],
#  ['მილანშია', 29],
#  ['შენიშვნებზეც', 3],
#  ['გადამთელონო', 1],
#  ['სინემატოგრაფის', 4],
#  ['წვერვისას', 1],
#  ['გაემიჯნნენ', 9],
#  ['უცხოელებთანაც', 9],
#  ['სარეზოლუციოცა', 1],
#  ...]

# %%
import codecs
from subword_nmt.learn_bpe import learn_bpe
from subword_nmt.apply_bpe import BPE

corpus = ' '.join([pair[0] * pair[1] for pair in freqs.values.tolist()])
# Learn BPE from the corpus
bpe_model_path = 'bpe_model.model'
bpe_vocab_size = 1000
learn_bpe(corpus, bpe_model_path, bpe_vocab_size)

# Create a BPE object
bpe = BPE(open(bpe_model_path))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       7 bpe_model_path = 'bpe_model.model'
#       8 bpe_vocab_size = 1000
# ----> 9 learn_bpe(corpus, bpe_model_path, bpe_vocab_size)
#      11 # Create a BPE object
#      12 bpe = BPE(open(bpe_model_path))
#
# File ~/opt/anaconda3/envs/NLP/lib/python3.10/site-packages/subword_nmt/learn_bpe.py:280, in learn_bpe(infile, outfile, num_symbols, min_frequency, verbose, is_dict, total_symbols, num_workers)
#     275 """Learn num_symbols BPE operations from vocabulary, and write to outfile.
#     276 """
#     278 # version 0.2 changes the handling of the end-of-word token ('</w>');
#     279 # version numbering allows bckward compatibility
# --> 280 outfile.write('#version: 0.2\n')
#     282 vocab = get_vocabulary(infile, is_dict, num_workers)
#     283 vocab = dict([(tuple(x[:-1])+(x[-1]+'</w>',) ,y) for (x,y) in vocab.items()])
#
# AttributeError: 'str' object has no attribute 'write'

# %%
# Encode text using BPE
encoded_text = bpe.process_line("Hello, world!")
print(encoded_text)

# Decode text using BPE
decoded_text = bpe.process_line(encoded_text, reverse=True)
print(decoded_text)
# Out:
# {'-',
#  '</w>',
#  'ა',
#  'ა</w>',
#  'ად',
#  'ად</w>',
#  'ავ',
#  'ალ',
#  'ამ',
#  'ამ</w>',
#  'ან',
#  'ან</w>',
#  'არ',
#  'არ</w>',
#  'ართ',
#  'ას',
#  'ას</w>',
#  'ატ',
#  'აქ',
#  'აღ',
#  'აში</w>',
#  'ახ',
#  'ბ',
#  'გ',
#  'გა',
#  'გამ',
#  'გან',
#  'გრ',
#  'დ',
#  'და',
#  'და</w>',
#  'ე',
#  'ე</w>',
#  'ებ',
#  'ება</w>',
#  'ები</w>',
#  'ების</w>',
#  'ებს</w>',
#  'ეგ',
#  'ედ',
#  'ევ',
#  'ეთ',
#  'ელ',
#  'ემ',
#  'ენ',
#  'ენ</w>',
#  'ენტ',
#  'ერ',
#  'ერთ',
#  'ეს',
#  'ეს</w>',
#  'ეტ',
#  'ვ',
#  'ველ',
#  'ზ',
#  'ზე</w>',
#  'თ',
#  'თ</w>',
#  'თავ',
#  'თვ',
#  'თუ',
#  'ი',
#  'ი</w>',
#  'ია</w>',
#  'იან',
#  'იდ',
#  'ივ',
#  'ით',
#  'ით</w>',
#  'იკ',
#  'ილ',
#  'იმ',
#  'ინ',
#  'ირ',
#  'ის',
#  'ის</w>',
#  'იტ',
#  'იც</w>',
#  'კ',
#  'ლ',
#  'მ',
#  'მა',
#  'მა</w>',
#  'მი',
#  'მო',
#  'ნ',
#  'ო',
#  'ო</w>',
#  'ობ',
#  'ოდ',
#  'ოვ',
#  'ოლ',
#  'ომ',
#  'ონ',
#  'ორ',
#  'ოს</w>',
#  'პ',
#  'ჟ',
#  'რ',
#  'რო',
#  'რომ',
#  'ს',
#  'ს</w>',
#  'სა',
#  'სამ',
#  'სახ',
#  'ტ',
#  'უ',
#  'ულ',
#  'ული</w>',
#  'უნ',
#  'ურ',
#  'ური</w>',
#  'უფ',
#  'ფ',
#  'ქ',
#  'ღ',
#  'ყ',
#  'შ',
#  'შე',
#  'შვ',
#  'ში</w>',
#  'ჩ',
#  'ც',
#  'ც</w>',
#  'ცი',
#  'ცხ',
#  'ძ',
#  'წ',
#  'ჭ',
#  'ხ',
#  'ხელ',
#  'ხვ',
#  'ჯ',
#  'ჰ'}

# %%
word = data['word'].to_list()[0]
[word[i : i + 3] for i in range(0, len(word), 3)]
# Out:
# ['მონ', 'ოზო', 'ნის', 'ა']

# %%
def get_tokens(series):
    yield ( for word in series.to_list())

get_tokens(data['word'])
vocab = build_vocab_from_iterator(iterator=get_tokens(itertools.chain(data['word'], data['lemma'])),
                                  min_freq=3,
                                  specials=["<end>", "<unk>"],
                                  )

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
