# %% [markdown]
# # Imports

# %%
import os

import pandas as pd
from transformers import TokenClassificationPipeline, DistilBertForTokenClassification, BertTokenizerFast
from tokenizers import Tokenizer, decoders

from evaluation.evaluation import PipelinePredictor, POSEvaluator

# %% [markdown]
# # Constants

# %%
UNK_TOKEN = '<UNK>'
PAD_TOKEN = '<PAD>'
CLS_TOKEN = '<CLS>'
SEP_TOKEN = '<SEP>'
MASK_TOKEN = '<MASK>'
SPECIAL_TOKENS = [UNK_TOKEN, PAD_TOKEN, CLS_TOKEN, SEP_TOKEN, MASK_TOKEN]
SPECIAL_TOKENS
# Out:
# ['<UNK>', '<PAD>', '<CLS>', '<SEP>', '<MASK>']

# %%
TOKENIZER_PATH = os.path.join('models', 'tokenizers')
WORDPIECE_TOKENIZER_PATH = os.path.join(TOKENIZER_PATH, 'wordpiece_tokenizer')
MODEL_PATH = os.path.join('models', 'results')

# %% [markdown]
# # Loading Model

# %%
model = DistilBertForTokenClassification.from_pretrained(os.path.join(MODEL_PATH ,'checkpoint-31000'))
model
# Out:
# DistilBertForTokenClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(6000, 64, padding_idx=1)
#       (position_embeddings): Embedding(200, 64)
#       (LayerNorm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0): TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=64, out_features=64, bias=True)
#             (k_lin): Linear(in_features=64, out_features=64, bias=True)
#             (v_lin): Linear(in_features=64, out_features=64, bias=True)
#             (out_lin): Linear(in_features=64, out_features=64, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=64, out_features=128, bias=True)
#             (lin2): Linear(in_features=128, out_features=64, bias=True)
#             (activation): ReLU()
#           )
#           (output_layer_norm): LayerNorm((64,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=64, out_features=11, bias=True)
# )

# %%
tokenizer = Tokenizer.from_file(os.path.join(WORDPIECE_TOKENIZER_PATH, 'wordpiece_6000.json'))
tokenizer.decoder = decoders.WordPiece(prefix="##")
tokenizer = BertTokenizerFast(tokenizer_object=tokenizer, unk_token=UNK_TOKEN,
    pad_token=PAD_TOKEN,
    cls_token=CLS_TOKEN,
    sep_token=SEP_TOKEN,
    mask_token=MASK_TOKEN, model_input_names=['input_ids', 'attention_mask'])

# %%
recognizer = TokenClassificationPipeline(model=model.to('cpu'), tokenizer=tokenizer)
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %%
predictor =  PipelinePredictor(recognizer)

# %%
TEST_PATH = os.path.join('data', 'test')
EVALUATIONS_PATH = os.path.join('evaluation', 'evaluations')

# %%
test_df = pd.read_orc(os.path.join(TEST_PATH, 'test_1.orc'), dtype_backend='pyarrow')

# %%
import json
import os
from collections import defaultdict
from dataclasses import dataclass
from typing import Protocol, Tuple, List, Dict
import torch.nn as nn
from transformers import TokenClassificationPipeline

import pandas as pd
from sklearn.metrics import classification_report
from hmmlearn import hmm

EVALUATION_PATH = 'evaluation/evaluations'


class Predictor(Protocol):

    def predict(self, data: pd.DataFrame) -> pd.DataFrame:
        pass


@dataclass
class HMMPredictor:
    model: hmm.CategoricalHMM

    def predict(self, data: pd.DataFrame) -> pd.DataFrame:
        data['predictions'] = data.mod_words.apply(lambda l: self.model.predict(l))
        return data
    
@dataclass
class PipelinePredictor:
    pipeline: TokenClassificationPipeline
    
    def _combine_entities_with_average(self, subword_entities, sent):
        grouped_entities = []

        entities = []
        current_entity = ""
        current_tokens = defaultdict(int)
        for entity in subword_entities:
            token = entity['word']
            tag = entity['entity']
            score = entity['score']
            
            if token.startswith('##'):
                current_entity += token[2:]
                current_tokens[tag] += score
            else:
                if current_entity:
                    entities.append((current_entity, max(current_tokens, key=lambda x: current_tokens[x])))
                    
                current_entity = token
                current_tokens.clear()
                current_tokens[tag] = score
                
        if current_entity:
            entities.append((current_entity, max(current_tokens, key=lambda x: current_tokens[x])))
        
        if len(sent) != len(entities):
            print(sent)
            print(entities)
            print()
        return entities

    def predict(self, data: pd.DataFrame) -> pd.DataFrame:
        data['predictions'] = data.mod_words.apply(lambda l: [tag for word, tag in self._combine_entities_with_average(self.pipeline(" ".join(l)), l)])
        return data


@dataclass
class POSEvaluator:
    df: pd.DataFrame
    model_name: str
    path: os.PathLike

    def __evaluate_category(self, data: pd.DataFrame, category: str) -> Dict[str, Dict[str, int]]:

        groupped = data.groupby(category)
        results = {}
        # print(dict(list(groupped)))

        for type, data in dict(list(groupped)).items():
            y_true = [p for l in data.pos_tags.tolist() for p in l]
            y_pred = data.predictions.explode().tolist()
                
            results[type] = classification_report(y_true, y_pred, output_dict=True)
                
        return results

    def evaluate(self, predictor: Predictor, categories: List[str], worst: int = 3) -> None:
        result_df = predictor.predict(self.df)

        eval = {}
        for i, category in enumerate(categories):
            eval[category] = self.__evaluate_category(result_df, category)

        with open(os.path.join(self.path, self.model_name, 'eval.json'), "w") as f:
            json.dump(eval, f, indent=3, ensure_ascii=False)

# %%
evaluator = POSEvaluator(test_df, 'transformers', EVALUATIONS_PATH)

# %%
predictor =  PipelinePredictor(recognizer)

# %%
evaluator.evaluate(predictor, ['starts_with', 'unique_pos'])
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ['მეფემ' 'აღარ' 'იცოდა' ',' 'როგორი' 'მადლი' 'გადაეხადა' 'წერეთლისათვის'
#  'და' 'დიდძალი' 'ყმა' 'და' 'მამული' 'უბოძა' 'ზემო-ქართლში' '.']
# [('მეფემ', 'N'), ('აღარ', 'Adv'), ('იცოდა', 'V'), (',', 'Punct'), ('როგორი', 'Pron'), ('მადლი', 'N'), ('გადაეხადა', 'V'), ('წერეთლისათვის', 'N'), ('და', 'Cj'), ('დიდძალი', 'N'), ('ყმა', 'N'), ('და', 'Cj'), ('მამული', 'N'), ('უბოძა', 'N'), ('ზემო', 'N'), ('-', 'N'), ('ქართლში', 'N'), ('.', 'Punct')]
#
# ['ასე' 'მოუხსენებია' 'ოდესღაც' 'ვიღაც' 'ბერს' 'და' 'შემდეგ' 'დონ-კიხოტის'
#  'მთქმელს' 'სერვანტესსაც' 'გაუმეორებია' '…' 'სთქვა' 'მწერლობასა' 'შინა'
#  'განსწავლულმა' 'ჭავჭავაძემ' 'და' 'ვახშმის' 'დასაჭედავად' 'გავიდა' '.']
# [('ასე', 'Adv'), ('მოუხსენებია', 'V'), ('ოდესღაც', 'Adv'), ('ვიღაც', 'Pron'), ('ბერს', 'N'), ('და', 'Cj'), ('შემდეგ', 'Adv'), ('დონ', 'N'), ('-', 'N'), ('კიხოტის', 'N'), ('მთქმელს', 'N'), ('სერვანტესსაც', 'N'), ('გაუმეორებია', 'V'), ('…', 'Punct'), ('სთქვა', 'V'), ('მწერლობასა', 'N'), ('შინა', 'A'), ('განსწავლულმა', 'A'), ('ჭავჭავაძემ', 'N'), ('და', 'Cj'), ('ვახშმის', 'N'), ('დასაჭედავად', 'A'), ('გავიდა', 'V'), ('.', 'Punct')]
#
# ['მაგრამ' 'ამ' 'თამაშ-თამაშში' 'ხელისუფლებამ' 'გააღვიძა' 'მონსტრი' ','
#  'რომელსაც' 'ყველა' 'კარგად' 'ვხედავთ' '.']
# [('მაგრამ', 'Cj'), ('ამ', 'Pron'), ('თამაშ', 'N'), ('-', 'N'), ('თამაშში', 'N'), ('ხელისუფლებამ', 'N'), ('გააღვიძა', 'V'), ('მონსტრი', 'N'), (',', 'Punct'), ('რომელსაც', 'Pron'), ('ყველა', 'A'), ('კარგად', 'A'), ('ვხედავთ', 'V'), ('.', 'Punct')]
#
# ['ჩავედი' ',' 'დავამშვიდე' ',' 'ცოტაც' 'უნდა' 'გაუძლოთ-მეთქი' '.']
# [('ჩავედი', 'V'), (',', 'Punct'), ('დავამშვიდე', 'V'), (',', 'Punct'), ('ცოტაც', 'Adv'), ('უნდა', 'Pron'), ('გაუძლოთ', 'V'), ('-', 'V'), ('მეთქი', 'V'), ('.', 'Punct')]
#
# ['ქ-ნი' 'მირანდა' 'შევარდა' 'სააბაზანოში' 'და' 'კარი' 'ჩაიკეტა' '.']
# [('ქ', 'N'), ('-', 'N'), ('ნი', 'N'), ('მირანდა', 'N'), ('შევარდა', 'V'), ('სააბაზანოში', 'N'), ('და', 'Cj'), ('კარი', 'N'), ('ჩაიკეტა', 'V'), ('.', 'Punct')]
#
# ['ამ' 'სავალალო' 'არსების' 'აღგზნებულება' 'თავისი' 'უმანკო' 'ამაოებითა'
#  'და' 'თვითკმაყოფილებით' 'ააღელვებს' 'პიკერინგს' ',' 'რომელიც' 'ქ-ნი'
#  'პირსის' 'თანდასწრებით' 'წელში' 'სწორდება' '.']
# [('ამ', 'Pron'), ('სავალალო', 'A'), ('არსების', 'N'), ('აღგზნებულება', 'N'), ('თავისი', 'Pron'), ('უმანკო', 'A'), ('ამაოებითა', 'A'), ('და', 'Cj'), ('თვითკმაყოფილებით', 'N'), ('ააღელვებს', 'V'), ('პიკერინგს', 'N'), (',', 'Punct'), ('რომელიც', 'Pron'), ('ქ', 'N'), ('-', 'N'), ('ნი', 'N'), ('პირსის', 'N'), ('თანდასწრებით', 'Adv'), ('წელში', 'N'), ('სწორდება', 'V'), ('.', 'Punct')]
#
# ['*' '*' '*' '15' 'სექტემბერს' 'ესპანურმა' 'პრესამ' 'გაავრცელა'
#  'ინფორმაცია' 'იმის' 'თაობაზე' ',' 'რომ' 'შარშან' 'საქართველოში'
#  'გატაცებული' 'ორი' 'ესპანელი' 'ბიზნესმენიდან' 'ერთ-ერთის' 'ნათესავებმა'
#  'გამოსასყიდი' 'გადაიხადეს' '.']
# [('*', 'Other'), ('*', 'Other'), ('*', 'Other'), ('15', 'Num'), ('სექტემბერს', 'N'), ('ესპანურმა', 'A'), ('პრესამ', 'N'), ('გაავრცელა', 'V'), ('ინფორმაცია', 'N'), ('იმის', 'Pron'), ('თაობაზე', 'Pp'), (',', 'Punct'), ('რომ', 'Cj'), ('შარშან', 'Adv'), ('საქართველოში', 'N'), ('გატაცებული', 'A'), ('ორი', 'Num'), ('ესპანელი', 'A'), ('ბიზნესმენიდან', 'N'), ('ერთ', 'A'), ('-', 'A'), ('ერთის', 'A'), ('ნათესავებმა', 'N'), ('გამოსასყიდი', 'N'), ('გადაიხადეს', 'V'), ('.', 'Punct')]
#
# ['გამიშლი' 'მფრინავ' 'ხალიჩას' ',' 'გადამატარებ' 'მთა-ველს' 'და' 'ჩვენ'
#  'ვიქნებით' 'ამაღამ' 'ვეებერთელა' 'მთვარე' '.']
# [('გამიშლი', 'A'), ('მფრინავ', 'A'), ('ხალიჩას', 'N'), (',', 'Punct'), ('გადამატარებ', 'V'), ('მთა', 'N'), ('-', 'N'), ('ველს', 'N'), ('და', 'Cj'), ('ჩვენ', 'Pron'), ('ვიქნებით', 'V'), ('ამაღამ', 'A'), ('ვეებერთელა', 'A'), ('მთვარე', 'V'), ('.', 'Punct')]
#
# ['მონტე-კრისტომ' 'ნიშნებით' 'გააფრთხილა' 'ალი' ';' 'ეს' 'უკანასკნელი'
#  'მიხვდა' ',' 'რომ' 'საფრთხე' 'ტუალეტის' 'ოთახის' 'მხრიდან' 'იყო' 'და'
#  'თავის' 'ბატონს' 'მიუახლოვდა' '.']
# [('მონტე', 'N'), ('-', 'N'), ('კრისტომ', 'N'), ('ნიშნებით', 'N'), ('გააფრთხილა', 'V'), ('ალი', 'N'), (';', 'Punct'), ('ეს', 'Pron'), ('უკანასკნელი', 'A'), ('მიხვდა', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('საფრთხე', 'N'), ('ტუალეტის', 'N'), ('ოთახის', 'N'), ('მხრიდან', 'N'), ('იყო', 'V'), ('და', 'Cj'), ('თავის', 'Pron'), ('ბატონს', 'N'), ('მიუახლოვდა', 'V'), ('.', 'Punct')]
#
# ['გაეროს' 'გენერალური' 'მდივნის' 'სპეციალურმა' 'წარმომადგენელმა' 'ჰეიდი'
#  'ტალიავინიმ' 'საქართველოში' 'მოღვაწეობა' 'დაასრულა' 'და' 'ამ' 'პოსტზე'
#  'ოთხწლიანი' 'მუშაობის' 'პერიოდში' 'ყველაზე' 'მნიშვნელოვან' 'მოვლენად'
#  'ქართულ-აფხაზური' 'დიალოგის' 'აღდგენა' 'და' '2001' 'წლიდან' 'შეჩერებული'
#  'საკოორდინაციო' 'საბჭოს' 'განახლება' 'დაასახელა' '.']
# [('გაეროს', 'N'), ('გენერალური', 'A'), ('მდივნის', 'N'), ('სპეციალურმა', 'A'), ('წარმომადგენელმა', 'N'), ('ჰეიდი', 'N'), ('ტალიავინიმ', 'N'), ('საქართველოში', 'N'), ('მოღვაწეობა', 'N'), ('დაასრულა', 'V'), ('და', 'Cj'), ('ამ', 'Pron'), ('პოსტზე', 'N'), ('ოთხწლიანი', 'A'), ('მუშაობის', 'N'), ('პერიოდში', 'N'), ('ყველაზე', 'A'), ('მნიშვნელოვან', 'A'), ('მოვლენად', 'N'), ('ქართულ', 'N'), ('-', 'N'), ('აფხაზური', 'N'), ('დიალოგის', 'N'), ('აღდგენა', 'N'), ('და', 'Cj'), ('2001', 'Num'), ('წლიდან', 'N'), ('შეჩერებული', 'A'), ('საკოორდინაციო', 'A'), ('საბჭოს', 'N'), ('განახლება', 'N'), ('დაასახელა', 'V'), ('.', 'Punct')]
#
# ['თავშიშველ-ფეხშიშველა' 'ის' 'ყვირილით' 'გარბოდა' 'კაციაანთ' 'სახლისაკენ'
#  ';' 'აი' ',' 'მივიდა' 'კიდეც' 'ამ' 'სახლთან' '.']
# [('თავშიშველ', 'N'), ('-', 'N'), ('ფეხშიშველა', 'N'), ('ის', 'Pron'), ('ყვირილით', 'N'), ('გარბოდა', 'V'), ('კაციაანთ', 'N'), ('სახლისაკენ', 'N'), (';', 'Punct'), ('აი', 'Adv'), (',', 'Punct'), ('მივიდა', 'V'), ('კიდეც', 'Adv'), ('ამ', 'Pron'), ('სახლთან', 'N'), ('.', 'Punct')]
#
# ['მე' 'ვცდილობდი' ',' 'გამედევნა' 'ეს' 'ბნელი' 'და' 'მავნებელი' 'ფიქრები'
#  ',' 'მაგრამ' 'სინიდისი' 'მდევნიდა' ',' 'მამხილებდა' 'ცოდვასა' ',' 'ერთსა'
#  'და' 'იმავე' 'დროს' 'გულს' 'მიქენჯნიდა' 'სვინდისი' ',' 'გონება-ღა' 'ჩემი'
#  'დაეძებდა' 'დაფარულ' 'მტრებსა' '.']
# [('მე', 'Pron'), ('ვცდილობდი', 'V'), (',', 'Punct'), ('გამედევნა', 'V'), ('ეს', 'Pron'), ('ბნელი', 'N'), ('და', 'Cj'), ('მავნებელი', 'A'), ('ფიქრები', 'N'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('სინიდისი', 'N'), ('მდევნიდა', 'V'), (',', 'Punct'), ('მამხილებდა', 'V'), ('ცოდვასა', 'N'), (',', 'Punct'), ('ერთსა', 'Num'), ('და', 'Cj'), ('იმავე', 'Pron'), ('დროს', 'N'), ('გულს', 'N'), ('მიქენჯნიდა', 'V'), ('სვინდისი', 'N'), (',', 'Punct'), ('გონება', 'N'), ('-', 'N'), ('ღა', 'N'), ('ჩემი', 'Pron'), ('დაეძებდა', 'V'), ('დაფარულ', 'A'), ('მტრებსა', 'N'), ('.', 'Punct')]
#
# ['რუსეთის' 'საგარეო' 'საქმეთა' 'სამინისტრო' 'პოზიტიურად' 'აფასებს'
#  'სტამბოლში' '21-22' 'მარტს' 'შერეული' 'საკონტროლოს' 'კომისიის' '(' 'შსკ'
#  ')' 'თანათავმჯდომარეთა' 'არაოფიციალური' 'შეხვედრის' 'შედეგებს' 'და'
#  'მიესალმება' 'მხარეთა' 'მზადყოფნას' 'გააგრძელონ' 'მოლაპარაკებათა'
#  'პროცესი' 'შსკ-ს' 'ფორმატში' '.']
# [('რუსეთის', 'N'), ('საგარეო', 'A'), ('საქმეთა', 'N'), ('სამინისტრო', 'N'), ('პოზიტიურად', 'A'), ('აფასებს', 'V'), ('სტამბოლში', 'N'), ('21', 'Num'), ('-', 'Num'), ('22', 'Num'), ('მარტს', 'N'), ('შერეული', 'A'), ('საკონტროლოს', 'A'), ('კომისიის', 'N'), ('(', 'Punct'), ('შსკ', 'A'), (')', 'Punct'), ('თანათავმჯდომარეთა', 'N'), ('არაოფიციალური', 'A'), ('შეხვედრის', 'N'), ('შედეგებს', 'N'), ('და', 'Cj'), ('მიესალმება', 'V'), ('მხარეთა', 'N'), ('მზადყოფნას', 'N'), ('გააგრძელონ', 'V'), ('მოლაპარაკებათა', 'N'), ('პროცესი', 'N'), ('შსკ', 'A'), ('-', 'N'), ('ს', 'N'), ('ფორმატში', 'N'), ('.', 'Punct')]
#
# ['ნიუ-იორკის' 'უნივერსიტეტში' 'ასწავლიდა' 'ახლა' 'ინგლისურს' '.']
# [('ნიუ', 'N'), ('-', 'N'), ('იორკის', 'N'), ('უნივერსიტეტში', 'N'), ('ასწავლიდა', 'V'), ('ახლა', 'Adv'), ('ინგლისურს', 'A'), ('.', 'Punct')]
#
# ['დედამისმა' 'კი' 'უმეტესი' 'ნაწილით' 'იყიდა' 'შესანიშნავი' 'ეტლი'
#  'თავისი' 'ოთხი' 'ცხენით' ',' 'ბრწყინვალე' 'ჩოხა-ახალუხი' 'გიგოსათვის' ','
#  'ოქრო-მკერდით' 'მოჭედილი' 'ქართული' 'კაბა' 'და' 'ჩიხტიკოპი' 'კი'
#  'თავისთვის' '.']
# [('დედამისმა', 'N'), ('კი', 'Adv'), ('უმეტესი', 'A'), ('ნაწილით', 'N'), ('იყიდა', 'V'), ('შესანიშნავი', 'A'), ('ეტლი', 'N'), ('თავისი', 'A'), ('ოთხი', 'Num'), ('ცხენით', 'N'), (',', 'Punct'), ('ბრწყინვალე', 'A'), ('ჩოხა', 'N'), ('-', 'N'), ('ახალუხი', 'N'), ('გიგოსათვის', 'N'), (',', 'Punct'), ('ოქრო', 'N'), ('-', 'N'), ('მკერდით', 'N'), ('მოჭედილი', 'N'), ('ქართული', 'A'), ('კაბა', 'N'), ('და', 'Cj'), ('ჩიხტიკოპი', 'N'), ('კი', 'Adv'), ('თავისთვის', 'N'), ('.', 'Punct')]
#
# [',' '25' 'მაისი' 'ამ' 'თემაზე-მწერლის' 'მუშაობაზე-ზოგი' 'მწერალი' 'მთელ'
#  'ტომს' 'დასწერდა' '.']
# [(',', 'Punct'), ('25', 'Num'), ('მაისი', 'N'), ('ამ', 'Pron'), ('თემაზე', 'N'), ('-', 'N'), ('მწერლის', 'N'), ('მუშაობაზე', 'N'), ('-', 'N'), ('ზოგი', 'N'), ('მწერალი', 'N'), ('მთელ', 'A'), ('ტომს', 'N'), ('დასწერდა', 'V'), ('.', 'Punct')]
#
# ['ახლა' 'რა' 'ხდე-ბა' '?']
# [('ახლა', 'Adv'), ('რა', 'Pron'), ('ხდე', 'N'), ('-', 'N'), ('ბა', 'N'), ('?', 'Punct')]
#
# ['ამის-თანანი' 'ჩვენში' 'ბევრნი' 'არიან' 'და' 'ზოგიერთთან' 'იმისთანა'
#  'გლეხობაა' ',' 'რომ' 'მარტო' 'საქონლის' 'მოშენებაღა' 'აქვთ' 'ცხოვრების'
#  'წყაროდ' '.']
# [('ამის', 'Pron'), ('-', 'N'), ('თანანი', 'N'), ('ჩვენში', 'Pron'), ('ბევრნი', 'A'), ('არიან', 'V'), ('და', 'Cj'), ('ზოგიერთთან', 'A'), ('იმისთანა', 'N'), ('გლეხობაა', 'N'), (',', 'Punct'), ('რომ', 'Cj'), ('მარტო', 'Adv'), ('საქონლის', 'N'), ('მოშენებაღა', 'N'), ('აქვთ', 'V'), ('ცხოვრების', 'N'), ('წყაროდ', 'N'), ('.', 'Punct')]
#
# ['მარტო' '16' ',' '20' ',' '22' 'ათასი' 'ჩვენი' 'ჯარისკაცი' '5' 'მლნ-იან'
#  'ქვეყანას' 'ვერ' 'დაიცავს' '.']
# [('მარტო', 'Adv'), ('16', 'Num'), (',', 'Punct'), ('20', 'Num'), (',', 'Punct'), ('22', 'Num'), ('ათასი', 'Num'), ('ჩვენი', 'Pron'), ('ჯარისკაცი', 'N'), ('5', 'Num'), ('მლნ', 'N'), ('-', 'N'), ('იან', 'N'), ('ქვეყანას', 'N'), ('ვერ', 'Adv'), ('დაიცავს', 'V'), ('.', 'Punct')]
#
# ['სახელმწიფო' 'მინისტრის' 'აპარატში' '„' 'სივილ' 'ჯორჯიას' '”' 'ასევე'
#  'აცნობეს' ',' 'რომ' 'სავარაუდოდ' ',' 'დღესვე' 'გაირკვევა'
#  'მერაბიშვილი-მინძაევის' 'შეხვედრის' 'ზუსტი' 'დრო' '.']
# [('სახელმწიფო', 'A'), ('მინისტრის', 'N'), ('აპარატში', 'N'), ('„', 'Punct'), ('სივილ', 'N'), ('ჯორჯიას', 'N'), ('”', 'Punct'), ('ასევე', 'Adv'), ('აცნობეს', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('სავარაუდოდ', 'A'), (',', 'Punct'), ('დღესვე', 'Adv'), ('გაირკვევა', 'V'), ('მერაბიშვილი', 'N'), ('-', 'N'), ('მინძაევის', 'N'), ('შეხვედრის', 'N'), ('ზუსტი', 'A'), ('დრო', 'N'), ('.', 'Punct')]
#
# ['30-ს' 'შუა-დღის' 'უკან' 'მივედით' 'გონიოში' '.']
# [('30', 'Num'), ('-', 'N'), ('ს', 'N'), ('შუა', 'N'), ('-', 'N'), ('დღის', 'N'), ('უკან', 'Adv'), ('მივედით', 'V'), ('გონიოში', 'N'), ('.', 'Punct')]
#
# ['ეს' 'და' 'ბევრი' 'ამისთანა' 'აზრი' 'რიგ-რიგად' 'მოსდიოდა' 'დურმიშხანს'
#  'და' 'ისე' 'ავიდა' 'ძეგვს' ',' 'რომ' 'ვერც-კი' 'გაიგო' '.']
# [('ეს', 'Pron'), ('და', 'Cj'), ('ბევრი', 'A'), ('ამისთანა', 'Pron'), ('აზრი', 'N'), ('რიგ', 'N'), ('-', 'A'), ('რიგად', 'A'), ('მოსდიოდა', 'V'), ('დურმიშხანს', 'N'), ('და', 'Cj'), ('ისე', 'Adv'), ('ავიდა', 'V'), ('ძეგვს', 'N'), (',', 'Punct'), ('რომ', 'Cj'), ('ვერც', 'Adv'), ('-', 'N'), ('კი', 'Adv'), ('გაიგო', 'V'), ('.', 'Punct')]
#
# ['ნიუ-იორკში' 'პრეზიდენტი' 'სააკაშვილი' 'და' 'საგარეო' 'საქმეთა'
#  'მინისტრი' 'შეხვდებიან' 'ნატოს' 'გენერალურ' 'მდივანს' 'ანდრეს' 'ფოგ'
#  'რასმუსენს' 'და' 'ევროკომისარს' 'საგარეო' 'პოლიტიკის' 'საკითხებში'
#  'ხავიერ' 'სოლანას' '.']
# [('ნიუ', 'N'), ('-', 'N'), ('იორკში', 'N'), ('პრეზიდენტი', 'N'), ('სააკაშვილი', 'N'), ('და', 'Cj'), ('საგარეო', 'A'), ('საქმეთა', 'N'), ('მინისტრი', 'N'), ('შეხვდებიან', 'V'), ('ნატოს', 'N'), ('გენერალურ', 'A'), ('მდივანს', 'N'), ('ანდრეს', 'N'), ('ფოგ', 'N'), ('რასმუსენს', 'N'), ('და', 'Cj'), ('ევროკომისარს', 'N'), ('საგარეო', 'A'), ('პოლიტიკის', 'N'), ('საკითხებში', 'N'), ('ხავიერ', 'N'), ('სოლანას', 'N'), ('.', 'Punct')]
#
# ['საქართველო' '„' 'მნიშვნელოვან' 'პრიორიტეტად' 'რჩება' '”' 'პრეზიდენტ'
#  'ობამას' 'ადმინისტრაციისთვის' ',' 'რომელიც' '„' 'ძალიან' 'მკაფიო'
#  'გზავნილს' 'აკეთებს' 'იმასთან' 'დაკავშირებით' ',' 'რომ' 'ჩვენ' 'მხარს'
#  'ვუჭერთ' 'საქართველოს' 'ხელისუფლებას' '”' ',' 'განაცხადა' 'აშშ-ის'
#  'სახელმწიფო' 'მდივანმა' 'ჰილარი' 'კლინტონმა' '.']
# [('საქართველო', 'N'), ('„', 'Punct'), ('მნიშვნელოვან', 'A'), ('პრიორიტეტად', 'N'), ('რჩება', 'V'), ('”', 'Punct'), ('პრეზიდენტ', 'N'), ('ობამას', 'N'), ('ადმინისტრაციისთვის', 'N'), (',', 'Punct'), ('რომელიც', 'Pron'), ('„', 'Punct'), ('ძალიან', 'Adv'), ('მკაფიო', 'A'), ('გზავნილს', 'N'), ('აკეთებს', 'V'), ('იმასთან', 'Pron'), ('დაკავშირებით', 'Pp'), (',', 'Punct'), ('რომ', 'Cj'), ('ჩვენ', 'Pron'), ('მხარს', 'N'), ('ვუჭერთ', 'V'), ('საქართველოს', 'N'), ('ხელისუფლებას', 'N'), ('”', 'Punct'), (',', 'Punct'), ('განაცხადა', 'V'), ('აშშ', 'N'), ('-', 'N'), ('ის', 'N'), ('სახელმწიფო', 'N'), ('მდივანმა', 'N'), ('ჰილარი', 'N'), ('კლინტონმა', 'N'), ('.', 'Punct')]
#
# ['ალექსეი-ალექსანდრე' 'თვითონაც' 'ვერ' 'მიმხვდარიყო' ',' 'რა' 'ეწეოდა'
#  'ამ' 'შავგვრემანი' 'ცისფერთვალება' 'ბიჭისკენ' ',' 'რომელიც' 'ყველასათვის'
#  'გაუგებარ' 'ესპანურ' 'ენაზე' 'ლაპარაკობდა' '.']
# [('ალექსეი', 'N'), ('-', 'N'), ('ალექსანდრე', 'N'), ('თვითონაც', 'Adv'), ('ვერ', 'Adv'), ('მიმხვდარიყო', 'V'), (',', 'Punct'), ('რა', 'Pron'), ('ეწეოდა', 'V'), ('ამ', 'Pron'), ('შავგვრემანი', 'N'), ('ცისფერთვალება', 'N'), ('ბიჭისკენ', 'N'), (',', 'Punct'), ('რომელიც', 'Pron'), ('ყველასათვის', 'A'), ('გაუგებარ', 'A'), ('ესპანურ', 'A'), ('ენაზე', 'N'), ('ლაპარაკობდა', 'V'), ('.', 'Punct')]
#
# ['სათაური' ':' 'ნარკვევი' '(' 'ჟურნალ-გაზეთებიდგან' ')' '.']
# [('სათაური', 'A'), (':', 'Punct'), ('ნარკვევი', 'N'), ('(', 'Punct'), ('ჟურნალ', 'N'), ('-', 'N'), ('გაზეთებიდგან', 'N'), (')', 'Punct'), ('.', 'Punct')]
#
# ['ფრენები' '2008' 'წლის' 'გაზაფხულზე' 'აღდგა' ',' 'თუმცა' 'მალევე'
#  'შეწყდა' 'რუსეთ-საქართველოს' 'აგვისტოს' 'ომის' 'შემდეგ' '.']
# [('ფრენები', 'N'), ('2008', 'Num'), ('წლის', 'N'), ('გაზაფხულზე', 'N'), ('აღდგა', 'V'), (',', 'Punct'), ('თუმცა', 'Cj'), ('მალევე', 'Adv'), ('შეწყდა', 'V'), ('რუსეთ', 'N'), ('-', 'N'), ('საქართველოს', 'N'), ('აგვისტოს', 'N'), ('ომის', 'N'), ('შემდეგ', 'Pp'), ('.', 'Punct')]
#
# ['კახეთ-ჰერეთისათვის' '1008' 'წელს' 'გურგენ' 'მეორე' 'გარდაიცვალა' 'და'
#  'სამხრეთ' 'საქართველოც' 'ბაგრატ' 'მესამემ' 'დაიმკვიდრა' '.']
# [('კახეთ', 'N'), ('-', 'N'), ('ჰერეთისათვის', 'N'), ('1008', 'Num'), ('წელს', 'N'), ('გურგენ', 'N'), ('მეორე', 'Num'), ('გარდაიცვალა', 'V'), ('და', 'Cj'), ('სამხრეთ', 'N'), ('საქართველოც', 'N'), ('ბაგრატ', 'N'), ('მესამემ', 'Num'), ('დაიმკვიდრა', 'V'), ('.', 'Punct')]
#
# ['2003' 'წლის' '6-7' 'მარტს' 'საქართველოსა' 'და' 'რუსეთის' 'პრეზიდენტების'
#  'სოჭში' 'შემდგარ' 'შეხვედრას' 'მაშინ' 'ორივე' 'მხარის' 'დადებითი'
#  'გამოხმაურება' 'მოჰყვა' '.']
# [('2003', 'Num'), ('წლის', 'N'), ('6', 'Num'), ('-', 'Num'), ('7', 'Num'), ('მარტს', 'N'), ('საქართველოსა', 'N'), ('და', 'Cj'), ('რუსეთის', 'N'), ('პრეზიდენტების', 'N'), ('სოჭში', 'N'), ('შემდგარ', 'A'), ('შეხვედრას', 'N'), ('მაშინ', 'Adv'), ('ორივე', 'Num'), ('მხარის', 'N'), ('დადებითი', 'A'), ('გამოხმაურება', 'N'), ('მოჰყვა', 'V'), ('.', 'Punct')]
#
# ['ივლიტა' 'დეიდას' 'ფაჩუნა' 'ნაბიჯებმა' ',' 'ლოცვა-ვედრებამ' ',' 'ხელახლა'
#  'მიაბრუნეს' 'იქით' ',' 'რასაც' 'გამოექცა' '…' 'მოხუცმა' 'თითქოს' 'იგრძნო'
#  'მისი' 'გასაჭირი' ',' 'თავად' 'შეუძახა' ',' 'შეუცაცხანა' ',' 'სული' 'არ'
#  'ჩაათქმევინა' ',' 'დავალებაც' 'მისცა' '.']
# [('ივლიტა', 'N'), ('დეიდას', 'N'), ('ფაჩუნა', 'N'), ('ნაბიჯებმა', 'N'), (',', 'Punct'), ('ლოცვა', 'N'), ('-', 'N'), ('ვედრებამ', 'N'), (',', 'Punct'), ('ხელახლა', 'Adv'), ('მიაბრუნეს', 'V'), ('იქით', 'Adv'), (',', 'Punct'), ('რასაც', 'Pron'), ('გამოექცა', 'V'), ('…', 'Punct'), ('მოხუცმა', 'N'), ('თითქოს', 'Cj'), ('იგრძნო', 'V'), ('მისი', 'Pron'), ('გასაჭირი', 'A'), (',', 'Punct'), ('თავად', 'Adv'), ('შეუძახა', 'V'), (',', 'Punct'), ('შეუცაცხანა', 'V'), (',', 'Punct'), ('სული', 'N'), ('არ', 'Adv'), ('ჩაათქმევინა', 'V'), (',', 'Punct'), ('დავალებაც', 'N'), ('მისცა', 'V'), ('.', 'Punct')]
#
# ['ყოველ' 'შემთხვევაში' ',' 'შემოქმედების' 'ერთ-ერთი' 'აუცილებელი' 'პირობა'
#  'შედეგებისადმი' 'გულგრილობა' 'უნდა' 'იყოს' ',' 'ალბათ' '.']
# [('ყოველ', 'A'), ('შემთხვევაში', 'N'), (',', 'Punct'), ('შემოქმედების', 'N'), ('ერთ', 'A'), ('-', 'A'), ('ერთი', 'A'), ('აუცილებელი', 'A'), ('პირობა', 'N'), ('შედეგებისადმი', 'N'), ('გულგრილობა', 'N'), ('უნდა', 'Pron'), ('იყოს', 'V'), (',', 'Punct'), ('ალბათ', 'Adv'), ('.', 'Punct')]
#
# ['28' 'მოთქმისა' ',' 'ტირილისაგან' 'მოაკლდეს' 'თვალთა' 'ნათელი' ','
#  'სიბრწყინვალე' 'და' 'სინათლე' ',' 'აღარა' 'ჰქონდეს' 'ნათელი' ',' 'ბაგე'
#  'და' 'კბილი' 'მოშლოდეს' ',' 'ძოწ-მარგალიტთა' 'ნათელი' ',' 'და' 'აწღა'
#  'ისმინეთ' 'სხვაცა' 'ვთქვა' 'ხელმწიფის' 'შემონათვალი' '.']
# [('28', 'Num'), ('მოთქმისა', 'N'), (',', 'Punct'), ('ტირილისაგან', 'N'), ('მოაკლდეს', 'V'), ('თვალთა', 'N'), ('ნათელი', 'N'), (',', 'Punct'), ('სიბრწყინვალე', 'N'), ('და', 'Cj'), ('სინათლე', 'N'), (',', 'Punct'), ('აღარა', 'Adv'), ('ჰქონდეს', 'V'), ('ნათელი', 'N'), (',', 'Punct'), ('ბაგე', 'N'), ('და', 'Cj'), ('კბილი', 'N'), ('მოშლოდეს', 'A'), (',', 'Punct'), ('ძოწ', 'N'), ('-', 'N'), ('მარგალიტთა', 'N'), ('ნათელი', 'N'), (',', 'Punct'), ('და', 'Cj'), ('აწღა', 'V'), ('ისმინეთ', 'V'), ('სხვაცა', 'A'), ('ვთქვა', 'V'), ('ხელმწიფის', 'N'), ('შემონათვალი', 'A'), ('.', 'Punct')]
#
# ['ყოველმა' 'ქართველმა' 'ბავშვმა' 'ზეპირად' 'იცის' 'დუტუ' 'მეგრელის'
#  'შესანიშ-ნავი' 'ლექსი' '„' 'პატარა' 'ქართველი' '”' '.']
# [('ყოველმა', 'A'), ('ქართველმა', 'A'), ('ბავშვმა', 'N'), ('ზეპირად', 'A'), ('იცის', 'V'), ('დუტუ', 'N'), ('მეგრელის', 'N'), ('შესანიშ', 'N'), ('-', 'N'), ('ნავი', 'N'), ('ლექსი', 'N'), ('„', 'Punct'), ('პატარა', 'A'), ('ქართველი', 'N'), ('”', 'Punct'), ('.', 'Punct')]
#
# ['ნუ' 'გაგიკვირდებათ' ',' 'განა' 'ცოტაა' 'ისეთი' 'ოჯახები' ',' 'ცოლ-ქმარი'
#  'რომ' 'ერთმანეთს' 'ღალატობს' 'და' 'მაინც' 'ერთად' 'ცხოვრობს' '?']
# [('ნუ', 'Adv'), ('გაგიკვირდებათ', 'V'), (',', 'Punct'), ('განა', 'Adv'), ('ცოტაა', 'Adv'), ('ისეთი', 'Pron'), ('ოჯახები', 'N'), (',', 'Punct'), ('ცოლ', 'N'), ('-', 'N'), ('ქმარი', 'N'), ('რომ', 'Cj'), ('ერთმანეთს', 'Pron'), ('ღალატობს', 'V'), ('და', 'Cj'), ('მაინც', 'Adv'), ('ერთად', 'Adv'), ('ცხოვრობს', 'V'), ('?', 'Punct')]
#
# ['აქედ-იქიდან' 'თოფის' 'ხმა' 'ისმოდა' '.']
# [('აქედ', 'Adv'), ('-', 'N'), ('იქიდან', 'Adv'), ('თოფის', 'N'), ('ხმა', 'N'), ('ისმოდა', 'V'), ('.', 'Punct')]
#
# ['კვლავ' 'იგრიალა' 'ჯარმა' 'და' 'მახმუტ-ბიის' 'ფუტკარივით' 'გარს'
#  'შემოეხვია' '.']
# [('კვლავ', 'N'), ('იგრიალა', 'N'), ('ჯარმა', 'N'), ('და', 'Cj'), ('მახმუტ', 'N'), ('-', 'N'), ('ბიის', 'N'), ('ფუტკარივით', 'N'), ('გარს', 'V'), ('შემოეხვია', 'V'), ('.', 'Punct')]
#
# ['ამის' 'შესახებ' 'თბილისმა' 'წელიწადზე' 'მეტია' 'რაც' 'რუსეთის'
#  'ფედერაციას' 'ოფიციალურად' 'მიმართა' 'და' 'შესაბამისი' 'სამთავრობო'
#  'კომისიაც' 'მუშაობს' 'პრემიერ-მინიტრის' 'ზურაბ' 'ნოღაიდელის'
#  'ხელმძღვანელობით' '.']
# [('ამის', 'Pron'), ('შესახებ', 'Pp'), ('თბილისმა', 'N'), ('წელიწადზე', 'N'), ('მეტია', 'A'), ('რაც', 'Pron'), ('რუსეთის', 'N'), ('ფედერაციას', 'N'), ('ოფიციალურად', 'A'), ('მიმართა', 'V'), ('და', 'Cj'), ('შესაბამისი', 'A'), ('სამთავრობო', 'A'), ('კომისიაც', 'N'), ('მუშაობს', 'V'), ('პრემიერ', 'N'), ('-', 'N'), ('მინიტრის', 'N'), ('ზურაბ', 'N'), ('ნოღაიდელის', 'N'), ('ხელმძღვანელობით', 'N'), ('.', 'Punct')]
#
# ['სადაც' 'კი' 'მიხვალ' ',' 'რჩევა' 'მიეც' ',' 'რომ' 'ფრთხილად' 'იყონ' ','
#  'მამის' 'სახელით' ',' 'გვარ-ტომობით' 'მიმართე' 'მებრძოლთ' ',' 'რიდით'
#  'მოეპყარ' ',' 'არავისთან' 'არ' 'იყოყოჩო' '.']
# [('სადაც', 'Adv'), ('კი', 'Adv'), ('მიხვალ', 'V'), (',', 'Punct'), ('რჩევა', 'N'), ('მიეც', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('ფრთხილად', 'A'), ('იყონ', 'V'), (',', 'Punct'), ('მამის', 'N'), ('სახელით', 'N'), (',', 'Punct'), ('გვარ', 'N'), ('-', 'N'), ('ტომობით', 'N'), ('მიმართე', 'Pp'), ('მებრძოლთ', 'N'), (',', 'Punct'), ('რიდით', 'V'), ('მოეპყარ', 'V'), (',', 'Punct'), ('არავისთან', 'Pron'), ('არ', 'Adv'), ('იყოყოჩო', 'V'), ('.', 'Punct')]
#
# ['7' 'სექტემბერს' '„' 'გაზპრომის' '”' 'ვებ-გვერდზე' 'გამოქვეყნებული'
#  'ინფორმაციის' 'თანახმად' ',' 'კომპანია' '2006' 'წლიდან' 'საქართველოს'
#  'ბუნებრივ' 'აირს' 'ევროპული' 'ფასებით' 'მიაწვდის' '.']
# [('7', 'Num'), ('სექტემბერს', 'N'), ('„', 'Punct'), ('გაზპრომის', 'N'), ('”', 'Punct'), ('ვებ', 'N'), ('-', 'N'), ('გვერდზე', 'N'), ('გამოქვეყნებული', 'A'), ('ინფორმაციის', 'N'), ('თანახმად', 'Pp'), (',', 'Punct'), ('კომპანია', 'N'), ('2006', 'Num'), ('წლიდან', 'N'), ('საქართველოს', 'N'), ('ბუნებრივ', 'A'), ('აირს', 'N'), ('ევროპული', 'A'), ('ფასებით', 'N'), ('მიაწვდის', 'V'), ('.', 'Punct')]
#
# ['აქეთ-იქით' 'მიმოიხედა' ',' 'ჩემი' 'ნახატებით' 'აჭრელებულ' 'კედლებს'
#  'ააყოლ-ჩააყოლა' 'მზერა' '.']
# [('აქეთ', 'Adv'), ('-', 'Adv'), ('იქით', 'Adv'), ('მიმოიხედა', 'V'), (',', 'Punct'), ('ჩემი', 'Pron'), ('ნახატებით', 'N'), ('აჭრელებულ', 'A'), ('კედლებს', 'N'), ('ააყოლ', 'V'), ('-', 'N'), ('ჩააყოლა', 'V'), ('მზერა', 'N'), ('.', 'Punct')]
#
# ['რუსეთის' 'სათათბიროს' 'დსთ-ს' 'საპარლამენტო' 'კომიტეტის' 'თავმჯდომარემ'
#  'ანდრეი' 'კოკოშინმა' 'საქართველოს' 'თავდაცვის' 'სამინისტროში' 'ახალი'
#  'დანიშვნების' 'ფონზე' 'შეშფოთება' 'გამოხატა' 'სამხრეთ' 'ოსეთისა' 'და'
#  'აფხაზეთის' 'თვითგამოცხადებულ' 'რესპუბლიკებში' 'სიტუაციის' 'შესაძლო'
#  'გართულების' 'თაობაზე' '.']
# [('რუსეთის', 'N'), ('სათათბიროს', 'N'), ('დსთ', 'N'), ('-', 'N'), ('ს', 'N'), ('საპარლამენტო', 'A'), ('კომიტეტის', 'N'), ('თავმჯდომარემ', 'N'), ('ანდრეი', 'N'), ('კოკოშინმა', 'N'), ('საქართველოს', 'N'), ('თავდაცვის', 'N'), ('სამინისტროში', 'N'), ('ახალი', 'A'), ('დანიშვნების', 'N'), ('ფონზე', 'N'), ('შეშფოთება', 'N'), ('გამოხატა', 'V'), ('სამხრეთ', 'N'), ('ოსეთისა', 'N'), ('და', 'Cj'), ('აფხაზეთის', 'N'), ('თვითგამოცხადებულ', 'A'), ('რესპუბლიკებში', 'N'), ('სიტუაციის', 'N'), ('შესაძლო', 'A'), ('გართულების', 'N'), ('თაობაზე', 'Pp'), ('.', 'Punct')]
#
# ['ყოველ' 'ამის' 'გამო' 'გამგეობამ' 'წარუდგინა' 'სამინისტროს' ',' 'რომ'
#  'ეს' 'რთული' 'და' 'ხარჯიანი' 'უკან' 'დევნა' 'მოსპობილ' 'იქნას' ','
#  'რადგანაც' 'მეტია' 'და' 'ყოფა-მდგომარეობა' 'საქმისა' 'არ' 'ითხოვს' '.']
# [('ყოველ', 'A'), ('ამის', 'Pron'), ('გამო', 'Pp'), ('გამგეობამ', 'N'), ('წარუდგინა', 'V'), ('სამინისტროს', 'N'), (',', 'Punct'), ('რომ', 'Cj'), ('ეს', 'Pron'), ('რთული', 'A'), ('და', 'Cj'), ('ხარჯიანი', 'A'), ('უკან', 'Pp'), ('დევნა', 'N'), ('მოსპობილ', 'N'), ('იქნას', 'V'), (',', 'Punct'), ('რადგანაც', 'Cj'), ('მეტია', 'A'), ('და', 'Cj'), ('ყოფა', 'N'), ('-', 'N'), ('მდგომარეობა', 'N'), ('საქმისა', 'N'), ('არ', 'Adv'), ('ითხოვს', 'V'), ('.', 'Punct')]
#
# ['ჰეიდი' 'ტალიავინის' 'განცხადებით' ',' 'ჟენევის' 'ფორმატში' 'მორიგი'
#  'მოლაპარაკებები' ',' 'რომელშიც' 'გაეროს' 'გენერალური' 'მდივნის'
#  'მეგობარი' 'ქვეყნების' 'საფრანგეთის' ',' 'გერმანიის' ',' 'რუსეთის' ','
#  'დიდი' 'ბრიტანეთისა' 'და' 'აშშ-ს' 'წარმომადგენლები' 'მონაწილეობენ' ','
#  'მარტისთვის' 'არის' 'დაგეგმილი' '.']
# [('ჰეიდი', 'N'), ('ტალიავინის', 'N'), ('განცხადებით', 'N'), (',', 'Punct'), ('ჟენევის', 'N'), ('ფორმატში', 'N'), ('მორიგი', 'A'), ('მოლაპარაკებები', 'N'), (',', 'Punct'), ('რომელშიც', 'Pron'), ('გაეროს', 'N'), ('გენერალური', 'A'), ('მდივნის', 'N'), ('მეგობარი', 'N'), ('ქვეყნების', 'N'), ('საფრანგეთის', 'N'), (',', 'Punct'), ('გერმანიის', 'N'), (',', 'Punct'), ('რუსეთის', 'N'), (',', 'Punct'), ('დიდი', 'N'), ('ბრიტანეთისა', 'N'), ('და', 'Cj'), ('აშშ', 'N'), ('-', 'N'), ('ს', 'N'), ('წარმომადგენლები', 'N'), ('მონაწილეობენ', 'V'), (',', 'Punct'), ('მარტისთვის', 'N'), ('არის', 'V'), ('დაგეგმილი', 'A'), ('.', 'Punct')]
#
# ['აქა-იქ' 'პირდაპირ' 'ქუჩაში' 'გამოედგათ' 'მაგიდები' 'თხილით' ','
#  'საპნითა' 'და' 'საპნისავე' 'მსგავსი' 'თაფლპურებით' ';' 'სად' 'სამიკიტნო'
#  'იყო' 'ზედ' 'გამოხატული' 'მსუქანი' 'თევზითა' 'და' 'თევზის' 'ზურგში'
#  'ჩარჭობილი' 'ჩანგლით' '.']
# [('აქა', 'Adv'), ('-', 'Adv'), ('იქ', 'Adv'), ('პირდაპირ', 'Adv'), ('ქუჩაში', 'N'), ('გამოედგათ', 'N'), ('მაგიდები', 'N'), ('თხილით', 'N'), (',', 'Punct'), ('საპნითა', 'N'), ('და', 'Cj'), ('საპნისავე', 'N'), ('მსგავსი', 'A'), ('თაფლპურებით', 'N'), (';', 'Punct'), ('სად', 'N'), ('სამიკიტნო', 'N'), ('იყო', 'V'), ('ზედ', 'A'), ('გამოხატული', 'A'), ('მსუქანი', 'A'), ('თევზითა', 'N'), ('და', 'Cj'), ('თევზის', 'N'), ('ზურგში', 'N'), ('ჩარჭობილი', 'N'), ('ჩანგლით', 'N'), ('.', 'Punct')]
#
# ['ჩემი' 'სული' 'კი' 'გავყიდე' 'და' 'იმით' 'ბინა' 'ვიყიდე-გავარემონტე' '.']
# [('ჩემი', 'Pron'), ('სული', 'N'), ('კი', 'Adv'), ('გავყიდე', 'V'), ('და', 'Cj'), ('იმით', 'Adv'), ('ბინა', 'N'), ('ვიყიდე', 'V'), ('-', 'N'), ('გავარემონტე', 'N'), ('.', 'Punct')]
#
# ['საქართველოს' 'ხელისუფლება' 'საგანგებო' 'მდგომარეობას' 'ორ' 'ან' 'სამ'
#  'დღეში' 'მოხსნის' ',' 'განაცხადა' 'აშშ-ს' 'სახელმწიფო' 'მდივნის'
#  'თანაშემწის' 'მოადგილემ' 'ევროპისა' 'და' 'ევრაზიის' 'საკითხებში' 'მეთიუ'
#  'ბრაიზამ' '13' 'ნოემბერს' 'თბილისში' '.']
# [('საქართველოს', 'N'), ('ხელისუფლება', 'N'), ('საგანგებო', 'A'), ('მდგომარეობას', 'N'), ('ორ', 'Num'), ('ან', 'Cj'), ('სამ', 'Num'), ('დღეში', 'N'), ('მოხსნის', 'N'), (',', 'Punct'), ('განაცხადა', 'V'), ('აშშ', 'N'), ('-', 'N'), ('ს', 'N'), ('სახელმწიფო', 'A'), ('მდივნის', 'N'), ('თანაშემწის', 'N'), ('მოადგილემ', 'N'), ('ევროპისა', 'N'), ('და', 'Cj'), ('ევრაზიის', 'N'), ('საკითხებში', 'N'), ('მეთიუ', 'N'), ('ბრაიზამ', 'N'), ('13', 'Num'), ('ნოემბერს', 'N'), ('თბილისში', 'N'), ('.', 'Punct')]
#
# ['ამა' 'წლის' 'მარტში' ',' 'ერაყში' 'ომის' 'დაწყებამდე' 'საქართველოს'
#  'საჰაერო' 'სივრცეში' 'სამჯერ' 'შემოვიდა' 'აშშ-ის' 'მზვერავი'
#  'თვითმფრინავი' 'რამაც' 'რუსეთის' 'შეშფოთება' 'მოჰყვა' '.']
# [('ამა', 'Pron'), ('წლის', 'N'), ('მარტში', 'N'), (',', 'Punct'), ('ერაყში', 'N'), ('ომის', 'N'), ('დაწყებამდე', 'N'), ('საქართველოს', 'N'), ('საჰაერო', 'A'), ('სივრცეში', 'N'), ('სამჯერ', 'Adv'), ('შემოვიდა', 'V'), ('აშშ', 'N'), ('-', 'N'), ('ის', 'N'), ('მზვერავი', 'N'), ('თვითმფრინავი', 'N'), ('რამაც', 'Pron'), ('რუსეთის', 'N'), ('შეშფოთება', 'N'), ('მოჰყვა', 'V'), ('.', 'Punct')]
#
# ['ქართული' 'დასის' 'ლიდერი' 'ჯონდი' 'ბაღათურია' 'ასევე' 'ყოყმანობს'
#  'პარლამენტში' 'შესვლა-არ' 'შესვლაზე' '.']
# [('ქართული', 'A'), ('დასის', 'N'), ('ლიდერი', 'N'), ('ჯონდი', 'N'), ('ბაღათურია', 'N'), ('ასევე', 'Adv'), ('ყოყმანობს', 'V'), ('პარლამენტში', 'N'), ('შესვლა', 'N'), ('-', 'N'), ('არ', 'Adv'), ('შესვლაზე', 'N'), ('.', 'Punct')]
#
# ['კიდევ' 'კარგი' ',' 'სიკო-ტორპედომ' 'ეს' 'მოგვიწყო' ',' 'თორემ' 'როდემდე'
#  'უნდა' 'გვეყიდა' 'პატრონის' 'ჰეროინი' 'და' 'თან' 'შიმშილით' 'სული'
#  'ამოგვსვლოდა' '?' '!']
# [('კიდევ', 'Adv'), ('კარგი', 'N'), (',', 'Punct'), ('სიკო', 'N'), ('-', 'N'), ('ტორპედომ', 'N'), ('ეს', 'Pron'), ('მოგვიწყო', 'V'), (',', 'Punct'), ('თორემ', 'Cj'), ('როდემდე', 'Adv'), ('უნდა', 'Pron'), ('გვეყიდა', 'V'), ('პატრონის', 'N'), ('ჰეროინი', 'N'), ('და', 'Cj'), ('თან', 'Adv'), ('შიმშილით', 'N'), ('სული', 'N'), ('ამოგვსვლოდა', 'V'), ('?', 'Punct'), ('!', 'Punct')]
#
# ['გადასვლა' 'არასდროს' 'უფიქრია' ';' 'ღამის' 'ბინდბუნდში' ',' 'ჩაბნელებულ'
#  'ხეთა' 'წვეროებს' 'მიღმა' ',' 'ელექტროშუქით' 'განათებულ' 'წითელკრამიტიან'
#  'ოდა-სახლებში' 'მხიარული' ',' 'უდარდელი' 'ხმები' 'ისმოდა' ',' 'მტრული'
#  ',' 'ძნელად' 'შესაგუებელი' 'გრძნობა' 'გაუჩნდა' '.']
# [('გადასვლა', 'N'), ('არასდროს', 'Adv'), ('უფიქრია', 'V'), (';', 'Punct'), ('ღამის', 'N'), ('ბინდბუნდში', 'N'), (',', 'Punct'), ('ჩაბნელებულ', 'A'), ('ხეთა', 'N'), ('წვეროებს', 'N'), ('მიღმა', 'Pp'), (',', 'Punct'), ('ელექტროშუქით', 'N'), ('განათებულ', 'A'), ('წითელკრამიტიან', 'A'), ('ოდა', 'N'), ('-', 'N'), ('სახლებში', 'N'), ('მხიარული', 'A'), (',', 'Punct'), ('უდარდელი', 'A'), ('ხმები', 'N'), ('ისმოდა', 'V'), (',', 'Punct'), ('მტრული', 'A'), (',', 'Punct'), ('ძნელად', 'A'), ('შესაგუებელი', 'A'), ('გრძნობა', 'N'), ('გაუჩნდა', 'V'), ('.', 'Punct')]
#
# ['როგორც' 'თავდაცვის' 'მინისტრმა' 'გელა' 'ბეჟუაშვილმა' 'განაცხადა'
#  'ბათუმიდან' 'წამოსული' 'ოფიცრებისა' 'და' 'ჯარისკაცების' 'საფუძველზე'
#  'თბილისში' 'შეიქმნება' '25-ე' 'ბრიგადა' '.']
# [('როგორც', 'Cj'), ('თავდაცვის', 'N'), ('მინისტრმა', 'N'), ('გელა', 'N'), ('ბეჟუაშვილმა', 'N'), ('განაცხადა', 'V'), ('ბათუმიდან', 'N'), ('წამოსული', 'A'), ('ოფიცრებისა', 'N'), ('და', 'Cj'), ('ჯარისკაცების', 'N'), ('საფუძველზე', 'N'), ('თბილისში', 'N'), ('შეიქმნება', 'V'), ('25', 'Num'), ('-', 'Num'), ('ე', 'Num'), ('ბრიგადა', 'N'), ('.', 'Punct')]
#
# ['გული' 'სიხარულით' 'ევსებოდა' ',' 'სიტყვა-კი' 'ვერ' 'დაეძრა' 'ბიჭის'
#  'სანუგეშებელი' ':' 'რცხვენოდა' ',' 'მთლად' 'გაეზიარებინა' 'ბიჭისათვის'
#  'თავისი' 'გულის' 'ნადები' '.']
# [('გული', 'N'), ('სიხარულით', 'N'), ('ევსებოდა', 'V'), (',', 'Punct'), ('სიტყვა', 'N'), ('-', 'N'), ('კი', 'Adv'), ('ვერ', 'Adv'), ('დაეძრა', 'V'), ('ბიჭის', 'N'), ('სანუგეშებელი', 'A'), (':', 'Punct'), ('რცხვენოდა', 'V'), (',', 'Punct'), ('მთლად', 'Adv'), ('გაეზიარებინა', 'V'), ('ბიჭისათვის', 'N'), ('თავისი', 'Pron'), ('გულის', 'N'), ('ნადები', 'N'), ('.', 'Punct')]
#
# ['პირველ' 'წელს' 'რომ' 'მოხნა' ',' 'უძველესი' 'დროის' 'ნივთების'
#  'რაღაც-რაღაც' 'ნატეხები' 'იპოვა' '.']
# [('პირველ', 'Num'), ('წელს', 'N'), ('რომ', 'Cj'), ('მოხნა', 'N'), (',', 'Punct'), ('უძველესი', 'A'), ('დროის', 'N'), ('ნივთების', 'N'), ('რაღაც', 'Pron'), ('-', 'Pron'), ('რაღაც', 'Pron'), ('ნატეხები', 'N'), ('იპოვა', 'V'), ('.', 'Punct')]
#
# ['დასასრულ' ',' 'შეიძლება' 'ითქვას' ',' 'რომ' 'ხელოვნება' 'მართლაც'
#  'გულისხმობს' 'ორივე' 'კომპონენტს-მიბაძვასა' 'და' 'ქმნას' ',' 'მაგრამ'
#  'მხოლოდ' 'იმდენად' ',' 'რამდენადაც' 'შემფასებელი' 'შეძლებს' 'მის'
#  'აღქმას' '.']
# [('დასასრულ', 'A'), (',', 'Punct'), ('შეიძლება', 'V'), ('ითქვას', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('ხელოვნება', 'N'), ('მართლაც', 'Adv'), ('გულისხმობს', 'V'), ('ორივე', 'Num'), ('კომპონენტს', 'N'), ('-', 'N'), ('მიბაძვასა', 'N'), ('და', 'Cj'), ('ქმნას', 'V'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('მხოლოდ', 'Adv'), ('იმდენად', 'Adv'), (',', 'Punct'), ('რამდენადაც', 'Adv'), ('შემფასებელი', 'A'), ('შეძლებს', 'V'), ('მის', 'Pron'), ('აღქმას', 'N'), ('.', 'Punct')]
#
# ['მრჩეველნი' 'შეკრიბო' 'და' 'ვაითუ' 'მერე' 'იყბედონ' 'აქა-იქ' '.']
# [('მრჩეველნი', 'N'), ('შეკრიბო', 'V'), ('და', 'Cj'), ('ვაითუ', 'V'), ('მერე', 'Adv'), ('იყბედონ', 'V'), ('აქა', 'Adv'), ('-', 'Adv'), ('იქ', 'Adv'), ('.', 'Punct')]
#
# ['ამის' 'ანგარიში' 'მოვთხოვეთ' 'ხაზინის' 'იქ' 'დამსწრე' 'მოხელეებს' ','
#  'შეიქმნა' 'მიძებნ-მოძებნა' 'და' 'ლაპარაკი' ',' 'მაგრამ' 'ყუთი' 'არ'
#  'აღმოჩნდა' '.']
# [('ამის', 'Pron'), ('ანგარიში', 'N'), ('მოვთხოვეთ', 'V'), ('ხაზინის', 'N'), ('იქ', 'Adv'), ('დამსწრე', 'V'), ('მოხელეებს', 'N'), (',', 'Punct'), ('შეიქმნა', 'V'), ('მიძებნ', 'N'), ('-', 'N'), ('მოძებნა', 'N'), ('და', 'Cj'), ('ლაპარაკი', 'N'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('ყუთი', 'N'), ('არ', 'Adv'), ('აღმოჩნდა', 'V'), ('.', 'Punct')]
#
# ['მისი' 'თქმით' ',' 'ყაზახეთის' 'პრეზიდენტთან' 'შეხვედრისას' 'დსთ-ს'
#  'რეფორმირების' 'საკითხიც' 'განიხილებოდა' '.']
# [('მისი', 'Pron'), ('თქმით', 'N'), (',', 'Punct'), ('ყაზახეთის', 'N'), ('პრეზიდენტთან', 'N'), ('შეხვედრისას', 'N'), ('დსთ', 'N'), ('-', 'N'), ('ს', 'N'), ('რეფორმირების', 'N'), ('საკითხიც', 'N'), ('განიხილებოდა', 'V'), ('.', 'Punct')]
#
# ['აქედან' 'გამომდინ-რე' ',' 'უნდა' 'ითქვას' ',' 'რომ' 'ერთი' 'თიხის'
#  'ჯამი' 'ბევრად' 'უფრო' 'ძვირი' 'უნდა' 'ღირდეს' ',' 'ვიდრე' 'მისი' 'წონის'
#  'ხორბალი' '.']
# [('აქედან', 'Adv'), ('გამომდინ', 'N'), ('-', 'N'), ('რე', 'N'), (',', 'Punct'), ('უნდა', 'Pron'), ('ითქვას', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('ერთი', 'Num'), ('თიხის', 'N'), ('ჯამი', 'N'), ('ბევრად', 'Adv'), ('უფრო', 'Adv'), ('ძვირი', 'N'), ('უნდა', 'Pron'), ('ღირდეს', 'V'), (',', 'Punct'), ('ვიდრე', 'Cj'), ('მისი', 'Pron'), ('წონის', 'N'), ('ხორბალი', 'N'), ('.', 'Punct')]
#
# ['ამასობაში' 'მოსკოვის' 'მისადგომებთან' 'სულს' 'ღაფავდა' 'ყველა'
#  'შესაძლებელი' 'რესურსი' ':' 'რეგულარული' 'არმიის' 'გარდა' ',' 'სახალხო'
#  'რაზმელები' ',' 'სამხედრო' 'სასწავლებლების' 'კურსანტები' ',' 'მილიცია'
#  '…' 'ვოლოკოლამსკის' 'მიმართულებას' 'იცავდა' 'გენერალ' 'პანფილოვის'
#  '316-ე' 'მსროლელთა' 'დივიზია' '.']
# [('ამასობაში', 'Adv'), ('მოსკოვის', 'N'), ('მისადგომებთან', 'N'), ('სულს', 'N'), ('ღაფავდა', 'V'), ('ყველა', 'A'), ('შესაძლებელი', 'A'), ('რესურსი', 'N'), (':', 'Punct'), ('რეგულარული', 'A'), ('არმიის', 'N'), ('გარდა', 'Pp'), (',', 'Punct'), ('სახალხო', 'A'), ('რაზმელები', 'N'), (',', 'Punct'), ('სამხედრო', 'A'), ('სასწავლებლების', 'N'), ('კურსანტები', 'N'), (',', 'Punct'), ('მილიცია', 'N'), ('…', 'Punct'), ('ვოლოკოლამსკის', 'N'), ('მიმართულებას', 'N'), ('იცავდა', 'V'), ('გენერალ', 'N'), ('პანფილოვის', 'N'), ('316', 'Num'), ('-', 'Num'), ('ე', 'Num'), ('მსროლელთა', 'N'), ('დივიზია', 'N'), ('.', 'Punct')]
#
# ['სპეცსამსახურის' 'დაწერილ-დაუწერელი' 'კანონები' 'მას' 'შესანიშნავად'
#  'მოეხსენებოდა' '.']
# [('სპეცსამსახურის', 'N'), ('დაწერილ', 'N'), ('-', 'N'), ('დაუწერელი', 'N'), ('კანონები', 'N'), ('მას', 'Pron'), ('შესანიშნავად', 'A'), ('მოეხსენებოდა', 'V'), ('.', 'Punct')]
#
# ['დღევანდელ' 'მოლაპარაკებებამდე' 'მედვედკოვი' 'აცხადებდა' ',' 'რომ'
#  'მოსკოვი' 'მხოლოდ' 'ვმო-ში' 'გაწევრიანების' 'შემდეგ' 'შეძლებს' 'ამ'
#  'საკითხის' 'მოგვარებას' '.']
# [('დღევანდელ', 'A'), ('მოლაპარაკებებამდე', 'N'), ('მედვედკოვი', 'N'), ('აცხადებდა', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('მოსკოვი', 'N'), ('მხოლოდ', 'Adv'), ('ვმო', 'N'), ('-', 'N'), ('ში', 'N'), ('გაწევრიანების', 'N'), ('შემდეგ', 'Pp'), ('შეძლებს', 'V'), ('ამ', 'Pron'), ('საკითხის', 'N'), ('მოგვარებას', 'N'), ('.', 'Punct')]
#
# ['სავარაუდოდ' ',' 'უახლოეს' 'კვირებში' '„' 'დედაქალაქის-თბილისის'
#  'შესახებ' '”' 'კანონპროექტს' 'პარლამენტის' 'პლენარული' 'სხდომა'
#  'განიხილავს' 'და' 'მიიღებს' '.']
# [('სავარაუდოდ', 'A'), (',', 'Punct'), ('უახლოეს', 'A'), ('კვირებში', 'N'), ('„', 'Punct'), ('დედაქალაქის', 'N'), ('-', 'N'), ('თბილისის', 'N'), ('შესახებ', 'Pp'), ('”', 'Punct'), ('კანონპროექტს', 'N'), ('პარლამენტის', 'N'), ('პლენარული', 'A'), ('სხდომა', 'N'), ('განიხილავს', 'V'), ('და', 'Cj'), ('მიიღებს', 'V'), ('.', 'Punct')]
#
# ['საქართველოს' 'კათოლიკოს-პატრიარქი' 'ილია' 'მეორე' '9' 'დეკემბერს'
#  'მოსკოვში' 'რუსეთის' 'პრეზიდენტს' 'დიმიტრი' 'მედვედევს' 'შეხვდა' '.']
# [('საქართველოს', 'N'), ('კათოლიკოს', 'N'), ('-', 'N'), ('პატრიარქი', 'N'), ('ილია', 'N'), ('მეორე', 'Num'), ('9', 'Num'), ('დეკემბერს', 'N'), ('მოსკოვში', 'N'), ('რუსეთის', 'N'), ('პრეზიდენტს', 'N'), ('დიმიტრი', 'N'), ('მედვედევს', 'N'), ('შეხვდა', 'V'), ('.', 'Punct')]
#
# ['ნუ' 'თუ' 'დაჰვიწყებია' 'პურ-მარილი' 'და' 'მთის' 'ხალხის' 'ჩვეულება' ','
#  'რომელიც' ',' 'გარდა' 'ოსებისა' ',' 'ისე' 'წმინდად' 'ინახება'
#  'ყველასაგან' '?']
# [('ნუ', 'Cj'), ('თუ', 'Cj'), ('დაჰვიწყებია', 'V'), ('პურ', 'N'), ('-', 'N'), ('მარილი', 'N'), ('და', 'Cj'), ('მთის', 'N'), ('ხალხის', 'N'), ('ჩვეულება', 'N'), (',', 'Punct'), ('რომელიც', 'Pron'), (',', 'Punct'), ('გარდა', 'Pp'), ('ოსებისა', 'N'), (',', 'Punct'), ('ისე', 'Adv'), ('წმინდად', 'A'), ('ინახება', 'V'), ('ყველასაგან', 'A'), ('?', 'Punct')]
#
# ['ურჩევს' ':' '„' 'ნინო' ',' 'ცოტა' 'გააქნიე-გამოაქნიე' 'თავი' 'და'
#  'კარგად' 'გახდები' '”' '.']
# [('ურჩევს', 'V'), (':', 'Punct'), ('„', 'Punct'), ('ნინო', 'N'), (',', 'Punct'), ('ცოტა', 'Adv'), ('გააქნიე', 'V'), ('-', 'N'), ('გამოაქნიე', 'V'), ('თავი', 'N'), ('და', 'Cj'), ('კარგად', 'A'), ('გახდები', 'V'), ('”', 'Punct'), ('.', 'Punct')]
#
# ['ხომ' 'ხედავ' 'ისეთ' 'დღეში' 'ვარ' 'თავი' 'ზომაში' 'გამიორმაგდა-თქო'
#  'ასე' 'მგონია' '.']
# [('ხომ', 'Adv'), ('ხედავ', 'V'), ('ისეთ', 'Pron'), ('დღეში', 'N'), ('ვარ', 'V'), ('თავი', 'N'), ('ზომაში', 'N'), ('გამიორმაგდა', 'N'), ('-', 'V'), ('თქო', 'V'), ('ასე', 'Adv'), ('მგონია', 'V'), ('.', 'Punct')]
#
# ['სამი' 'დაცლილი' 'იყო' 'და' 'ერთიდამ-ღა' 'აწვდიდნენ' 'თივასა' '.']
# [('სამი', 'Num'), ('დაცლილი', 'A'), ('იყო', 'V'), ('და', 'Cj'), ('ერთიდამ', 'N'), ('-', 'N'), ('ღა', 'N'), ('აწვდიდნენ', 'V'), ('თივასა', 'N'), ('.', 'Punct')]
#
# ['როგორც' 'ცნობილია' 'ტრაგედიის' 'დროს' 'მას' 'თან' 'არ' 'ახლდა' 'დაცვა'
#  ',' 'რომელიც' ',' 'ჟვანიას' 'პირად' 'მძღოლთან' 'ერთად' ','
#  'პრემიერ-მინისტრს' ',' 'ოფიციალური' 'ინფორმაციით' ',' 'გარეთ' 'ელოდებოდა'
#  '.']
# [('როგორც', 'Cj'), ('ცნობილია', 'A'), ('ტრაგედიის', 'N'), ('დროს', 'N'), ('მას', 'Pron'), ('თან', 'Adv'), ('არ', 'Adv'), ('ახლდა', 'V'), ('დაცვა', 'N'), (',', 'Punct'), ('რომელიც', 'Pron'), (',', 'Punct'), ('ჟვანიას', 'N'), ('პირად', 'Pp'), ('მძღოლთან', 'N'), ('ერთად', 'Pp'), (',', 'Punct'), ('პრემიერ', 'N'), ('-', 'N'), ('მინისტრს', 'N'), (',', 'Punct'), ('ოფიციალური', 'A'), ('ინფორმაციით', 'N'), (',', 'Punct'), ('გარეთ', 'Adv'), ('ელოდებოდა', 'V'), ('.', 'Punct')]
#
# ['ასევე' 'დაგეგმილია' 'შეხვედრები' 'პრეზიდენტ' 'სააკაშვილთან' ','
#  'პარლამენტის' 'თავმჯდომარესთან' 'ნინო' 'ბურჯანაძესთან' 'და'
#  'პრემიერ-მინისტრთან' 'ზურაბ' 'ნოღაიდელთან' '.']
# [('ასევე', 'Adv'), ('დაგეგმილია', 'A'), ('შეხვედრები', 'N'), ('პრეზიდენტ', 'N'), ('სააკაშვილთან', 'N'), (',', 'Punct'), ('პარლამენტის', 'N'), ('თავმჯდომარესთან', 'N'), ('ნინო', 'N'), ('ბურჯანაძესთან', 'N'), ('და', 'Cj'), ('პრემიერ', 'N'), ('-', 'N'), ('მინისტრთან', 'N'), ('ზურაბ', 'N'), ('ნოღაიდელთან', 'N'), ('.', 'Punct')]
#
# ['მისმა' 'სიტ-ყვებმა' 'უარყოფითი' 'შთაბეჭდილება' 'იქონიეს' 'ჩვენზე' '.']
# [('მისმა', 'Pron'), ('სიტ', 'N'), ('-', 'N'), ('ყვებმა', 'N'), ('უარყოფითი', 'A'), ('შთაბეჭდილება', 'N'), ('იქონიეს', 'V'), ('ჩვენზე', 'Pron'), ('.', 'Punct')]
#
# ['ჩვეულებრივ' 'პაგო-პაგოში' 'დავდივარ' ',' 'მაგრამ' 'ახლა' 'იქაურობას'
#  'ყვავილი' 'მოედო' 'და' 'ყველაფერი' 'ჩაკვდა' '.']
# [('ჩვეულებრივ', 'A'), ('პაგო', 'N'), ('-', 'N'), ('პაგოში', 'N'), ('დავდივარ', 'V'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('ახლა', 'Adv'), ('იქაურობას', 'N'), ('ყვავილი', 'N'), ('მოედო', 'N'), ('და', 'Cj'), ('ყველაფერი', 'A'), ('ჩაკვდა', 'V'), ('.', 'Punct')]
#
# ['აღსანიშნავია' 'ისიც' ',' 'რომ' 'მსოფლიოს' 'ძირითადი' 'ენების' '/'
#  'კილოების' 'სტატუსი' 'გაირკვა' 'ისტორიულ-შედარებითი' 'ენათმეცნიერების'
#  'მეთოდოლოგიის' 'ჩამოყალიბებამდე' 'დიდი' 'ხნით' 'ადრე' 'და' ',' 'იშვიათი'
#  'გამონაკლისების' 'გარდა' ',' 'არავინ' 'ცდილობს' 'ამ' 'სტატუსთა'
#  'გადასინჯვას' '.']
# [('აღსანიშნავია', 'A'), ('ისიც', 'Pron'), (',', 'Punct'), ('რომ', 'Cj'), ('მსოფლიოს', 'N'), ('ძირითადი', 'A'), ('ენების', 'N'), ('/', 'Other'), ('კილოების', 'N'), ('სტატუსი', 'N'), ('გაირკვა', 'V'), ('ისტორიულ', 'N'), ('-', 'N'), ('შედარებითი', 'Adv'), ('ენათმეცნიერების', 'N'), ('მეთოდოლოგიის', 'N'), ('ჩამოყალიბებამდე', 'N'), ('დიდი', 'A'), ('ხნით', 'N'), ('ადრე', 'Adv'), ('და', 'Cj'), (',', 'Punct'), ('იშვიათი', 'A'), ('გამონაკლისების', 'N'), ('გარდა', 'Pp'), (',', 'Punct'), ('არავინ', 'Pron'), ('ცდილობს', 'V'), ('ამ', 'Pron'), ('სტატუსთა', 'N'), ('გადასინჯვას', 'N'), ('.', 'Punct')]
#
# ['მსგავსი' 'პრობლემის' 'წინაშე' 'აღმოჩნდა' '20-ე' 'საუკუნის' 'ერთ-ერთი'
#  'ყველაზე' 'ცნობილი' 'ეთნოლოგი' 'ვიქტორ' 'ტრენერი' ',' 'რომლის'
#  'სამეცნიერო' 'რეფლექსიის' 'მთავარი' 'საგანი' 'რიტუალი' 'იყო' '.']
# [('მსგავსი', 'A'), ('პრობლემის', 'N'), ('წინაშე', 'Pp'), ('აღმოჩნდა', 'V'), ('20', 'Num'), ('-', 'Num'), ('ე', 'Num'), ('საუკუნის', 'N'), ('ერთ', 'A'), ('-', 'Num'), ('ერთი', 'A'), ('ყველაზე', 'A'), ('ცნობილი', 'A'), ('ეთნოლოგი', 'N'), ('ვიქტორ', 'N'), ('ტრენერი', 'N'), (',', 'Punct'), ('რომლის', 'Pron'), ('სამეცნიერო', 'A'), ('რეფლექსიის', 'N'), ('მთავარი', 'A'), ('საგანი', 'N'), ('რიტუალი', 'N'), ('იყო', 'V'), ('.', 'Punct')]
#
# ['მისი' 'წინასახეა' 'ფრანგი' 'ფილოსოფოსი' 'უილიამ' 'შერვუდი' '('
#  '1200-1249' ')' ',' 'რომლის' 'ლოგიკის' 'სახელმძღვანელო' 'მეცხრამეტე'
#  'საუკუნეში' 'აღმოაჩინეს' ',' 'გამოცემით' 'კი' 'ფატალურ' '1937' 'წელს'
#  'გამოიცა' '.']
# [('მისი', 'Pron'), ('წინასახეა', 'N'), ('ფრანგი', 'A'), ('ფილოსოფოსი', 'N'), ('უილიამ', 'N'), ('შერვუდი', 'N'), ('(', 'Punct'), ('1200', 'Num'), ('-', 'Num'), ('1249', 'Num'), (')', 'Punct'), (',', 'Punct'), ('რომლის', 'Pron'), ('ლოგიკის', 'N'), ('სახელმძღვანელო', 'N'), ('მეცხრამეტე', 'Num'), ('საუკუნეში', 'N'), ('აღმოაჩინეს', 'V'), (',', 'Punct'), ('გამოცემით', 'N'), ('კი', 'Adv'), ('ფატალურ', 'N'), ('1937', 'Num'), ('წელს', 'N'), ('გამოიცა', 'V'), ('.', 'Punct')]
#
# ['ბარნოვის' 'მხატვრული' 'სისტემა' 'მრავალ' 'თავისებურებას' 'მოიცავს' 'და'
#  'ერთ-ერთიც' 'ესაა' ',' 'ერთ-ერთიცა' 'და' 'ძირითადიცა-მხატვრული' 'სტილი'
#  ',' 'განსაკუთრებული' ',' 'თავისთავადი' ',' 'მომხიბლავი' 'და'
#  'შეუდარებელი' '.']
# [('ბარნოვის', 'N'), ('მხატვრული', 'A'), ('სისტემა', 'N'), ('მრავალ', 'A'), ('თავისებურებას', 'N'), ('მოიცავს', 'V'), ('და', 'Cj'), ('ერთ', 'A'), ('-', 'A'), ('ერთიც', 'A'), ('ესაა', 'Pron'), (',', 'Punct'), ('ერთ', 'A'), ('-', 'A'), ('ერთიცა', 'A'), ('და', 'Cj'), ('ძირითადიცა', 'A'), ('-', 'N'), ('მხატვრული', 'A'), ('სტილი', 'N'), (',', 'Punct'), ('განსაკუთრებული', 'A'), (',', 'Punct'), ('თავისთავადი', 'A'), (',', 'Punct'), ('მომხიბლავი', 'A'), ('და', 'Cj'), ('შეუდარებელი', 'A'), ('.', 'Punct')]
#
# ['ქართული' 'წარმოდგენა' 'პე-ტერბურღში' '.']
# [('ქართული', 'A'), ('წარმოდგენა', 'N'), ('პე', 'N'), ('-', 'N'), ('ტერბურღში', 'N'), ('.', 'Punct')]
#
# ['ქართულ' 'მხარეს' 'ამასთან' 'დაკავშირებით' 'ჯერ-ჯერობით' 'კომენტარი' 'არ'
#  'გაუკეთებია' '.']
# [('ქართულ', 'A'), ('მხარეს', 'N'), ('ამასთან', 'Pron'), ('დაკავშირებით', 'Pp'), ('ჯერ', 'Adv'), ('-', 'N'), ('ჯერობით', 'Adv'), ('კომენტარი', 'N'), ('არ', 'Adv'), ('გაუკეთებია', 'V'), ('.', 'Punct')]
#
# ['გამოსვლა' 'მესამე' 'იგინივე' 'და' 'მოლა-მუსა' 'მუსა' '(' 'აღელვებული'
#  ')' 'აქედან' 'რაღაც' 'საუბარი' 'მომესმა' '!']
# [('გამოსვლა', 'N'), ('მესამე', 'Num'), ('იგინივე', 'Num'), ('და', 'Cj'), ('მოლა', 'N'), ('-', 'N'), ('მუსა', 'N'), ('მუსა', 'N'), ('(', 'Punct'), ('აღელვებული', 'A'), (')', 'Punct'), ('აქედან', 'Adv'), ('რაღაც', 'Pron'), ('საუბარი', 'N'), ('მომესმა', 'V'), ('!', 'Punct')]
#
# ['96' 'ხომ' 'მოგეხსენებათ' ',' 'ჩვენში' 'საცა' 'სმაა' ',' 'იქ' 'სიმღერაც'
#  'არის' ',' 'და' 'აი' 'კაკლის' 'ქვეშ' 'გაის-მის' 'განუწყვეტელი'
#  'მრავალჟამიერ' ',' 'ყანწით' 'ვსვამ' 'ღვინოს' ',' 'გულში' 'ჭირიმე' ','
#  'სულში' 'ჭირიმე' 'და' 'სხვა' 'ამისთანები' '.']
# [('96', 'Num'), ('ხომ', 'Adv'), ('მოგეხსენებათ', 'V'), (',', 'Punct'), ('ჩვენში', 'Pron'), ('საცა', 'A'), ('სმაა', 'N'), (',', 'Punct'), ('იქ', 'Adv'), ('სიმღერაც', 'N'), ('არის', 'V'), (',', 'Punct'), ('და', 'Cj'), ('აი', 'Adv'), ('კაკლის', 'N'), ('ქვეშ', 'Pp'), ('გაის', 'Adv'), ('-', 'N'), ('მის', 'Pron'), ('განუწყვეტელი', 'A'), ('მრავალჟამიერ', 'A'), (',', 'Punct'), ('ყანწით', 'V'), ('ვსვამ', 'V'), ('ღვინოს', 'N'), (',', 'Punct'), ('გულში', 'N'), ('ჭირიმე', 'N'), (',', 'Punct'), ('სულში', 'N'), ('ჭირიმე', 'N'), ('და', 'Cj'), ('სხვა', 'A'), ('ამისთანები', 'N'), ('.', 'Punct')]
#
# ['ტარიელისა' 'და' 'ნესტან-დარეჯანის' 'თათბირი' 'და' 'გამორჩევა' '517'
#  'მეტმან' 'სევდამან' 'მიმწურა' 'გულსა' 'დაცემად' 'დანისად' '.']
# [('ტარიელისა', 'N'), ('და', 'Cj'), ('ნესტან', 'N'), ('-', 'N'), ('დარეჯანის', 'N'), ('თათბირი', 'N'), ('და', 'Cj'), ('გამორჩევა', 'N'), ('517', 'Num'), ('მეტმან', 'N'), ('სევდამან', 'N'), ('მიმწურა', 'N'), ('გულსა', 'N'), ('დაცემად', 'N'), ('დანისად', 'N'), ('.', 'Punct')]
#
# ['მოძრაობა' 'სამართლიანი' 'საქართველოსთვის' 'ლიდერი' ',' 'ყოფილი'
#  'პრემიერ-მინისტრი' 'ზურაბ' 'ნოღაიდელი' '28' 'ივნისს' 'მოსკოვს' 'ეწვევა'
#  'და' 'რუსეთის' 'მმართველი' 'პარტიის' '„' 'ედინია' 'როსიას' '”'
#  'წარმომადგენლებთან' 'გამართავს' 'მოლაპარაკებებს' ',' 'იტყობინება'
#  'ნოღაიდელის' 'პარტიის' 'პრესსამსახური' '.']
# [('მოძრაობა', 'N'), ('სამართლიანი', 'A'), ('საქართველოსთვის', 'N'), ('ლიდერი', 'N'), (',', 'Punct'), ('ყოფილი', 'A'), ('პრემიერ', 'N'), ('-', 'N'), ('მინისტრი', 'N'), ('ზურაბ', 'N'), ('ნოღაიდელი', 'N'), ('28', 'Num'), ('ივნისს', 'N'), ('მოსკოვს', 'N'), ('ეწვევა', 'V'), ('და', 'Cj'), ('რუსეთის', 'N'), ('მმართველი', 'A'), ('პარტიის', 'N'), ('„', 'Punct'), ('ედინია', 'N'), ('როსიას', 'N'), ('”', 'Punct'), ('წარმომადგენლებთან', 'N'), ('გამართავს', 'V'), ('მოლაპარაკებებს', 'N'), (',', 'Punct'), ('იტყობინება', 'V'), ('ნოღაიდელის', 'N'), ('პარტიის', 'N'), ('პრესსამსახური', 'N'), ('.', 'Punct')]
#
# ['ერთი' 'ჩემებურად' 'ავდიდდები' ',' 'ვეცემი' 'იმის' 'ბეღელ-მარანს' ','
#  'სარდაფს' 'და' 'სულ' 'ველად' 'გავიტან' ',' 'გავაოხრებ' 'და' 'გავატიალებ'
#  '.']
# [('ერთი', 'Num'), ('ჩემებურად', 'A'), ('ავდიდდები', 'V'), (',', 'Punct'), ('ვეცემი', 'N'), ('იმის', 'Pron'), ('ბეღელ', 'N'), ('-', 'N'), ('მარანს', 'N'), (',', 'Punct'), ('სარდაფს', 'N'), ('და', 'Cj'), ('სულ', 'Adv'), ('ველად', 'V'), ('გავიტან', 'V'), (',', 'Punct'), ('გავაოხრებ', 'V'), ('და', 'Cj'), ('გავატიალებ', 'V'), ('.', 'Punct')]
#
# ['იქედან' 'ბევრი' 'აღარ' 'დამრჩა' ',' 'განსაკუთრებით' 'ინგლისურები' ','
#  'რადგან' '90-იანებში' 'ჩავარბენინე' 'ბუკინისტურში' 'დეიდა' 'იზოსთან' 'და'
#  'მაიასთან' '.']
# [('იქედან', 'Adv'), ('ბევრი', 'A'), ('აღარ', 'Adv'), ('დამრჩა', 'V'), (',', 'Punct'), ('განსაკუთრებით', 'Adv'), ('ინგლისურები', 'N'), (',', 'Punct'), ('რადგან', 'Cj'), ('90', 'N'), ('-', 'N'), ('იანებში', 'N'), ('ჩავარბენინე', 'N'), ('ბუკინისტურში', 'N'), ('დეიდა', 'N'), ('იზოსთან', 'N'), ('და', 'Cj'), ('მაიასთან', 'N'), ('.', 'Punct')]
#
# ['და' 'შევიდა' 'სამცხეს' 'შაჰ-თამაზ' 'და' 'დაიპყრა' 'ციხენი' 'და'
#  'განასხნა' 'ოსმალნი' '.']
# [('და', 'Cj'), ('შევიდა', 'V'), ('სამცხეს', 'N'), ('შაჰ', 'N'), ('-', 'N'), ('თამაზ', 'N'), ('და', 'Cj'), ('დაიპყრა', 'V'), ('ციხენი', 'N'), ('და', 'Cj'), ('განასხნა', 'V'), ('ოსმალნი', 'N'), ('.', 'Punct')]
#
# ['ყოველ' 'დაწოლა-ადგომისას' ',' 'ტანსაცმლის' 'ყოველი' 'გამოცვლისას'
#  'საოცრად' 'ფრთხილად' 'და' 'ყურადღებით' 'უნდა' 'ვყოფილიყავი' ','
#  'მშობლებს' 'ეს' 'ფოტო' 'რომ' 'არ' 'აღმოეჩინათ' ',' 'რომელსაც' 'არ' 'ვიცი'
#  ',' 'დღე-ღამე' 'რამდენი' 'საათის' 'განმავლობაში' 'დავყურებდი' 'ხოლმე' '.']
# [('ყოველ', 'A'), ('დაწოლა', 'N'), ('-', 'N'), ('ადგომისას', 'N'), (',', 'Punct'), ('ტანსაცმლის', 'N'), ('ყოველი', 'A'), ('გამოცვლისას', 'N'), ('საოცრად', 'A'), ('ფრთხილად', 'A'), ('და', 'Cj'), ('ყურადღებით', 'N'), ('უნდა', 'Pron'), ('ვყოფილიყავი', 'V'), (',', 'Punct'), ('მშობლებს', 'A'), ('ეს', 'Pron'), ('ფოტო', 'N'), ('რომ', 'Cj'), ('არ', 'Adv'), ('აღმოეჩინათ', 'V'), (',', 'Punct'), ('რომელსაც', 'Pron'), ('არ', 'Adv'), ('ვიცი', 'V'), (',', 'Punct'), ('დღე', 'N'), ('-', 'N'), ('ღამე', 'N'), ('რამდენი', 'Pron'), ('საათის', 'N'), ('განმავლობაში', 'N'), ('დავყურებდი', 'V'), ('ხოლმე', 'Adv'), ('.', 'Punct')]
#
# ['თუმცა' ',' 'აღნიშნა' ',' 'რომ' '„' 'ვიცე-პრეზიდენტი' 'არ'
#  'გააკონტროლებს' 'თავდაცვისა' 'და' 'უშიშროების' 'სტრუქტურებს' ',' 'ისევე'
#  'როგორც' 'საგარეო' 'პოლიტიკას' '.']
# [('თუმცა', 'Adv'), (',', 'Punct'), ('აღნიშნა', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('„', 'Punct'), ('ვიცე', 'N'), ('-', 'N'), ('პრეზიდენტი', 'N'), ('არ', 'Adv'), ('გააკონტროლებს', 'V'), ('თავდაცვისა', 'N'), ('და', 'Cj'), ('უშიშროების', 'N'), ('სტრუქტურებს', 'N'), (',', 'Punct'), ('ისევე', 'Adv'), ('როგორც', 'Adv'), ('საგარეო', 'A'), ('პოლიტიკას', 'N'), ('.', 'Punct')]
#
# ['მარაბდელებს' 'დროზე' 'შეუტყვიათ' 'ქართველთა' 'მოახლოება' 'და' 'მახლობელ'
#  'მთებში' 'გახიზნულან' 'დიდიან-პატარიანად' '.']
# [('მარაბდელებს', 'N'), ('დროზე', 'N'), ('შეუტყვიათ', 'V'), ('ქართველთა', 'N'), ('მოახლოება', 'N'), ('და', 'Cj'), ('მახლობელ', 'N'), ('მთებში', 'N'), ('გახიზნულან', 'N'), ('დიდიან', 'A'), ('-', 'A'), ('პატარიანად', 'A'), ('.', 'Punct')]
#
# ['გაირკვა' 'იმ' 'პირთა' 'ვინაობაც' ',' 'რომლებმაც' 'ამოწერეს'
#  'ზემოხსენებული' 'წერილები' 'და' 'დადგინდა' 'ისიც' ',' 'რომ' 'სათანადო'
#  'ხელშეკრულებით' 'ხელნაწერები' 'მწერალმა' 'თვითონ' 'გადასცა' '„'
#  'ქართველთა' 'შორის' 'წერა-კითხვის' 'გამავრცელებელ' 'საზოგადოებას' '”' '.']
# [('გაირკვა', 'V'), ('იმ', 'Pron'), ('პირთა', 'N'), ('ვინაობაც', 'N'), (',', 'Punct'), ('რომლებმაც', 'Pron'), ('ამოწერეს', 'V'), ('ზემოხსენებული', 'A'), ('წერილები', 'N'), ('და', 'Cj'), ('დადგინდა', 'V'), ('ისიც', 'Pron'), (',', 'Punct'), ('რომ', 'Cj'), ('სათანადო', 'A'), ('ხელშეკრულებით', 'N'), ('ხელნაწერები', 'N'), ('მწერალმა', 'N'), ('თვითონ', 'Adv'), ('გადასცა', 'V'), ('„', 'Punct'), ('ქართველთა', 'N'), ('შორის', 'Pp'), ('წერა', 'N'), ('-', 'N'), ('კითხვის', 'N'), ('გამავრცელებელ', 'A'), ('საზოგადოებას', 'N'), ('”', 'Punct'), ('.', 'Punct')]
#
# ['თითო-ოროლამ' 'სცადა' 'ტაშის' 'დაკვრა' ',' 'მაგრამ' 'უშედეგოდ' '.']
# [('თითო', 'A'), ('-', 'A'), ('ოროლამ', 'N'), ('სცადა', 'V'), ('ტაშის', 'N'), ('დაკვრა', 'N'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('უშედეგოდ', 'A'), ('.', 'Punct')]
#
# ['მან' 'მოუწოდა' 'დსთ-ს' 'წევრ' 'ქვეყნებს' 'დაინტერესდნენ' ',' 'თუ' 'რა'
#  'ხდება' 'ქართულ' 'ღვინოსთან' 'დაკავშირებით' 'და' '„' 'გამოგვიცხადონ'
#  'სოლიდარობა' 'იქ' ',' 'სადაც' 'საქართველოს' 'პოზიციები' 'ნამდვილად'
#  'სამართლიანია' '”' '.']
# [('მან', 'Pron'), ('მოუწოდა', 'V'), ('დსთ', 'N'), ('-', 'N'), ('ს', 'N'), ('წევრ', 'N'), ('ქვეყნებს', 'N'), ('დაინტერესდნენ', 'V'), (',', 'Punct'), ('თუ', 'Cj'), ('რა', 'Pron'), ('ხდება', 'V'), ('ქართულ', 'A'), ('ღვინოსთან', 'N'), ('დაკავშირებით', 'Pp'), ('და', 'Cj'), ('„', 'Punct'), ('გამოგვიცხადონ', 'V'), ('სოლიდარობა', 'N'), ('იქ', 'V'), (',', 'Punct'), ('სადაც', 'Adv'), ('საქართველოს', 'N'), ('პოზიციები', 'N'), ('ნამდვილად', 'Adv'), ('სამართლიანია', 'A'), ('”', 'Punct'), ('.', 'Punct')]
#
# ['მაგრამ' 'ალბერისათვის' 'საშაქრე' 'მაინც' 'იდო' ':' 'მონტე-კრისტო' 'და'
#  'ჰაიდე' 'ამ' 'არაბულ' 'სასმელს' 'არაბული' 'წესით' ',' 'ესე' 'იგი'
#  'უშაქროდ' 'სვამდნენ' '.']
# [('მაგრამ', 'Cj'), ('ალბერისათვის', 'N'), ('საშაქრე', 'A'), ('მაინც', 'Adv'), ('იდო', 'V'), (':', 'Punct'), ('მონტე', 'N'), ('-', 'N'), ('კრისტო', 'N'), ('და', 'Cj'), ('ჰაიდე', 'N'), ('ამ', 'Pron'), ('არაბულ', 'A'), ('სასმელს', 'N'), ('არაბული', 'A'), ('წესით', 'N'), (',', 'Punct'), ('ესე', 'V'), ('იგი', 'Pron'), ('უშაქროდ', 'A'), ('სვამდნენ', 'V'), ('.', 'Punct')]
#
# ['მაშინ' 'ეს' 'ფაქტი' 'აღქმული' 'იქნა' ',' 'როგორც' 'რუსეთ-საქართველოს'
#  'მეგობრობის' 'დადასტურებად' '.']
# [('მაშინ', 'Adv'), ('ეს', 'Pron'), ('ფაქტი', 'N'), ('აღქმული', 'A'), ('იქნა', 'V'), (',', 'Punct'), ('როგორც', 'Cj'), ('რუსეთ', 'N'), ('-', 'N'), ('საქართველოს', 'N'), ('მეგობრობის', 'N'), ('დადასტურებად', 'A'), ('.', 'Punct')]
#
# ['ამის' 'გამგონ' 'ცოლ-ქმარს' 'იმედი' 'ეძლეოდა' ',' 'რომ' 'ბეკინა' 'მეტად'
#  'დაშორებული' 'უნდა' 'ყოფილიყო' 'რაიმე' 'მათ' 'საწყენ' 'საქციელს' 'და'
#  'ბოლოს' 'კიდეც' 'სრულიად' 'გული' 'დაიმშვიდეს' '.']
# [('ამის', 'Pron'), ('გამგონ', 'N'), ('ცოლ', 'N'), ('-', 'N'), ('ქმარს', 'N'), ('იმედი', 'N'), ('ეძლეოდა', 'V'), (',', 'Punct'), ('რომ', 'Cj'), ('ბეკინა', 'N'), ('მეტად', 'A'), ('დაშორებული', 'A'), ('უნდა', 'Pron'), ('ყოფილიყო', 'V'), ('რაიმე', 'A'), ('მათ', 'Pron'), ('საწყენ', 'N'), ('საქციელს', 'N'), ('და', 'Cj'), ('ბოლოს', 'Adv'), ('კიდეც', 'Adv'), ('სრულიად', 'Adv'), ('გული', 'N'), ('დაიმშვიდეს', 'V'), ('.', 'Punct')]
#
# ['მზე' 'გაივლის' 'თორმეტ' 'ზოდიაკოს' ',' 'მაგრამ' 'ამას' 'გარდა' 'მზეს'
#  'ჰყავს' 'თავისი' 'საკუთარი' 'ეტლი-ზოდიაკო' ',' 'რომელში' 'ყოფნის' 'დროს'
#  'იგი' 'არის' 'ყველა' 'თავისი' 'ძალითა' 'და' 'შვენებით' 'უძლიერესი' 'და'
#  'უკეთესი' '.']
# [('მზე', 'N'), ('გაივლის', 'V'), ('თორმეტ', 'Num'), ('ზოდიაკოს', 'N'), (',', 'Punct'), ('მაგრამ', 'Cj'), ('ამას', 'Pron'), ('გარდა', 'Pp'), ('მზეს', 'N'), ('ჰყავს', 'V'), ('თავისი', 'Pron'), ('საკუთარი', 'A'), ('ეტლი', 'N'), ('-', 'N'), ('ზოდიაკო', 'N'), (',', 'Punct'), ('რომელში', 'Pron'), ('ყოფნის', 'N'), ('დროს', 'N'), ('იგი', 'Pron'), ('არის', 'V'), ('ყველა', 'A'), ('თავისი', 'Pron'), ('ძალითა', 'N'), ('და', 'Cj'), ('შვენებით', 'N'), ('უძლიერესი', 'A'), ('და', 'Cj'), ('უკეთესი', 'A'), ('.', 'Punct')]
#
# ['ილიას' 'მიერ' 'მუსიკა-ლური' 'სმენის' 'უქონლობა' '.']
# [('ილიას', 'N'), ('მიერ', 'Pp'), ('მუსიკა', 'N'), ('-', 'N'), ('ლური', 'N'), ('სმენის', 'N'), ('უქონლობა', 'N'), ('.', 'Punct')]
#
# ['„' 'უახლოესი' 'დღეები' 'და' 'შსკ-ს' 'სხდომის' 'შედეგები' 'გამოაჩენს'
#  'დავრჩები' 'თუ' 'არა' 'თანამდებობაზე' '.']
# [('„', 'Punct'), ('უახლოესი', 'A'), ('დღეები', 'N'), ('და', 'Cj'), ('შსკ', 'N'), ('-', 'N'), ('ს', 'N'), ('სხდომის', 'N'), ('შედეგები', 'N'), ('გამოაჩენს', 'V'), ('დავრჩები', 'V'), ('თუ', 'Cj'), ('არა', 'Adv'), ('თანამდებობაზე', 'N'), ('.', 'Punct')]
# KeyboardInterrupt
